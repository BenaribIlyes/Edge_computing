# %% [markdown]
# <a href="https://colab.research.google.com/github/BenaribIlyes/Edge_computing/blob/main/code/edge_computing_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Travaux Pratiques - N9EE39A Edge Computing
# **Contact: Adrien THIRION ([email](adrien.thirion@nanomade.com))**
# **Créé en Octobre 2023**
#
# L'objectif de ces séances de travaux pratiques est de vous familiariser avec le métier de Data Scientists, plus particulièrement dans un environnement contraint (système embarqué). Celui-ci a été pensé pour développer une vue d'ensemble de toutes les étapes nécessaires lors de la création d'un modèle, jusqu'à ce que celui-ci soit embarqué.
#
# Comme tout bon data scientist, l'utilisation de fonction existante sur internet est vitale !! En effet, l'intelligence artificielle est très présent de nos jours, donc si vous avez un problème, il est presque assuré que quelqu'un ait déjà eu le même !
#
# Le TP va se porter sur un sujet concret: la reconnaissance vocal. Ce sujet rentre dans le thème du Traitement automatique du langage naturel ou NLP [1]) où la demande en IA embarqué est très recherchée (ex. enceinte connecté, smartphone, smartwatches, ..). Pour cela, vous allez vous baser sur une base de données existante se trouvant Kaggle: the TensorFlow Speech Recognition Challenge. Kaggle est un site de competition permettant de récompenser les meilleurs modèles avec des prix décernés aux meilleurs modèles. Cette compétition a été organisée par Google, avec plus de 25 000$ à gagner. Certaines peuvent même dépasser le million de dollard (ex. Netflix Price) donc si vous avez soif d'argent ou que le l'IA vous plaît, allez y jeter un coup d'oeil !
#
# Dans ce projet, vous allez essayer de classer correctement les 12 labels présents dans cette base de donnée via un modèle de convolution 1D ou récursif que vous aurez optimisé. Puis, vous devrez visualiser la variation des performances de ce modèle en fonction de son allégement (dans une volonté de l'embarquer).
#
# Le Rapport devra être fait sur ce jupyter notebook, en Markdown (comme le texte que vous êtes en train de lire).
#
# Ce projet a pour but d'évaluer votre esprit critique, votre analyse d'un problème et votre regard critique sur vos performances. Pour cela, l'entraide est encouragée mais en aucun cas le plagiat. Merci de respecter cela (promis c'est pour votre bien). Expliquez bien votre démarche et la raison de vos choix !!
#
# Le projet sera découpé en 5 TPs de 4h. Un guide de progession sera affiché sur chaque partie pour connaître votre avancement.
#
# Ce projet va être découpé en plusieurs parties:
#
# 1. L'Analyse de la base de donnée.
# 2. L'état de l'art.
# 3. Le Preprocessing.
# 4. L'apprentissage du modèle.
# 5. Les résultats et discussions.
# 6. L'allégement du modèle.
# 7. La conclusion.

# %% [markdown]
# # Analyse de la base de données
#
# La première étape est de télecharger et d'analyser la base de donnée. Pour cela rendez vous sur le site de la compétition:
# https://www.kaggle.com/competitions/tensorflow-speech-recognition-challenge/overview
#
# Pensez à bien regarder la compétition en détail, cela pourra vous être très utile (comme par exemple trouver du code ou des articles).

# %% [markdown]
# # Information sur la base de donnée
#
# Tips: Parlez de tous ce que vous savez des données (quantité d'instances, les labels, la taille d'une time series, sa fréquence d'echantillonage, ...).
#
# Le dossier contient trois fichiers principaux :
# - Train.7z : Les données d'entraînement sont des enregistrements d'une seconde. La fréquence d'échantillonnage est de 16 KHz . Les labels à prédire sont : yes, no, up, down, left, right, on, off, stop, go.
#
# -Test.7z : Contient un dossier de 150,000+ fichiers au format wav.
#
# -Sample_submission.csv - Un exemple de rendu.
# Visualitation d'une donnée et analyse critique
#
# Tips: Faites un subplot de plusieurs labels différents pour voir visuellement les différences.

# %% [markdown]
# # Visualitation d'une donnée et analyse critique
#
# Tips: Faites un subplot de plusieurs labels différents pour voir visuellement les différences.
#
#     On observe qu'il va être compliqué de différencier les données par leur enregsitrement simple et donc nécéssaire de mettre en place une chaîne de pré-traitement comme dans les précédents projets de traitement que nous avons réalisé.

# %%
import matplotlib.pyplot as plt
import numpy as np
import IPython.display as ipd
from scipy.io import wavfile

# %%
#from google.colab import drive # Pour google colab
#drive.mount('/content/drive')  # Pour google colab

# Ajouter ce dossier dans votre drive: https://drive.google.com/drive/folders/1AAiaDTWJzvS6NaZXE_dfJ603QWhhcl0R?usp=sharing
# train_data_path = '/home/zebre/Bureau/IATI/3A/IA_et_materiel/edge_computing/Edge_computing/data/tensorflow-speech-recognition-challenge/train/audio'

# %%
#Pour utiliser le notebook en local

#Préciser le path des données d'entrainements
train_data_path = '/home/zebre/Bureau/eddge_computing/Edge_computing/data/train/audio'

#Préciser le path des données de test
test_data_path = '/home/zebre/Bureau/eddge_computing/Edge_computing/data/test/audio'

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

# Chemin vers les données
labels = os.listdir(train_data_path)[1:]  # On ignore le premier fichier

# Sélection aléatoire de 9 labels
Random_Labels = np.random.choice(labels, size=9, replace=False)

plt.figure(figsize=(15, 8))

for i, label in enumerate(Random_Labels, 1):
    wav_files_path = os.path.join(train_data_path, label)
    random_wav = np.random.choice(os.listdir(wav_files_path))  # un fichier wav aléatoire
    sr, time_series = wavfile.read(os.path.join(wav_files_path, random_wav))

    plt.subplot(3, 3, i)
    plt.plot(time_series)
    plt.grid()
    plt.title(label)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Stockage des données
#  <font color="red"> **ATTENTION:** Respectez l'ordre des labels: 0 = yes, 1 = no, 2 = up, 3 = down, 4 = left, 5 = right, 6 = on, 7 = off, 8 = stop, 9 = go, 10 = silence, 11 = unknown </font>
#
# <font color=" Darkblue"> **Tips:** Réduisez la taille des données d'entrées afin d'éviter la saturation de la mémoire </font>

# %%
import os
import numpy as np
from scipy.io import wavfile
import pandas as pd  # Importer pandas

# Dictionnaire pour identifier les label
Data_Dict = {
      "yes": 0,
      "no": 1,
      "up": 2,
      "down": 3,
      "left": 4,
      "right": 5,
      "on": 6,
      "off": 7,
      "stop": 8,
      "go": 9,
      "silence": 10,
      "unknown": 11
}

# Dictionnaire inversé pour l'affichage (toujours utile)
ID_to_Label = {v: k for k, v in Data_Dict.items()}

# On utilise une constante que l'on récupèredepuis Data_Dict pour éviter NameError 
UNKNOWN_ID = Data_Dict.get("unknown", Data_Dict.get("UNKNOWN_ID", 11))


# Fonction d'import des données en dataframe pandas
def import_data_as_dataframe(max_files_per_label=None, max_unknown=None, data_path=train_data_path, seed=42, shuffle=True):
    ''' 
    Importe les données. 
    Par défaut (None), importe TOUS les fichiers disponibles.
    Si un entier est fourni, limite l'import à ce nombre.
    '''
    rows = []

    # Scan des fichiers 
    for label in os.listdir(data_path):
        label_path = os.path.join(data_path, label)
        if not os.path.isdir(label_path):
            continue

        label_id = Data_Dict.get(label, UNKNOWN_ID)
        label_name = ID_to_Label.get(label_id, "unknown")

        wav_files = [f for f in os.listdir(label_path) if f.endswith(".wav")]

        for wav_file in wav_files:
            file_path = os.path.join(label_path, wav_file)
            rows.append({"file_path": file_path, "label_id": label_id, "label_name": label_name})

    df_all = pd.DataFrame(rows)

    # Sampling intelligent
    sampled_dfs = []
    rng = np.random.RandomState(seed)

    for label_id, group in df_all.groupby("label_id"):
        # Choix de la limite à appliquer
        if label_id == UNKNOWN_ID:
            limit = max_unknown
        else:
            limit = max_files_per_label

        # Si la limite est None, on prend tout le groupe, sinon on prend le min(dispo, limite)
        if limit is None:
            n = len(group)
        else:
            n = min(len(group), limit)

        sampled = group.sample(n=n, random_state=rng)
        sampled_dfs.append(sampled)

    df = pd.concat(sampled_dfs, ignore_index=True)

    # Shuffle des données
    if shuffle:
        df = df.sample(frac=1.0, random_state=seed).reset_index(drop=True)

    # 4. Lecture des waves et padding à 1 sec (16000 échantillons)
    all_waves = []
    for file_path in df["file_path"]:
        sr, samples = wavfile.read(file_path)

        if len(samples) > 16000:
            samples = samples[:16000]
        else:
            samples = np.pad(samples, (0, 16000 - len(samples)))

        all_waves.append(samples)

    X = np.array(all_waves) 
    df_labels = df[["label_id", "label_name"]].copy()

    return X, df_labels

# %%
waves, labels = import_data_as_dataframe(data_path=train_data_path)
print("Formats des données = ",waves.shape)
print("Formats des labels = ",labels.shape)
# Out:
# /tmp/ipykernel_57985/1334860832.py:84: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sr, samples = wavfile.read(file_path)
# Formats des données =  (67727, 16000)
# Formats des labels =  (67727, 2)

# %%
def plot_data_distribution(df):
    """
    Affiche un histogramme de la répartition des classes.
    df : DataFrame contenant au moins une colonne 'label_name'
    """
    # 1. Comptage des occurrences
    counts = df['label_name'].value_counts()

    # 2. Création de la figure
    plt.figure(figsize=(12, 6))
    bars = plt.bar(counts.index, counts.values, color='skyblue', edgecolor='black')

    # 3. Mise en forme
    plt.title(f'Distribution du Dataset (Total: {len(df)} échantillons)', fontsize=14)
    plt.xlabel('Classes (Mots-clés)', fontsize=12)
    plt.ylabel("Nombre d'enregistrements", fontsize=12)
    plt.xticks(rotation=45)
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # 4. Ajout des valeurs sur les barres (Feedback visuel immédiat)
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height + 5,
                 f'{int(height)}',
                 ha='center', va='bottom', fontweight='bold')

    plt.tight_layout()
    plt.show()

# %%
# On affiche la distribtuon de nos données par vérification
plot_data_distribution(labels)

# %% [markdown]
#     On obtient 64727 enregsitrement dans notre Dataframe après une tentaive d'import de 1000 fichiers par classe (12 classes) car on ne dispose que de 6 enregsitemnt de bruit de fond (assimilé à la classe silence). Il faudra donc découper ces enregsitrements pour en obtenir un miliers et pouvoir avoir un nombre d'échantillon suffisant pour les classifier. Nous proposons une solution à ce problème ci dessous:

# %%
# Chemin vers le dossier contenant les 6 fichiers originaux (_background_noise_)
source_folder = os.path.join(train_data_path, "_background_noise_")

# Chemin du nouveau dossier où on va créer les milliers de fichiers
target_folder = os.path.join(train_data_path, "silence")

# Paramètres de découpage
SAMPLE_RATE = 16000    # Le dataset est en 16kHz
CLIP_DURATION = 16000  # On garde une seconde
STRIDE = 1000          # Pas d'avancement (1000 samples)
                

def generate_silence_files():
    # Création du dossier cible s'il n'existe pas
    if not os.path.exists(target_folder):
        os.makedirs(target_folder)
        print(f"Dossier créé : {target_folder}")

    files_created_count = 0
    
    # On parcourt les 6 fichiers de bruit de fond
    noise_files = [f for f in os.listdir(source_folder) if f.endswith('.wav')]
    
    print(f"Traitement de {len(noise_files)} fichiers de bruit de fond...")

    for wav_file in noise_files:
        src_path = os.path.join(source_folder, wav_file)
        sr, audio = wavfile.read(src_path)
        
        # Vérification fréquence
        if sr != SAMPLE_RATE:
            print(f"Attention: {wav_file} est à {sr}Hz au lieu de {SAMPLE_RATE}Hz. Ignoré.")
            continue
            
        # Découpage en tranches (Sliding Window)
        # On avance de 'STRIDE' à chaque fois pour maximiser le nombre de fichiers
        for i in range(0, len(audio) - CLIP_DURATION, STRIDE):
            chunk = audio[i : i + CLIP_DURATION]
            
            # Nom unique pour le nouveau fichier
            # ex: running_tap_0001.wav
            new_filename = f"{os.path.splitext(wav_file)[0]}_{i}.wav"
            dst_path = os.path.join(target_folder, new_filename)
            
            wavfile.write(dst_path, SAMPLE_RATE, chunk)
            files_created_count += 1
            
            # Sécurité pour ne pas saturer le disque dur si le stride est trop petit
            if files_created_count >= 3000: # Limite arbitraire à 3000 fichiers
                break
        
        if files_created_count >= 3000:
            break

    print(f"Terminé ! {files_created_count} fichiers 'silence' de 1s ont été générés dans {target_folder}")

# Lancer la génération
generate_silence_files()
# Out:
# Traitement de 6 fichiers de bruit de fond...
# Terminé ! 3000 fichiers 'silence' de 1s ont été générés dans /home/zebre/Bureau/eddge_computing/Edge_computing/data/train/audio/silence
# /tmp/ipykernel_57985/2975609648.py:28: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sr, audio = wavfile.read(src_path)

# %% [markdown]
#     On regénère donc les données avec notre fonction d'importation déjà établis et on vérifie qu'on obtient bien ke bon nombre de fichiers.

# %%
waves, labels = import_data_as_dataframe(data_path=train_data_path)
print("Formats des données = ",waves.shape)
print("Formats des labels = ",labels.shape)
# Out:
# /tmp/ipykernel_57985/1334860832.py:84: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sr, samples = wavfile.read(file_path)
# Formats des données =  (67727, 16000)
# Formats des labels =  (67727, 2)

# %%
# Exemple de donnée
id_exemple = 5

# Signal audio
signal_ex = waves[id_exemple]

# ID + nom du label via le DataFrame
label_id_ex = labels.loc[id_exemple, "label_id"]
label_name_ex = labels.loc[id_exemple, "label_name"]

print(f"Exemple d'échantillon de données : {signal_ex}")
print(f"ID du label : {label_id_ex}")
print(f"Nom du label : {label_name_ex}")

# Lecture audio
ipd.Audio(signal_ex, rate=16000)
# Out:
# Exemple d'échantillon de données : [ 4  6  3 ... -2 -3 -4]
# ID du label : 0
# Nom du label : yes
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Etat de l'art
#
# Etape importante qui suit: faire un état de l'art. Que cela soit pour innover, ou pour trouver une solution existante pertinente, faire un état de l'art scientifique est essentiel. Ici, vous devez chercher les articles liés à ce projet. Il faut pour cela remplir le tableau et bien marquer leurs références en dessous. De plus, un texte synthétique vous sera demandé pour expliquer selon vous, quels papiers sont les plus pertinants pour la suite de ce projet.
#
# Attention: une analyse critique est nécessaire sur ces papiers (certain papiers peuvent avoir des biais cachés).
#
# <font color="orange"> **Note anti-plagiat:** Au moins 2 références devraient être différente des autres binômes. </font>
#
# &nbsp;
#
#
# <font color="Darkred"> Progression du TP après cette partie (environ 2h):
#
# &nbsp;
#
# ---
#
# Le véritable état de l'art pour ce défi est construit autour de deux axes majeurs : la définition du jeu de données et la conception d'architectures optimisées pour les contraintes d'embarqué.
#
# ### Tableau Récapitulatif
#
#
# | Article | Références | Preprocessing | Modèle | Solution Embarquée ? | Dataset utilisé | Performances (Baseline) |
# | :--- | :--- | :--- | :--- | :--- | :--- | :--- |
# | **Warden (2018)** | [1] Speech Commands | Normalisation 1s, 16kHz. Alignement temporel (padding/cropping). Décimation (downsampling) implicite. | CNN standard (traditionnel). Sert de référence. | **Oui**, avec objectif de faible empreinte mémoire et robustesse au bruit. | **Speech Commands** (Google).Semble être un standard du KWS. | **88.2%** Accuracy (Baseline). |
# | **Zhang et al. (2017) "Hello Edge"** | [2] Hello Edge | Extraction de features MFCC (40 coeffs). | **DS-CNN** (Depthwise Separable CNN). Architecture optimisée. | **Oui**. Optimisé spécifiquement pour microcontrôleurs (Arm Cortex-M). | Speech Commands v1. | **95.4%** Accuracy. Meilleur compromis précision/mémoire. |
# | **Howard et al. (2017) "MobileNets"** | [3] MobileNets | Redimensionnement d'images (concept adaptable aux spectrogrammes). | CNN à convolutions séparables (Depthwise + Pointwise). | **Oui**. Réduit drastiquement les MACs (Opérations) et paramètres vs CNN standard. | ImageNet (Classification). | **70.6%** Accuracy avec ~8x moins de calculs que VGG16. |
# | **Zhang et al. (2017) "End-to-End"** | [4] End-to-End Speech | Log-Mel filterbanks. Normalisation par utterance. | Deep CNN profond sans couches récurrentes. | **Oui (Indirect)**. Prouve que les CNN sont aussi efficaces que les LSTM pour l'audio. | TIMIT (Phonèmes). | **18.2%** Phone Error Rate (Compétitif avec LSTM). |
# | **Han et al. (2016) "Deep Compression"** | [5] Deep Compression | N/A (Focalisé sur la compression des poids après entraînement). | N/A (Focalisé sur la compression des poids après entraînement). Mets en place un pipeline : **Élagage** (Pruning), **Clustering** (Weight Sharing) et Quantification. | **Oui**. Permet de faire tenir de gros modèles dans une mémoire flash limitée. | ImageNet (Démo), applicable KWS. | Réduction de taille de **35x à 49x** sans perte de précision. |
# | **Jacob et al. (2018) (Google)** | [6] Quantization & Training | N/A (Focus sur l'arithmétique entière). | N/A (Focus sur l'arithmétique entière).Inférence en entiers 8-bits (**Int8**). Utilise la *Quantization Aware Training*. | **Oui**. Standard actuel pour l'inférence sur microcontrôleurs (ex: TF Lite Micro). | ImageNet / COCO. | Perte minime (<1%) en passant de float32 à **int8**. |
#
# ## Références
#
# Les références complètes (format IEEE) pour les sources utilisées dans cette analyse :
#
# 1.  P. Warden, "Speech Commands: A Dataset for Limited-Vocabulary Speech Recognition," *arXiv preprint arXiv:1804.03209*, 2018.
# 2.  Y. Zhang, N. Suda, L. Lai, and V. Chandra, "Hello Edge: Keyword Spotting on Microcontrollers," *arXiv preprint arXiv:1711.07128*, 2017.
# 3.  A. G. Howard *et al.*, "MobileNets: Efficient Convolutional Neural Networks for Mobile Vision Applications," *arXiv preprint arXiv:1704.04861*, 2017.
# 4.  Y. Zhang *et al.*, "Towards End-to-End Speech Recognition with Deep Convolutional Neural Networks," *arXiv preprint arXiv:1701.02720*, 2017.
# 5.  S. Han, H. Mao, and W. J. Dally, "Deep Compression: Compressing Deep Neural Networks with Pruning, Trained Quantization and Huffman Coding," in *ICLR*, 2016.
# 6.  B. Jacob *et al.*, "Quantization and Training of Neural Networks for Efficient Integer-Arithmetic-Only Inference," in *CVPR*, 2018.
#
# # Synthèse et Analyse Critique
#
# Pour ce projet, le papier de Warden [1] est fondateur car il définit le format des données que nous manipulons (fichiers .wav de 1s), soulignant la difficulté de gérer les "faux positifs" (bruit de fond).
#
# Cependant, l'article le plus pertinent pour la partie "système embarqué" est "Hello Edge" [2]. Il démontre que les architectures classiques (DNN) sont trop gourmandes en mémoire pour des microcontrôleurs. Il propose l'architecture DS-CNN, directement inspirée des MobileNets [3] de Google.
#
# Bien que Howard et al. [3] travaillent sur de l'image (Vision), leur concept de Depthwise Separable Convolution est intéressante pour notre TP : il permet de réduire drastiquement la taille du modèle (ce que nous traiterons en fin de TP) en séparant le filtrage spatial et la combinaison des canaux. Enfin, Zhang et al. [4] confirment que les CNNs peuvent capturer les dépendances temporelles de la parole aussi bien que les RNNs, mais avec une parallélisation plus aisée, ce qui est un atout majeur pour l'inférence temps-réel sur matériel contraint.
#
# Pour aller plus loin que l'architecture DS-CNN, l'optimisation du modèle est nécéssaire. L'article de Han et al. [5] apparait incontournable dans le domaine car il théorise le pipeline de compression moderne : l'élagage (supprimer les connexions faibles), suivi du clustering (partage de poids dans le réseau) et de la quantification (compréssion des paramètres de float32 à int8).
#
# Cependant, pour une implémentation réelle sur microcontrôleur (comme celle visée dans ce projet), c'est l'approche de Jacob et al. [6] qui semble faire foi. Elle détaille comment simuler la quantification (int8) dès l'entraînement (Quantization Aware Training) pour éviter la chute de précision brutale lors du passage sur le hardware, un problème fréquent en KWS.

# %% [markdown]
# ## Preprocessing
#
# C'est la partie la plus importante du projet !! Même le modèle le plus performant de la terre ne pourra pas être précis sans des données d'entrées propres. De plus, il est important de réduire la quantité de données d'entrée (Décimation) afin de ne pas avoir un modèle trop lourd.
#
# <font color=" Darkblue"> **Tips:** Commencez par un preprocessing simple, et améliorez le lorsque les modèles seront en cours d'apprentissage. </font>
#
# Voici quelques sources qui pourront vous être utile pour faire votre code, en plus de l'état de l'art précedemment fait:
# - https://medium.com/enjoy-algorithm/pre-processing-of-time-series-data-c50f8a3e7a98
# - https://monkeylearn.com/blog/data-preprocessing/
# - https://machinelearningmastery.com/machine-learning-data-transforms-for-time-series-forecasting/
# - https://haythamfayek.com/2016/04/21/speech-processing-for-machine-learning.html (pour les plus expérimenté d'entre vous)
#
# &nbsp;
#
# <font color=" Darkred"> Progression du TP après cette partie (environ 3h): </font>
# ![56%](https://progress-bar.dev/56)

# %% [markdown]
# ### Zone d'expérimentation
#
# Ici vous êtes libre d'essayer des choses, les visualiser, avoir un regard critique sur la solution que vous décidez de prendre. Utilisez autant de cases de codes et de textes.

# %% [markdown]
#     De par nos expérience passé en traitement automatique de la parole et notre étude des articles et méthodes déjà mises en place sur ce sujet, nous avons décidé de travailler avec des images spectrales de nos signaux. Dans cette optique il nous parrait intéressant d'en comparé 3:
#         - Le spectrogramme
#         - Les filtres de Mel
#         - Les coeficient MFCC
#
# La case de codes suivantes présente l'évantail des focntions que nous avons jugé nécéssaires pour réaliser ce traitement qui peut se décompser dans les étapes suivantes:
#
# **Normalisation de l'audio → Pré-accentuation → framing → Fenêtrage → FFT → Banc de filtres Mel → Calcul des MFCC → Normalisation des coefficients.**

# %%
# Fonctions de prétraitement audio (inspirées de la documentation de l'état de l'art)

import numpy as np
from scipy.fftpack import dct
from sklearn.preprocessing import MinMaxScaler

def To_normalize(signal, eps=1e-8):
    """Fonction de normalisation d'enregistrement audio ([-1, 1]) par max absolu."""
    signal = signal.astype(np.float32)
    max_abs = np.max(np.abs(signal)) + eps
    return signal / max_abs


def pre_emphasis_filter(signal, coefficient=0.97):
    """"Filtre numérique passe haut (dérivateur) amplififiant les hautes fréquence, fc = 100Hz (valeur classique)"""
    return signal - coefficient * np.roll(signal, 1)


def framing(signal, frame_length, frame_step, sample_rate):
    """Découpe le signal en trames de durée fixe (fenêtrage temporel)."""
    signal_length = len(signal)
    frame_length = int(round(frame_length * sample_rate))
    frame_step = int(round(frame_step * sample_rate))

    num_frames = int(np.floor((signal_length - frame_length) / frame_step)) + 1
    pad_signal_length = num_frames * frame_step + frame_length
    z = np.zeros((pad_signal_length - signal_length))
    pad_signal = np.append(signal, z)

    indices = np.tile(np.arange(0, frame_length), (num_frames, 1)) + \
              np.tile(np.arange(0, num_frames * frame_step, frame_step), (frame_length, 1)).T

    frames = pad_signal[indices.astype(np.int32, copy=False)]
    return frames


def window_hamming(frames):
    """Applique une fenêtre de Hamming pour lisser les trames."""
    frame_length = len(frames[0])
    windowed_frames = np.zeros(frames.shape)
    for i in range(len(frames)):
        windowed_frames[i] = frames[i] * np.hamming(frame_length)
    return windowed_frames


def fft(windowed_frames, NFFT=512):
    """Calcule le spectre de puissance de chaque trame (FFT)."""
    mag_frames = np.absolute(np.fft.rfft(windowed_frames, NFFT))
    pow_frames = ((1.0 / NFFT) * (mag_frames ** 2))
    return pow_frames


def filter_bank(pow_frames, sample_rate, NFFT=512, nfilt=40):
    """Applique un banc de filtres de Mel pour regrouper les fréquences."""
    low_freq_mel = 0
    high_freq_mel = 2595 * np.log10(1 + (sample_rate / 2) / 700)
    mel_points = np.linspace(low_freq_mel, high_freq_mel, nfilt + 2)
    hz_points = 700 * (10**(mel_points / 2595) - 1)
    bin = np.floor((NFFT + 1) * hz_points / sample_rate)

    fbank = np.zeros((nfilt, int(np.floor(NFFT / 2 + 1))))
    for m in range(1, nfilt + 1):
        f_m_minus = int(bin[m - 1])
        f_m = int(bin[m])
        f_m_plus = int(bin[m + 1])

        for k in range(f_m_minus, f_m):
            fbank[m - 1, k] = (k - bin[m - 1]) / (bin[m] - bin[m - 1])
        for k in range(f_m, f_m_plus):
            fbank[m - 1, k] = (bin[m + 1] - k) / (bin[m + 1] - bin[m])

    filter_banks = np.dot(pow_frames, fbank.T)
    filter_banks = np.where(filter_banks == 0, np.finfo(float).eps, filter_banks)
    filter_banks = 20 * np.log10(filter_banks)
    return filter_banks


def mfcc_coeffs(filter_banks, num_ceps=12, ceplifter=22):
    """Extrait les coefficients cepstraux MFCC à partir des filtres de Mel."""
    mfcc = dct(filter_banks, type=2, axis=1, norm='ortho')[:, 1:(num_ceps + 1)]
    (nframes, ncoeff) = mfcc.shape
    n = np.arange(ncoeff)
    lift = 1 + (ceplifter / 2) * np.sin(np.pi * n / ceplifter)
    mfcc *= lift
    return mfcc


def Mean_Norm(Data):
    """Centre les données (MFCC ou filter banks) autour de leur moyenne."""
    Mean_Data = np.zeros(Data.shape)
    for i in range(Data.shape[0]):
        Mean_Data[i] = Data[i] - np.mean(Data[i])
    return Mean_Data

# %% [markdown]
#     Ces fonctions vont maintenant nous permettre de visualiser les différences entres les 3 transformations que nous voulons réalisés et surtout leur impact sur l'entrainement du modèle.

# %%
import librosa
import librosa.display

# Visualisation de l'effet des fonctions précédentes

# Chemin vers les données
label = os.listdir(train_data_path)[1:]  # On ignore le premier fichier

# Sélection aléatoire d'un fichier wav
Random_Label = np.random.choice(label, size=len(label), replace=False)
wav_files_path = os.path.join(train_data_path, Random_Labels[0])
random_wav = np.random.choice(os.listdir(wav_files_path))  # un fichier wav aléatoire
sr, signal = wavfile.read(os.path.join(wav_files_path, random_wav))

# Application des transformations
signal = To_normalize(signal)                                                   # Normalisation
emphasized_signal = pre_emphasis_filter(signal)                                 # FIltrage passe-haut
frames = framing(signal, frame_length=0.025, frame_step=0.01, sample_rate=sr)   # Découpage en fenêtres de 25ms
windowed_frames = window_hamming(frames)                                        # Application de la fenêtre de Hamming
pow_frames = fft(windowed_frames)                                               # FFT
log_spectrogram = 10 * np.log10(pow_frames.T + 1e-8)                            # Mise sous échelle logarithmique pour la visualisation
filter_banks = filter_bank(pow_frames, sample_rate = sr)                        # Bancs de filtres Mel
filter_banks = Mean_Norm(filter_banks)                                          # Normalisation des filter de Mel
mfcc = mfcc_coeffs(filter_banks, num_ceps=12, ceplifter=22)                     # MFCC
mfcc = Mean_Norm(mfcc)                                                          # Normalisation des MFCC

# Débogage
print(f'Taille du signal :{signal.shape}')
print(f'Taille du signal filtré :{emphasized_signal.shape}')
print(f'Taille des fenêtres :{frames.shape}')
print(f'Taille des fenêtres après hamming :{windowed_frames.shape}')
print(f'Taille des fenêtres après fft :{pow_frames.shape}')
print(f'Taille du spectrogramme :{log_spectrogram.shape}')
print(f'Taille des filter banks :{filter_banks.shape}')
print(f'Taille des MFCCs :{mfcc.shape}')

### Affichage des figures

# Signaux Temporels
plt.figure(figsize=(18, 6))
plt.subplot(1, 3, 1)
plt.plot(np.arange(len(signal))/sr,signal)
plt.xlabel("Temps (s)")
plt.ylabel("Amplitude")
plt.grid()
plt.title('Données brutes')

plt.subplot(1, 3, 2)
plt.plot(np.arange(len(emphasized_signal))/sr,emphasized_signal)
plt.xlabel("Temps (s)")
plt.ylabel("Amplitude")
plt.grid()
plt.title('Données filtrées')

plt.subplot(1, 3, 3)
plt.plot(np.arange(len(windowed_frames)),np.mean(windowed_frames, axis=1))
plt.xlabel("Temps (s)")
plt.ylabel("Amplitude")
plt.title('Données après hamming')
plt.grid()

# Signaux Fréquentiels
plt.figure(figsize=(18, 6))
plt.subplot(1, 3, 1)
librosa.display.specshow(log_spectrogram,
                         sr=sr,
                         hop_length=int(0.01 * sr),
                         x_axis='time',
                         y_axis='linear',
                         cmap='turbo')
plt.title('Spectrogramme (FFT par trame)')
plt.xlabel("Temps (s)")
plt.ylabel("Fréquence (Hz)")

plt.subplot(1, 3, 2)
librosa.display.specshow(filter_banks.T, sr=sr, hop_length=int(0.01*sr),
                         x_axis='time', y_axis='mel', cmap='turbo')
plt.xlabel("Temps (s)")
plt.title("Bancs de filtres Mel (énergies en dB)")

plt.subplot(1,3,3)
librosa.display.specshow(mfcc.T, sr=sr, hop_length=int(0.01*sr),
                         x_axis='time', cmap='turbo')
plt.xlabel("Temps (s)")
plt.title("MFCC (Coefficients Cepstraux)")

plt.tight_layout()
plt.show()
# Out:
# Taille du signal :(16000,)
# Taille du signal filtré :(16000,)
# Taille des fenêtres :(98, 400)
# Taille des fenêtres après hamming :(98, 400)
# Taille des fenêtres après fft :(98, 257)
# Taille du spectrogramme :(257, 98)
# Taille des filter banks :(98, 40)
# Taille des MFCCs :(98, 12)

# %% [markdown]
# L'objectif de ce prétraitement étant de réduire la dimensionnalité du signal brut tout en conservant les caractéristiques pertinentes pour la parole. Nous avons choisie de calculer:
#
#     Spectrogramme (STFT) : Représentation Temps-Fréquence brute. Bien qu'exhaustive, elle génère une matrice de très grande dimension contenant beaucoup d'informations redondantes ou inaudibles pour l'homme (hautes fréquences linéaires). Elle est souvent trop coûteuse en mémoire pour un système embarqué.
#
#     Mel-Filterbanks (Log-Mel) : Cette méthode applique des filtres triangulaires selon l'échelle de Mel (logarithmique), imitant l'audition humaine. C'est souvent le meilleur choix pour les CNN, car elle réduit drastiquement la taille des données tout en conservant la corrélation locale entre les fréquences (structure visuelle du son), ce que les convolutions exploitent efficacement.
#
#     MFCC (Mel Frequency Cepstral Coefficients) : C'est l'étape suivante, ajoutant une transformation en cosinus discret (DCT) aux Mel-Filterbanks. Historiquement incontournable pour les modèles statistiques (GMM/HMM) car elle décorréle les données, elle est parfois moins performante pour les CNN profonds car la DCT détruit la localité fréquentielle (les relations de voisinage vertical dans l'image).
#
# > **Conclusion pour le projet : Dans un contexte de ressources contraintes (microcontrôleur, NPU, FPGA potentiellement), les MFCC restent pertinents pour leur extrême compacité (40 voire 12 coefficients suffisent), mais les Mel-Filterbanks offrent généralement une meilleure précision avec les réseaux de neurones modernes (Deep Learning) en préservant la texture du signal. Pour la suite du TP on se concentrera sur une utilisation des MFCC avec 12 coeficients car la taille des données à acquérir pour l'inférence.**

# %% [markdown]
# ### Fonction de preprocessing
#
# > **On réalise donc une fonction de preprocessing à partir des fonctions déjà définies précédemements, pour réaliser la chaîne de traitement en vue d'entrainer notre réseau.**
#
# Cette fonction convertit le signal audio brut (1D) en "images" acoustiques (2D) adaptées aux CNNs.
#
# 1. Conditionnement du signal :
#
#     Pré-accentuation : Filtre passe-haut qui compense la perte d'énergie naturelle des hautes fréquences de la voix.
#
#     Fenêtrage (Hamming) : Découpe le signal en trames de 25ms avec recouvrement pour minimiser les artefacts de bord avant la FFT.
#
#
# 2. Extraction des caractéristiques (au choix) :
#
#    spectrogramme : Représentation brute. Souvent trop volumineuse et bruitée pour l'embarqué.
#
#     mel (Log-Mel) : Le choix optimal pour les CNN. Réduit la dimension (40 filtres) en imitant l'oreille humaine tout en préservant la structure visuelle (corrélations locales).
#
#     mfccs : Ajoute une DCT (Cosines Transform) aux Mel. Très compact, mais la DCT "casse" la localité spatiale que les convolutions cherchent à exploiter.
#
#
# 3. Mise à l'échelle :
#
#     La division finale par max_abs force les valeurs dans l'intervalle [-1, 1]. C'est une étape critique pour éviter l'explosion des gradients lors de l'entraînement du réseau de neurones.

# %%
def preprocessing(inputs,
                  type='mfccs',
                  sample_rate=16000,
                  frame_length=0.025,
                  frame_step=0.01,
                  NFFT=512,
                  nfilt=40,
                  num_ceps=12,
                  ceplifter=22):
    """
    inputs : array de forme (nb_fichiers, 16000) car échantillons à 16kHz
    type   : 'mfccs' | 'spectrogramme' | 'mel' pour choisir le type de features à extraire
    Returns : array de forme (nb_fichiers, nb_features, nb_frames)
    """
    clean_inputs = []
    eps = 1e-8

    for i in range(inputs.shape[0]):
        # Normalisation par enregistrement
        x = To_normalize(inputs[i])               # (16000,)

        #  Pré-accentuation
        x = pre_emphasis_filter(x)                # (16000,)

        #  Framing + fenêtre de Hamming
        frames = framing(x,
                         frame_length=frame_length,
                         frame_step=frame_step,
                         sample_rate=sample_rate)  
        windowed_frames = window_hamming(frames)

        #  FFT => spectre de puissance
        pow_frames = fft(windowed_frames, NFFT=NFFT)

        # Extraction des features selon le type demandé
        
        if type == 'mfccs':
            # Banc de filtres Mel
            filter_banks = filter_bank(pow_frames,
                                       sample_rate=sample_rate,
                                       NFFT=NFFT,
                                       nfilt=nfilt)
            filter_banks = Mean_Norm(filter_banks)

            # MFCC
            mfcc = mfcc_coeffs(filter_banks,
                               num_ceps=num_ceps,
                               ceplifter=ceplifter)
            mfcc = Mean_Norm(mfcc)

            max_abs = max(np.max(np.abs(mfcc)), eps)
            clean_inputs.append(mfcc / max_abs)

        elif type == 'spectrogramme':
            # Spectrogramme log
            log_spectrogram = 10 * np.log10(
                np.clip(pow_frames.T, a_min=eps, a_max=None)
            )
            max_abs = max(np.max(np.abs(log_spectrogram)), eps)
            clean_inputs.append(log_spectrogram / max_abs)

        elif type == 'mel':
            # Banc de filtres Mel sans DCT
            filter_banks = filter_bank(pow_frames,
                                       sample_rate=sample_rate,
                                       NFFT=NFFT,
                                       nfilt=nfilt)
            filter_banks = Mean_Norm(filter_banks)
            max_abs = max(np.max(np.abs(filter_banks)), eps)
            clean_inputs.append(filter_banks / max_abs)

        else:
            raise ValueError("type doit être 'mfccs', 'spectrogramme' ou 'mel'.")

    return np.array(clean_inputs, dtype=np.float32)

# %%
# Test de la fonction de prétraitement
print(f'Input before preprocessing: {waves.shape}')
processed_waves = preprocessing(waves)
print(f'Input after preprocessing: {processed_waves.shape}')
# Out:
# Input before preprocessing: (67727, 16000)
# Input after preprocessing: (67727, 98, 12)

# %% [markdown]
# > **Nos données peuvent donc maintenant être utilisé pour réaliser un entrainement de notre CNN avec des features simples et compacts, idéal dans un objectif d'embarquabilité.**

# %% [markdown]
# ## Apprentissage du Modèle
# On y est, il est temps de créer un modèle. Pour cela, il vous sera imposé d'utiliser un réseau de convolution 1D [2] (https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv1D). Nous préconisons l'utilisation de Tensorflow mais vous êtes libre d'utiliser d'autres librairies comme Pytorch.
#
# &nbsp;
#
# <font color=" Darkred"> Progression du TP après cette partie (environ 3h): </font>
# ![75%](https://progress-bar.dev/75)

# %% [markdown]
# ### Train set, Validation set
#
# Avant d'entraîner votre modèle, pensez à séparer vos données d'entraînements et vos données de validations. Puis, pensez à créer des batchs pour correspondre à l'entrée de votre modèle.
#
# Plus d'infos ici:
#  - https://www.tensorflow.org/datasets/splits?hl=fr
#  - https://towardsdatascience.com/how-to-split-a-dataframe-into-train-and-test-set-with-python-eaa1630ca7b3
#  - https://www.tensorflow.org/tutorials/customization/custom_training_walkthrough?hl=fr
#
#  <font color=" Darkblue"> **Tips:** Pensez à bien mélanger vos données avant de les séparer. </font>
#
#  <font color="orange"> **Note anti-plagiat:** Le mélange doit avoir une random seed fixe et différente pour chaque groupe. </font>

# %% [markdown]
# On as choisie ici d'utiliser une méthode cross-validation des K folds que nous avons étudié l'an dernier et que vous nous avez rapellé dans la suite du projet, ce qui nous pousse à diviser le data set dans cette objectif ici.

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split, StratifiedKFold

# --- 1. CONFIGURATION & DONNÉES ---
tf.random.set_seed(42)
NUM_CLASSES = 12
INPUT_SHAPE = (98, 12, 1) # Frames, Coeffs, Channels

# Préparation données
X_data = processed_waves
Y_data = labels['label_id'].values

# Isolation du Test Set (15%) - Juge de paix final
X_cv, X_test, y_cv, y_test = train_test_split(X_data, Y_data, test_size=0.15, random_state=42, stratify=Y_data)

print(f"Données pour Cross-Validation (K-Fold) : {X_cv.shape[0]}")
print(f"Données de Test (Final)                : {X_test.shape[0]}")
# Out:
# 2025-12-17 11:07:37.372601: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-17 11:07:37.751065: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765966057.889695   57985 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765966057.927528   57985 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-12-17 11:07:38.282207: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Données pour Cross-Validation (K-Fold) : 57567
# Données de Test (Final)                : 10160

# %% [markdown]
# ### Baseline
#
# La baseline est importante afin de connaître le seuil où le modèle est performant. A vous de trouver la meilleure baseline et d'expliquer votre choix.
#
# Plus d'infos ici:
# https://towardsdatascience.com/calculating-a-baseline-accuracy-for-a-classification-model-a4b342ceb88f
#
# > **La baseline de notre modèle doit être fixé de sorte a dépassé le Zero Rate, c'est à dire la fréquence de la classe la plus fréquente. On créer la fonction qui nous permets de calculer ce score.**

# %%
def calculate_zeroR_with_pandas(labels_series):
    """
    Calcule la précision du ZeroR à partir de nos données.
    """
    if labels_series.empty:
        return 0.0, None, None

    # 1. Compter la fréquence de chaque label (plus simple avec value_counts)
    # value_counts() trie déjà par fréquence (décroissant)
    label_counts = labels_series.value_counts()
    
    # 2. Identifier la classe majoritaire
    major_label_name = label_counts.index[0]
    major_label_count = label_counts.iloc[0]
    
    # 3. Calculer le taux de précision
    total_samples = len(labels_series)
    zeroR_accuracy = major_label_count / total_samples
    
    return zeroR_accuracy, major_label_name

# %% [markdown]
# Boucle pour calculer la baseline à partir datasframe pandas

# %%
# 1. Importer les données
waves, labels_df = import_data_as_dataframe(max_files_per_label=30000, data_path=train_data_path)

print(f"Total d'échantillons importés: {len(labels_df)}")
print("-" * 30)
print("Aperçu du DataFrame des labels :")
print(labels_df.head())
print("-" * 30)

# 2. Calculer le ZeroR
# Nous utilisons la colonne 'label_name' pour des résultats lisibles
accuracy, major_label = calculate_zeroR_with_pandas(labels_df['label_name'])

# 3. Afficher les résultats
print(f"Classe majoritaire (ZeroR): '{major_label}'")
print(f"Précision du ZeroR (Baseline) : {accuracy:.4f} (soit {accuracy*100:.2f}%)")
# Out:
# /tmp/ipykernel_57985/1334860832.py:84: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sr, samples = wavfile.read(file_path)
# Total d'échantillons importés: 67727
# ------------------------------
# Aperçu du DataFrame des labels :
#    label_id label_name
# 0         5      right
# 1        11    unknown
# 2        11    unknown
# 3         8       stop
# 4        11    unknown
# ------------------------------
# Classe majoritaire (ZeroR): 'unknown'
# Précision du ZeroR (Baseline) : 0.6060 (soit 60.60%)

# %% [markdown]
# On as donc une baseline de 0.67 à dépassé d'après le ZeroR.

# %% [markdown]
# ### Modèle
#
# Vous devez créer une fonction permettant de générer le modèle. Celle-ci doit pouvoir être modifiable en fonction des Hyperparamètres mis en entrée.
#
#  <font color="red"> **ATTENTION:** Une limite de 150 000 paramètres est imposés. </font>
#
# Justification de vos choix (Choix des paramètres modifiables, fonction d'activations, nombres de couches, regularizers, ...) :
# > **Pour répondre aux contraintes de déploiement sur microcontrôleur (mémoire limitée, faible puissance de calcul), nous avons opté pour une architecture DS-CNN (Depthwise Separable Convolutional Neural Network). Ce choix s'appuie sur les résultats de Zhang et al. (2017) [2], qui démontrent que cette architecture offre le meilleur compromis précision/ressources pour le Keyword Spotting.**
#
# Nous utilisons le framework Optuna pour explorer l'espace des hyperparamètres, avec une stratégie multi-objectifs visant à maximiser la précision (val_acc) tout en minimisant la taille du modèle (size).
# 1. Choix Structurants (Architecture Fixe)
#
#     Convolutions Séparables (SeparableConv2D) : Contrairement aux CNN classiques, nous utilisons la technique des MobileNets [Howard et al., 2017]. Elle décompose la convolution en deux étapes (Filtrage spatial Depthwise + Combinaison Pointwise), réduisant drastiquement les opérations (MACs) pour permettre l'inférence temps-réel.
#
#     Global Average Pooling (GAP) : Nous remplaçons les couches Flatten massives par un GlobalAveragePooling2D [Lin et al., 2013]. Cela réduit la sortie des convolutions à un simple vecteur, supprimant des millions de paramètres inutiles et limitant le risque d'overfitting.
#
#     Taille de Noyau Fixée (3×3) : Nous avons exclu la taille du noyau (kernell) de l'espace de recherche, la fixant à 3. C'est un standard de l'état de l'art (VGG, MobileNet) qui offre une granularité suffisante pour capter les formants audio sans le surcoût quadratique des noyaux 5×5 ou 7×7.
#
# 2. Espace de Recherche Optuna (Paramètres Variables)
#
# Les plages de valeurs définies dans objective(trial) répondent à une logique matérielle et statistique :
#
#     Filtres et Neurones (Puissances de 2) : Nous testons [16, 32, 64, 128] pour conv_filters, ds_filters et dense_units.
#
#         Justification : L'utilisation de puissances de 2 est cruciale en embarqué pour optimiser l'alignement mémoire et l'utilisation des registres CPU/SIMD.
#
#         Compromis : La valeur 16 vise l'ultra-basse consommation (modèle < 10ko), tandis que 128 cherche à maximiser la capacité d'abstraction du réseau au prix d'une empreinte mémoire plus lourde.
#
#     Fonction d'Activation :
#
#         ReLU : Standard, calcul gratuit (max(0,x)), favorise la sparsité (zéros) utile pour la compression.
#
#         Leaky ReLU : Testée pour éviter le problème des "neurones morts" (dead neurons) si le réseau est trop compressé, au prix d'une légère opération de multiplication supplémentaire.
#
#     Régularisation (Dropout) : Nous faisons varier le dropout_rate entre 0.1 et 0.5. Avec un dataset réduit (~3000 échantillons par classe), un taux élevé (0.5) est souvent nécessaire pour forcer le réseau à généraliser, mais un taux trop bas (0.1) permet une convergence plus rapide si le modèle est petit (sous-paramétré).
#
#     Batch Size : Le choix [16, 32, 64, 128] influe sur la stabilité du gradient et l'occupation RAM durant l'apprentissage. Sur un petit dataset, un batch size plus petit (16/32) peut aider à sortir des minimums locaux grâce au bruit introduit dans le gradient.
#
# 3. Objectif : Front de Pareto
#
# Notre optimisation ne cherche pas uniquement la meilleure accuracy. En demandant à Optuna de maximize(val_acc) ET minimize(size), nous cherchons à établir un Front de Pareto. Cela nous permettra in fine de sélectionner le modèle le plus précis pour une taille donnée (ex: le meilleur modèle qui tient dans 30ko).

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras import regularizers

# %%
def total_param(model):
  """Calcule et affiche le nombre total de paramètres du modèle."""
  total_params = model.count_params()
  print(f"Nombre de poids du modèle: {total_params:,}")
  return total_params


def create_model(param, input_shape, num_classes):
  """
  Crée un modèle DS-CNN (Depthwise Separable CNN) pour une entrée 2D (ex: MFCCs).
  Les hyperparamètres sont contrôlés par le dictionnaire 'param'.
  """
  model = models.Sequential()


  # taille du kernel (tombe sur 3 si clé absente)
  k = param.get('kernell', 3)

  # Récupération du taux de régularisation (valeur par défaut 0.0001)
  l2_rate = param.get('l2_rate', 1e-4) 
  reg = regularizers.l2(l2_rate)

  # --- Couche d'Entrée ---
  model.add(layers.Input(shape=input_shape))

  # --- Bloc Conv2D Standard (pour l'extraction initiale) ---
  model.add(layers.Conv2D(param['conv_filters'], (k, k), 
                           strides=(1, 1), 
                           padding='same', 
                           activation=param['activation']))
  model.add(layers.BatchNormalization())

  # --- Bloc DS-CNN 1 --- couche clé : SeparableConv2D
  model.add(layers.SeparableConv2D(param['ds_filters_1'], (k, k), 
                                    padding='same', 
                                    activation=param['activation']))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))

  # --- Bloc DS-CNN 2 ---
  model.add(layers.SeparableConv2D(param['ds_filters_2'], (k, k), 
                                    padding='same', 
                                    activation=param['activation']))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))

  # --- Tête de Classification ---
  model.add(layers.GlobalAveragePooling2D())
  
  model.add(layers.Dense(param['dense_units'], activation=param['activation']))
  model.add(layers.Dropout(param['dropout_rate']))
  
  # Couche de sortie finale
  model.add(layers.Dense(num_classes, activation='softmax'))
  
  return model
 
# PARAMÈTRES pour DS-CNN
param = {
    'activation'    : 'relu',
    'conv_filters'  : 32,    # Filtres pour la première couche Conv2D
    'ds_filters_1'  : 64,    # Filtres pour le premier bloc DS-CNN
    'ds_filters_2'  : 64,    # Filtres pour le second bloc DS-CNN
    'dense_units'   : 32,    # Neurones dans la couche dense finale
    'dropout_rate'  : 0.5,   # Taux de dropout pour la régularisation
    'kernell'       : 3,     # Taille des kernels pour la convolution 
    'l2_rate'       : 0.001  #Force de la régularisation (1e-3 est classique)
}

# Remarque : vos entrées MFCC pré-traitées ont la forme (98, 12, 1) dans les batches.
# Adapter INPUT_SHAPE pour correspondre aux données (frames, coeffs, channels).
INPUT_SHAPE = (98, 12, 1)  # 98 timesteps, 12 coefficients MFCC, 1 canal
NUM_CLASSES= 12

model = create_model(param, INPUT_SHAPE, NUM_CLASSES)

model.summary()
# Out:
# I0000 00:00:1765966064.283742   57985 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5582 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 98, 12, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 98, 12, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d                │ (None, 98, 12, 64)     │         2,400 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 98, 12, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 49, 6, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d_1              │ (None, 49, 6, 64)      │         4,736 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 49, 6, 64)      │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 24, 3, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 12)             │           396 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,572 (41.30 KB)
#  Trainable params: 10,252 (40.05 KB)
#  Non-trainable params: 320 (1.25 KB)

# %% [markdown]
# ### Fonction d'entraînement
#
# Cette fonction doit prendre un modèle en entrée et l'entrainer grâce au Train set. Puis, retourner les performances obtenues avec le Validation set.
#
# Pour les plus expérimentés d'entre vous: Vous pouvez réaliser une cross validation [[2]](https://datascientest.com/cross-validation).
#
# Justification de vos choix (Choix des paramètres modifiables, optimizer, nombres d'epoch, learning rate, ...) :
# > Pour garantir la fiabilité de notre solution embarquée, nous avons procédé en deux étapes :
#
# 1.  **Validation Scientifique (Cross-Validation K-Fold, $K=5$) :**
#     * **Objectif :** Vérifier que la performance n'est pas due au hasard d'un bon découpage des données.
#     * **Résultats :** Nous avons obtenu une précision moyenne de **89.31%** avec un écart-type très faible de **$\pm 0.66\%$**.
#     * **Conclusion :** Cette faible variance valide la robustesse intrinsèque de l'architecture DS-CNN. Le modèle est stable et généralise bien, ce qui nous autorise à repasser sur un entraînement simple pour la phase finale.
#
# 2.  **Optimisation Industrielle (Split Train/Test + Régularisation) :**
#     * **Objectif :** Produire le modèle unique qui sera déployé, en lissant les courbes d'apprentissage pour éviter les pics d'instabilité observés précédemment.
#     * **Moyens :**
#         * Réintroduction d'un split classique (80% Train / 10% Val / 10% Test) pour réduire le temps de calcul.
#         * Ajout d'une **régularisation L2** ($\lambda=0.001$) sur les poids pour contraindre le modèle.
#         * Correction de l'optimiseur pour qu'il prenne réellement en compte le *Learning Rate Scheduler*.
#
# ---
#
# ## Conclusion sur le Modèle DS-CNN
#
# ### Synthèse des Performances
# Notre modèle basé sur l'architecture **DS-CNN (Depthwise Separable CNN)** a démontré d'excellentes performances pour la tâche de *Keyword Spotting* sur microcontrôleur.
# * **Précision Finale :** Le modèle atteint une accuracy de **~89.8%** sur le jeu de test (données jamais vues), bien au-delà de la baseline fixée à 40% (classe majoritaire).
# * **Stabilité :** La validation croisée a confirmé que le modèle ne souffre pas de biais majeur lié à la séparation des données.
#
# ### Analyse de la Convergence
# L'ajout de la **régularisation L2** combinée à un **Learning Rate Scheduler** (décroissance exponentielle) a permis de :
# * Lisser les courbes de perte (*loss*), réduisant le fossé entre l'entraînement et la validation.
# * Prévenir le sur-apprentissage (overfitting) inhérent aux petits datasets (~3000 échantillons).
# * Maintenir une précision élevée tout en contraignant les poids, ce qui est bénéfique pour la future étape de quantification.
#
# ### Prochaine Étape : Déploiement Embarqué
# Ce modèle, compact par design (grâce aux convolutions séparables) et performant, est maintenant prêt pour la chaîne de déploiement. Les prochaines étapes consisteront à :
# 1.  Figer le graphe TensorFlow.
# 2.  Le convertir en **TensorFlow Lite** (TFLite).
# 3.  Appliquer une **Quantification (Float32 $\to$ Int8)** pour réduire sa taille (objectif < 20 ko) sans dégrader significativement cette précision de ~90%.

# %%
from sklearn.model_selection import StratifiedKFold

def compile_and_fit(model, train_ds, val_ds, train_params, verbose=0):
    
    # 1. Callbacks (Sécurité)
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=10, mode='min', restore_best_weights=True
    )

    # 2. Scheduler (Vitesse variable)
    # Pour un finetuning ou L2, 1e-3 est souvent plus stable.
    lr_schedule = tf.optimizers.schedules.ExponentialDecay(
         initial_learning_rate=0.001, 
         decay_steps=1000,           
         decay_rate=0.95)            

    # 3. Optimiseurqui utilise le scheduler
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

    # 4. Compilation
    model.compile(loss='categorical_crossentropy',
                optimizer=optimizer,  # <--- INDISPENSABLE
                metrics=['accuracy',
                tf.keras.metrics.Precision(name='precision'),
                tf.keras.metrics.Recall(name='recall')])

    # 5. Entraînement
    history = model.fit(
        train_ds, 
        epochs=train_params['max_epochs'],
        validation_data=val_ds,
        callbacks=[early_stopping], 
        verbose=1
    )

    scores = model.evaluate(val_ds, verbose=0)
    return scores, model, history

def run_kfold_cv(model_builder, X, y, model_params, train_params, k_folds=5, batch_size=64):
    skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)
    fold_accuracies = []
    
    print(f"\n--- Démarrage Cross-Validation ({k_folds} folds) ---")
    
    for fold, (train_idx, val_idx) in enumerate(skf.split(X, y)):
        # Découpage
        X_train_f, X_val_f = X[train_idx], X[val_idx]
        y_train_f, y_val_f = y[train_idx], y[val_idx]
        
        # Encodage & Reshape
        y_train_enc = tf.keras.utils.to_categorical(y_train_f, num_classes=NUM_CLASSES)
        y_val_enc = tf.keras.utils.to_categorical(y_val_f, num_classes=NUM_CLASSES)
        X_train_f = np.expand_dims(X_train_f, axis=-1)
        X_val_f = np.expand_dims(X_val_f, axis=-1)
        
        # Datasets
        train_ds = tf.data.Dataset.from_tensor_slices((X_train_f, y_train_enc)).batch(batch_size, drop_remainder=True)
        val_ds = tf.data.Dataset.from_tensor_slices((X_val_f, y_val_enc)).batch(batch_size)
        
        # Nouveau modèle vierge
        model = model_builder(model_params, INPUT_SHAPE, NUM_CLASSES)
        
        # Entraînement
        scores, _, _ = compile_and_fit(model, train_ds, val_ds, train_params, verbose=0)
        
        print(f"Fold {fold+1}: Accuracy = {scores[1]:.2%}")
        fold_accuracies.append(scores[1])

    print(f">>> Moyenne : {np.mean(fold_accuracies):.2%} (+/- {np.std(fold_accuracies):.2%})")
    return np.mean(fold_accuracies)


train_param = {
    # Exemple de paramètres à modifier
    'max_epochs' : 100, # On fixe max_epochs haut et utilise early stopping 
    'BATCH_SIZE' : 64
}

def plot_training_history(history):
    """
    Trace les courbes d'apprentissage pour la perte, l'accuracy, la précision
    et le rappel (training vs validation).
    """

    # Données de l'historique
    history_data = history.history

    # Noms des métriques
    loss = history_data['loss']
    val_loss = history_data['val_loss']
    accuracy = history_data['accuracy']
    val_accuracy = history_data['val_accuracy']
    precision = history_data['precision']
    val_precision = history_data['val_precision']
    recall = history_data['recall']
    val_recall = history_data['val_recall']

    epochs = range(1, len(accuracy) + 1)

    # --- Plot 1: Perte (Loss) ---
    plt.figure(figsize=(14, 7))
    plt.subplot(1, 2, 1) # Grille 1x2, premier graphique
    plt.plot(epochs, loss, 'bo-', label='Perte (Entraînement)')
    plt.plot(epochs, val_loss, 'r*-', label='Perte (Validation)')
    plt.title('Courbe de Perte (Loss)')
    plt.xlabel('Époques')
    plt.ylabel('Perte')
    plt.legend()
    plt.grid(True)

    # --- Plot 2: Précision (Accuracy) ---
    plt.subplot(1, 2, 2) # Grille 1x2, deuxième graphique
    plt.plot(epochs, accuracy, 'bo-', label='Accuracy, esttraînement)')
    plt.plot(epochs, val_accuracy, 'r*-', label='Accuracy (Validation)')
    plt.title('Courbe de Précision (Accuracy)')
    plt.xlabel('Époques')
    plt.ylabel('Précision')
    plt.legend()
    plt.grid(True)

    plt.tight_layout() # Ajuste l'espacement
    plt.show() # Affiche les deux premiers graphiques

    # --- Plot 3: Précision (Precision) vs Rappel (Recall) ---
    plt.figure(figsize=(14, 7))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, precision, 'bo-', label='Précision (Entraînement)')
    plt.plot(epochs, val_precision, 'r*-', label='Précision (Validation)')
    plt.title('Courbe de Précision (Precision)')
    plt.xlabel('Époques')
    plt.ylabel('Précision')
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(epochs, recall, 'bo-', label='Rappel (Entraînement)')
    plt.plot(epochs, val_recall, 'r*-', label='Rappel (Validation)')
    plt.title('Courbe de Rappel (Recall)')
    plt.xlabel('Époques')
    plt.ylabel('Rappel')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show() # Affiche les deux derniers graphiques

# %%
# On lancer la Cross-Validation
run_kfold_cv(create_model, X_cv, y_cv, param, train_param, k_folds=5)

# Entraînement FINAL sur tout X_cv

print("\n--- Entraînement Final sur tout X_cv ---")

# Préparation Test Set final
y_test_enc = tf.keras.utils.to_categorical(y_test, NUM_CLASSES)
test_ds = tf.data.Dataset.from_tensor_slices((np.expand_dims(X_test, -1), y_test_enc)).batch(64)

# Préparation Train Set final (Tout X_cv)
y_cv_enc = tf.keras.utils.to_categorical(y_cv, NUM_CLASSES)
full_train_ds = tf.data.Dataset.from_tensor_slices((np.expand_dims(X_cv, -1), y_cv_enc)).shuffle(2000).batch(64)

# Entraînement
final_model = create_model(param, INPUT_SHAPE, NUM_CLASSES)
scores, final_model, history = compile_and_fit(final_model, full_train_ds, test_ds, train_param, verbose=1)

print(f"Score Test Set Final : {scores[1]:.2%}")
# Out:
# --- Démarrage Cross-Validation (5 folds) ---
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1765966066.406326   58138 service.cc:148] XLA service 0x74e8b0013880 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1765966066.406346   58138 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4060, Compute Capability 8.9
# 2025-12-17 11:07:46.465194: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1765966066.654817   58138 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1765966069.740818   58138 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Fold 1: Accuracy = 90.39%
# Fold 2: Accuracy = 90.03%
# Fold 3: Accuracy = 90.15%
# Fold 4: Accuracy = 90.31%
# Fold 5: Accuracy = 91.52%
# >>> Moyenne : 90.48% (+/- 0.54%)
#
# --- Entraînement Final sur tout X_cv ---
# Epoch 1/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.6317 - loss: 1.4093 - precision: 0.7515 - recall: 0.4331 - val_accuracy: 0.6526 - val_loss: 1.1568 - val_precision: 0.7166 - val_recall: 0.6206
# Epoch 2/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6733 - loss: 1.0468 - precision: 0.7955 - recall: 0.5457 - val_accuracy: 0.6929 - val_loss: 0.8467 - val_precision: 0.7566 - val_recall: 0.6422
# Epoch 3/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7238 - loss: 0.8332 - precision: 0.8361 - recall: 0.6137 - val_accuracy: 0.7901 - val_loss: 0.6631 - val_precision: 0.8955 - val_recall: 0.6411
# Epoch 4/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7558 - loss: 0.7283 - precision: 0.8564 - recall: 0.6612 - val_accuracy: 0.7998 - val_loss: 0.5779 - val_precision: 0.8495 - val_recall: 0.7454
# Epoch 5/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7797 - loss: 0.6624 - precision: 0.8690 - recall: 0.6954 - val_accuracy: 0.8518 - val_loss: 0.4773 - val_precision: 0.9062 - val_recall: 0.7883
# Epoch 6/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7965 - loss: 0.6150 - precision: 0.8776 - recall: 0.7190 - val_accuracy: 0.8453 - val_loss: 0.4853 - val_precision: 0.8913 - val_recall: 0.7983
# Epoch 7/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8079 - loss: 0.5829 - precision: 0.8828 - recall: 0.7391 - val_accuracy: 0.8576 - val_loss: 0.4433 - val_precision: 0.8923 - val_recall: 0.8244
# Epoch 8/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8141 - loss: 0.5598 - precision: 0.8864 - recall: 0.7464 - val_accuracy: 0.8608 - val_loss: 0.4414 - val_precision: 0.9102 - val_recall: 0.8106
# Epoch 9/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8273 - loss: 0.5273 - precision: 0.8915 - recall: 0.7643 - val_accuracy: 0.8757 - val_loss: 0.3876 - val_precision: 0.9050 - val_recall: 0.8466
# Epoch 10/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8329 - loss: 0.5067 - precision: 0.8935 - recall: 0.7724 - val_accuracy: 0.8777 - val_loss: 0.3892 - val_precision: 0.9164 - val_recall: 0.8378
# Epoch 11/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8387 - loss: 0.4927 - precision: 0.8985 - recall: 0.7800 - val_accuracy: 0.8802 - val_loss: 0.3789 - val_precision: 0.9122 - val_recall: 0.8464
# Epoch 12/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8418 - loss: 0.4778 - precision: 0.8993 - recall: 0.7864 - val_accuracy: 0.8823 - val_loss: 0.3938 - val_precision: 0.9104 - val_recall: 0.8512
# Epoch 13/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8444 - loss: 0.4679 - precision: 0.9007 - recall: 0.7917 - val_accuracy: 0.8799 - val_loss: 0.3891 - val_precision: 0.9008 - val_recall: 0.8579
# Epoch 14/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8485 - loss: 0.4571 - precision: 0.9036 - recall: 0.7967 - val_accuracy: 0.8924 - val_loss: 0.3548 - val_precision: 0.9204 - val_recall: 0.8646
# Epoch 15/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8531 - loss: 0.4399 - precision: 0.9057 - recall: 0.8042 - val_accuracy: 0.8950 - val_loss: 0.3417 - val_precision: 0.9280 - val_recall: 0.8614
# Epoch 16/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8564 - loss: 0.4337 - precision: 0.9075 - recall: 0.8078 - val_accuracy: 0.8922 - val_loss: 0.3403 - val_precision: 0.9261 - val_recall: 0.8623
# Epoch 17/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8603 - loss: 0.4256 - precision: 0.9101 - recall: 0.8122 - val_accuracy: 0.8967 - val_loss: 0.3361 - val_precision: 0.9256 - val_recall: 0.8684
# Epoch 18/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8616 - loss: 0.4198 - precision: 0.9117 - recall: 0.8138 - val_accuracy: 0.9015 - val_loss: 0.3206 - val_precision: 0.9282 - val_recall: 0.8721
# Epoch 19/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8634 - loss: 0.4153 - precision: 0.9112 - recall: 0.8167 - val_accuracy: 0.9012 - val_loss: 0.3148 - val_precision: 0.9265 - val_recall: 0.8784
# Epoch 20/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8645 - loss: 0.4045 - precision: 0.9127 - recall: 0.8196 - val_accuracy: 0.9003 - val_loss: 0.3236 - val_precision: 0.9310 - val_recall: 0.8703
# Epoch 21/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8678 - loss: 0.3991 - precision: 0.9147 - recall: 0.8248 - val_accuracy: 0.9046 - val_loss: 0.3134 - val_precision: 0.9258 - val_recall: 0.8833
# Epoch 22/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8713 - loss: 0.3901 - precision: 0.9170 - recall: 0.8295 - val_accuracy: 0.9027 - val_loss: 0.3207 - val_precision: 0.9240 - val_recall: 0.8822
# Epoch 23/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8712 - loss: 0.3894 - precision: 0.9165 - recall: 0.8287 - val_accuracy: 0.9073 - val_loss: 0.3114 - val_precision: 0.9289 - val_recall: 0.8856
# Epoch 24/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8760 - loss: 0.3783 - precision: 0.9188 - recall: 0.8356 - val_accuracy: 0.8951 - val_loss: 0.3616 - val_precision: 0.9117 - val_recall: 0.8792
# Epoch 25/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8760 - loss: 0.3758 - precision: 0.9179 - recall: 0.8350 - val_accuracy: 0.9105 - val_loss: 0.2990 - val_precision: 0.9344 - val_recall: 0.8868
# Epoch 26/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8748 - loss: 0.3746 - precision: 0.9183 - recall: 0.8345 - val_accuracy: 0.9067 - val_loss: 0.3164 - val_precision: 0.9254 - val_recall: 0.8877
# Epoch 27/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8799 - loss: 0.3651 - precision: 0.9210 - recall: 0.8384 - val_accuracy: 0.9092 - val_loss: 0.2954 - val_precision: 0.9317 - val_recall: 0.8879
# Epoch 28/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8787 - loss: 0.3649 - precision: 0.9214 - recall: 0.8410 - val_accuracy: 0.9120 - val_loss: 0.2950 - val_precision: 0.9349 - val_recall: 0.8871
# Epoch 29/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8823 - loss: 0.3570 - precision: 0.9228 - recall: 0.8435 - val_accuracy: 0.9098 - val_loss: 0.3057 - val_precision: 0.9304 - val_recall: 0.8897
# Epoch 30/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8818 - loss: 0.3549 - precision: 0.9229 - recall: 0.8443 - val_accuracy: 0.9089 - val_loss: 0.3143 - val_precision: 0.9260 - val_recall: 0.8904
# Epoch 31/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8822 - loss: 0.3540 - precision: 0.9223 - recall: 0.8444 - val_accuracy: 0.9136 - val_loss: 0.2889 - val_precision: 0.9350 - val_recall: 0.8889
# Epoch 32/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8843 - loss: 0.3480 - precision: 0.9240 - recall: 0.8465 - val_accuracy: 0.9126 - val_loss: 0.2960 - val_precision: 0.9314 - val_recall: 0.8918
# Epoch 33/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8838 - loss: 0.3476 - precision: 0.9241 - recall: 0.8476 - val_accuracy: 0.9136 - val_loss: 0.2958 - val_precision: 0.9318 - val_recall: 0.8939
# Epoch 34/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8858 - loss: 0.3417 - precision: 0.9257 - recall: 0.8503 - val_accuracy: 0.9101 - val_loss: 0.2984 - val_precision: 0.9311 - val_recall: 0.8876
# Epoch 35/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8847 - loss: 0.3443 - precision: 0.9238 - recall: 0.8492 - val_accuracy: 0.9129 - val_loss: 0.2960 - val_precision: 0.9306 - val_recall: 0.8949
# Epoch 36/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8882 - loss: 0.3396 - precision: 0.9260 - recall: 0.8525 - val_accuracy: 0.9148 - val_loss: 0.2866 - val_precision: 0.9360 - val_recall: 0.8932
# Epoch 37/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8876 - loss: 0.3399 - precision: 0.9264 - recall: 0.8517 - val_accuracy: 0.9103 - val_loss: 0.3026 - val_precision: 0.9283 - val_recall: 0.8925
# Epoch 38/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8891 - loss: 0.3341 - precision: 0.9277 - recall: 0.8542 - val_accuracy: 0.9131 - val_loss: 0.2893 - val_precision: 0.9318 - val_recall: 0.8929
# Epoch 39/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8887 - loss: 0.3327 - precision: 0.9265 - recall: 0.8533 - val_accuracy: 0.9136 - val_loss: 0.2990 - val_precision: 0.9306 - val_recall: 0.8954
# Epoch 40/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8903 - loss: 0.3307 - precision: 0.9280 - recall: 0.8565 - val_accuracy: 0.9153 - val_loss: 0.2934 - val_precision: 0.9336 - val_recall: 0.8961
# Epoch 41/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8906 - loss: 0.3300 - precision: 0.9266 - recall: 0.8560 - val_accuracy: 0.9176 - val_loss: 0.2868 - val_precision: 0.9362 - val_recall: 0.8966
# Epoch 42/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8910 - loss: 0.3260 - precision: 0.9290 - recall: 0.8566 - val_accuracy: 0.9164 - val_loss: 0.2883 - val_precision: 0.9319 - val_recall: 0.8968
# Epoch 43/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8923 - loss: 0.3234 - precision: 0.9290 - recall: 0.8581 - val_accuracy: 0.9159 - val_loss: 0.2809 - val_precision: 0.9336 - val_recall: 0.8937
# Epoch 44/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8939 - loss: 0.3216 - precision: 0.9296 - recall: 0.8588 - val_accuracy: 0.9137 - val_loss: 0.2960 - val_precision: 0.9303 - val_recall: 0.8969
# Epoch 45/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8933 - loss: 0.3207 - precision: 0.9294 - recall: 0.8618 - val_accuracy: 0.9159 - val_loss: 0.2863 - val_precision: 0.9337 - val_recall: 0.8977
# Epoch 46/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8923 - loss: 0.3209 - precision: 0.9289 - recall: 0.8591 - val_accuracy: 0.9156 - val_loss: 0.2887 - val_precision: 0.9320 - val_recall: 0.8983
# Epoch 47/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8949 - loss: 0.3165 - precision: 0.9304 - recall: 0.8614 - val_accuracy: 0.9169 - val_loss: 0.2851 - val_precision: 0.9344 - val_recall: 0.8985
# Epoch 48/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8959 - loss: 0.3160 - precision: 0.9314 - recall: 0.8626 - val_accuracy: 0.9133 - val_loss: 0.2893 - val_precision: 0.9313 - val_recall: 0.8969
# Epoch 49/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8933 - loss: 0.3174 - precision: 0.9303 - recall: 0.8609 - val_accuracy: 0.9153 - val_loss: 0.2898 - val_precision: 0.9312 - val_recall: 0.8985
# Epoch 50/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8946 - loss: 0.3159 - precision: 0.9302 - recall: 0.8616 - val_accuracy: 0.9186 - val_loss: 0.2877 - val_precision: 0.9339 - val_recall: 0.8983
# Epoch 51/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8962 - loss: 0.3138 - precision: 0.9315 - recall: 0.8642 - val_accuracy: 0.9172 - val_loss: 0.2869 - val_precision: 0.9361 - val_recall: 0.8983
# Epoch 52/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8965 - loss: 0.3120 - precision: 0.9319 - recall: 0.8634 - val_accuracy: 0.9155 - val_loss: 0.2883 - val_precision: 0.9326 - val_recall: 0.8968
# Epoch 53/100
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8962 - loss: 0.3122 - precision: 0.9321 - recall: 0.8639 - val_accuracy: 0.9144 - val_loss: 0.2921 - val_precision: 0.9326 - val_recall: 0.8995
# Score Test Set Final : 91.59%

# %%
# Affichage des courbes
plot_training_history(history)

# %% [markdown]
# ### Fit tuning des hyperparamètres.
#
# Après avoir défini les hyperparamètres modifiables et vérifier que les fonctions fonctionnent, il est temps de lancer l'optimisation des hyperparamètres. Pour cela je vous invite à utiliser Optuna [[3]](https://optuna.readthedocs.io/en/stable/index.html) qui a plusieurs fonctionnalités:
# *   Une visualisation facilitée.
# *   Un suivi de l'avancement de l'optimisation.
# *   Une possibilité de reprendre l'optimisation sans reprendre depuis le début si un problème arrive durant le traitement.
#
#  <font color=" Darkblue"> **Tips:** Essayez de lancer l'optimisation pendant le TP pour voir si il fonctionne et arretez le. Lancez le pour de bon à la fin de la séance ou pendant la semaine car cela va prendre plusieurs heures, voir plusieurs jours. </font>
#
#  <font color="orange"> **Note anti-plagiat:** L'optimisation doit avoir une random seed fixe et différente pour chaque groupe. </font>
#
#  Merci de justifier vos plages de valeurs et faite un résumé sous forme de tableau :
#  > **Justification des Choix**
#
#     L'espace de recherche a été contraint pour répondre aux exigences spécifiques des systèmes embarqués (STM32 / Cortex-M) :
#
# 1.  **Puissances de 2 (`16, 32...`) :**
#     Nous avons restreint le nombre de filtres et de neurones à des puissances de 2. Cela facilite l'alignement mémoire et l'optimisation des calculs SIMD sur le matériel cible, évitant le gaspillage de cycles CPU typique des dimensions arbitraires (ex: 50 ou 100).
#
# 2.  **Paramètres Fixes (Kernel & L2) :**
#     * La taille du noyau est fixée à **3x3** (standard pour les MFCC) et le taux de régularisation L2 à **0.001** (validé lors des phases précédentes).
#     * Fixer ces paramètres permet de réduire la dimensionnalité du problème, laissant l'optimiseur TPE se concentrer sur les hyperparamètres les plus critiques pour le compromis "Taille vs Précision".
#
# 3.  **Fonctions d'activation :**
#     Nous comparons principalement **ReLU** (très peu coûteuse en calcul `max(0,x)`) et **Leaky ReLU** (pour éviter la mort des neurones sur les petits modèles compressés).
#
# 4.  **Optimisation Multi-Objectifs :**
#     L'objectif n'est pas seulement de trouver le modèle le plus précis, mais d'établir un **Front de Pareto**. Cela nous permettra de sélectionner *a posteriori* le modèle le plus performant capable de tenir dans une contrainte mémoire stricte (ex: < 20 ko de RAM).
#
# | Hyperparamètre | Meilleure valeur | Plage / Valeurs | Step | Type de la plage |
# | :---------------- | :------: | :----: | :----: | :----: |
# | **activation** | *À compléter* | `['relu', 'leaky_relu']` | - | Catégoriel |
# | **conv_filters** | *À compléter* | `[16, 32, 64, 128]` | - | Catégoriel (Puiss. de 2) |
# | **ds_filters_1** | *À compléter* | `[16, 32, 64, 128]` | - | Catégoriel (Puiss. de 2) |
# | **ds_filters_2** | *À compléter* | `[16, 32, 64, 128]` | - | Catégoriel (Puiss. de 2) |
# | **dense_units** | *À compléter* | `[16, 32, 64, 128]` | - | Catégoriel (Puiss. de 2) |
# | **dropout_rate** | *À compléter* | `[0.1 - 0.5]` | Continu | Flottant (Uniforme) |
# | **BATCH_SIZE** | *À compléter* | `[16, 32, 64, 128]` | - | Catégoriel |
# | *kernell* | **3** | Fixé | - | Constante |
# | *l2_rate* | **0.001** | Fixé | - | Constante |
#
# ---

# %%
import optuna

SEED = 42
np.random.seed(SEED)

# %%
def objective(trial):
    # 1) Tirage des hyperparamètres
    param_model = {
        "activation"  : trial.suggest_categorical("activation", ["relu", "leaky_relu"]),
        "conv_filters": trial.suggest_categorical("conv_filters", [16, 32, 64, 128]), # on reste en puissance de dexu pour simplififer implémentation
        "ds_filters_1": trial.suggest_categorical("ds_filters_1", [16, 32, 64, 128]),
        "ds_filters_2": trial.suggest_categorical("ds_filters_2", [16, 32, 64, 128]),
        "dense_units" : trial.suggest_categorical("dense_units", [16, 32, 64, 128]),
        "dropout_rate": trial.suggest_float("dropout_rate", 0.1, 0.5),
        "kernell"     :  3,         # Fixé pour simplififer la zone de recherche des hyperparamètre en accord avec littérature
        'l2_rate'     : 0.001       # Force de la régularisation (1e-3 est classique)
}
    
    param_training = {
        "BATCH_SIZE": trial.suggest_categorical("BATCH_SIZE", [16, 32, 64, 128]),
        "max_epochs": 200  # On fixe max_epochs haut et utilise early stopping
    }

    # 2) Création + taille du modèle
    model = create_model(param_model, INPUT_SHAPE, NUM_CLASSES)
    print("model")
    size = total_param(model)
    trial.set_user_attr("Size", size)

    # 3) Entraînement + métriques
    metrics, _, _ = compile_and_fit(model, full_train_ds, test_ds, param_training, verbose=0)
    print("training over")

    val_acc = metrics[1]  # adapte si besoin
    print("val_acc =", val_acc)

    # 4) On renvoie 2 objectifs : (à max, à min)
    return val_acc, size   # 1er objectif = accuracy, 2e = taille


study_name="Benarib~Hanni-Tuning-embedded-v1",
storage_name = f'/home/zebre/Bureau/eddge_computing/Edge_computing/model/{study_name}.db' #Chemin à créer dans votre drive

storage_url = f"sqlite:///{storage_name}"


study = optuna.create_study(
    directions=["maximize", "minimize"],
    study_name="Benarib~Hanni-Tuning-embedded-v1",
    storage=storage_url,
    sampler=optuna.samplers.TPESampler(seed=SEED),
    load_if_exists=True,
)
# Out:
# [I 2025-12-17 18:57:21,323] Using an existing study with name 'Benarib~Hanni-Tuning-embedded-v1' instead of creating a new one.

# %%
study.optimize(objective, n_trials=2)
# Out:
# model
# Nombre de poids du modèle: 4,060
# Epoch 1/200
# 781/900 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6142 - loss: 1.5356 - precision: 0.6824 - recall: 0.4075
# [W 2025-12-17 18:57:27,762] Trial 23 failed with parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 64, 'dense_units': 16, 'dropout_rate': 0.1626987210868994, 'BATCH_SIZE': 128} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/home/zebre/miniconda/envs/ml-tf/lib/python3.10/site-packages/optuna/study/_optimize.py", line 205, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_57985/3606610655.py", line 26, in objective
#     metrics, _, _ = compile_and_fit(model, full_train_ds, test_ds, param_training, verbose=1)
#   File "/tmp/ipykernel_57985/1549797117.py", line 29, in compile_and_fit
#     history = model.fit(
#   File "/home/zebre/miniconda/envs/ml-tf/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#     return fn(*args, **kwargs)
#   File "/home/zebre/miniconda/envs/ml-tf/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 378, in fit
#     callbacks.on_train_batch_end(end_step, logs)
#   File "/home/zebre/miniconda/envs/ml-tf/lib/python3.10/site-packages/keras/src/callbacks/callback_list.py", line 172, in on_train_batch_end
#     self._on_train_batch_end(batch, logs)
#   File "/home/zebre/miniconda/envs/ml-tf/lib/python3.10/site-packages/keras/src/callbacks/callback_list.py", line 194, in _on_train_batch_end
#     callback.on_train_batch_end(batch, logs=logs)
#   File "/home/zebre/miniconda/envs/ml-tf/lib/python3.10/site-packages/keras/src/callbacks/progbar_logger.py", line 58, in on_train_batch_end
#     self._update_progbar(batch, logs)
#   File "/home/zebre/miniconda/envs/ml-tf/lib/python3.10/site-packages/keras/src/callbacks/progbar_logger.py", line 95, in _update_progbar
#     self.progbar.update(self.seen, list(logs.items()), finalize=False)
#   File "/home/zebre/miniconda/envs/ml-tf/lib/python3.10/site-packages/keras/src/utils/progbar.py", line 166, in update
#     backend.numpy.mean(
#   File "/home/zebre/miniconda/envs/ml-tf/lib/python3.10/site-packages/keras/src/backend/tensorflow/numpy.py", line 719, in mean
#     return tf.cast(output, result_dtype)
#   File "/home/zebre/miniconda/envs/ml-tf/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py", line 150, in error_handler
#     return fn(*args, **kwargs)
#   File "/home/zebre/miniconda/envs/ml-tf/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py", line 1260, in op_dispatch_handler
#     return dispatch_target(*args, **kwargs)
#   File "/home/zebre/miniconda/envs/ml-tf/lib/python3.10/site-packages/tensorflow/python/ops/math_ops.py", line 997, in cast
#     isinstance(x, tensor_lib.Tensor) or _pywrap_utils.IsResourceVariable(x)
# KeyboardInterrupt
# [W 2025-12-17 18:57:27,765] Trial 23 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 study.optimize(objective, n_trials=2)
#
# File ~/miniconda/envs/ml-tf/lib/python3.10/site-packages/optuna/study/study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)
#     397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File ~/miniconda/envs/ml-tf/lib/python3.10/site-packages/optuna/study/_optimize.py:67, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      65 try:
#      66     if n_jobs == 1:
# ---> 67         _optimize_sequential(
#      68             study,
#      69             func,
#      70             n_trials,
#      71             timeout,
#      72             catch,
#      73             callbacks,
#      74             gc_after_trial,
#      75             reseed_sampler_rng=False,
#      76             time_start=None,
#      77             progress_bar=progress_bar,
#      78         )
#      79     else:
#      80         if n_jobs == -1:
#
# File ~/miniconda/envs/ml-tf/lib/python3.10/site-packages/optuna/study/_optimize.py:164, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161         break
#     163 try:
# --> 164     frozen_trial_id = _run_trial(study, func, catch)
#     165 finally:
#     166     # The following line mitigates memory problems that can be occurred in some
#     167     # environments (e.g., services that use computing containers such as GitHub Actions).
#     168     # Please refer to the following PR for further details:
#     169     # https://github.com/optuna/optuna/pull/325.
#     170     if gc_after_trial:
#
# File ~/miniconda/envs/ml-tf/lib/python3.10/site-packages/optuna/study/_optimize.py:262, in _run_trial(study, func, catch)
#     255         assert False, "Should not reach."
#     257 if (
#     258     updated_state == TrialState.FAIL
#     259     and func_err is not None
#     260     and not isinstance(func_err, catch)
#     261 ):
# --> 262     raise func_err
#     263 return trial._trial_id
#
# File ~/miniconda/envs/ml-tf/lib/python3.10/site-packages/optuna/study/_optimize.py:205, in _run_trial(study, func, catch)
#     203 with get_heartbeat_thread(trial._trial_id, study._storage):
#     204     try:
# --> 205         value_or_values = func(trial)
#     206     except exceptions.TrialPruned as e:
#     207         # TODO(mamu): Handle multi-objective cases.
#     208         state = TrialState.PRUNED
#
# Cell In[35], line 26, in objective(trial)
#      23 trial.set_user_attr("Size", size)
#      25 # 3) Entraînement + métriques
# ---> 26 metrics, _, _ = compile_and_fit(model, full_train_ds, test_ds, param_training, verbose=1)
#      27 print("training over")
#      29 val_acc = metrics[1]  # adapte si besoin
#
# Cell In[21], line 29, in compile_and_fit(model, train_ds, val_ds, train_params, verbose)
#      22 model.compile(loss='categorical_crossentropy',
#      23             optimizer=optimizer,  # <--- INDISPENSABLE
#      24             metrics=['accuracy',
#      25             tf.keras.metrics.Precision(name='precision'),
#      26             tf.keras.metrics.Recall(name='recall')])
#      28 # 5. Entraînement
# ---> 29 history = model.fit(
#      30     train_ds,
#      31     epochs=train_params['max_epochs'],
#      32     validation_data=val_ds,
#      33     callbacks=[early_stopping],
#      34     verbose=verbose
#      35 )
#      37 scores = model.evaluate(val_ds, verbose=0)
#      38 return scores, model, history
#
# File ~/miniconda/envs/ml-tf/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda/envs/ml-tf/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:378, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     376 callbacks.on_train_batch_begin(begin_step)
#     377 logs = self.train_function(iterator)
# --> 378 callbacks.on_train_batch_end(end_step, logs)
#     379 if self.stop_training:
#     380     break
#
# File ~/miniconda/envs/ml-tf/lib/python3.10/site-packages/keras/src/callbacks/callback_list.py:172, in CallbackList.on_train_batch_end(self, batch, logs)
#     170     self._async_dispatch(self._on_train_batch_end, batch, logs)
#     171 else:
# --> 172     self._on_train_batch_end(batch, logs)
#
# File ~/miniconda/envs/ml-tf/lib/python3.10/site-packages/keras/src/callbacks/callback_list.py:194, in CallbackList._on_train_batch_end(self, batch, logs)
#     192 logs = python_utils.pythonify_logs(logs)
#     193 for callback in self.callbacks:
# --> 194     callback.on_train_batch_end(batch, logs=logs)
#
# File ~/miniconda/envs/ml-tf/lib/python3.10/site-packages/keras/src/callbacks/progbar_logger.py:58, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#      57 def on_train_batch_end(self, batch, logs=None):
# ---> 58     self._update_progbar(batch, logs)
#
# File ~/miniconda/envs/ml-tf/lib/python3.10/site-packages/keras/src/callbacks/progbar_logger.py:95, in ProgbarLogger._update_progbar(self, batch, logs)
#      92 self.seen = batch + 1  # One-indexed.
#      94 if self.verbose == 1:
# ---> 95     self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File ~/miniconda/envs/ml-tf/lib/python3.10/site-packages/keras/src/utils/progbar.py:166, in Progbar.update(self, current, values, finalize)
#     163 info += f" - {k}:"
#     164 if isinstance(self._values[k], list):
#     165     avg = backend.convert_to_numpy(
# --> 166         backend.numpy.mean(
#     167             self._values[k][0] / max(1, self._values[k][1])
#     168         )
#     169     )
#     170     avg = float(avg)
#     171     if abs(avg) > 1e-3:
#
# File ~/miniconda/envs/ml-tf/lib/python3.10/site-packages/keras/src/backend/tensorflow/numpy.py:719, in mean(x, axis, keepdims)
#     715     result_dtype = ori_dtype
#     716 output = tf.reduce_mean(
#     717     tf.cast(x, compute_dtype), axis=axis, keepdims=keepdims
#     718 )
# --> 719 return tf.cast(output, result_dtype)
#
# File ~/miniconda/envs/ml-tf/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda/envs/ml-tf/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/miniconda/envs/ml-tf/lib/python3.10/site-packages/tensorflow/python/ops/math_ops.py:997, in cast(x, dtype, name)
#     944 """Casts a tensor to a new type.
#     945
#     946 The operation casts `x` (in case of `Tensor`) or `x.values`
#    (...)
#     993
#     994 """
#     995 base_type = dtypes.as_dtype(dtype).base_dtype
#     996 if (
# --> 997     isinstance(x, tensor_lib.Tensor) or _pywrap_utils.IsResourceVariable(x)
#     998 ) and base_type == x.dtype:
#     999   return x
#    1000 with ops.name_scope(name, "Cast", [x]) as name:
#
# KeyboardInterrupt:

# %%
# Load the existing study
study_name = "Benarib~Hanni-Tuning-embedded-v1"
storage_name = '/home/zebre/Bureau/eddge_computing/Edge_computing/model/Benarib~Hanni-Tuning-embedded-v1.db'
storage_url = f"sqlite:///{storage_name}"

study = optuna.load_study(
    study_name=study_name,
    storage=storage_url
)

# %% [markdown]
# ## Résultat et discussion
#
# <font color=" Darkred"> Progression du TP après cette partie (environ 3h): </font>
# ![84%](https://progress-bar.dev/84)

# %% [markdown]
# ### Export du modèle
#
# Merci d'exporter le meilleur modèle et l'envoyer avec le jupyter notebook et la base de données d'entraînement. Lors de l'exportation d'un modèle, il est recommandé d'utiliser la base de donnée d'entrainement, et de validation.
#
#  <font color="green">*Cette partie du code est complète, vous n'avez pas besoin de la modifier.* </font>

# %%
import joblib

# 1. Chargement de l'étude
storage_url_fixed = f"sqlite:///{storage_name.replace('sqlite:///', '')}"
study = optuna.load_study(storage=storage_url_fixed, study_name=study_name)

# 2. Récupération du Front de Pareto (Liste des meilleurs compromis)
best_trials = study.best_trials

print(f"Nombre de modèles sur le front de Pareto : {len(best_trials)}")

# 3. Trouver la meilleure Accuracy absolue sur le front de Pareto
# (values[0] = accuracy, values[1] = size)
max_accuracy_trial = max(best_trials, key=lambda t: t.values[0])
max_acc = max_accuracy_trial.values[0]

# 4. Définir la marge de tolérance (0.01 = 1%)
TOLERANCE = 0.02
acc_threshold = max_acc - TOLERANCE

print(f"Accuracy Max Absolue : {max_acc:.4f}")
print(f"Accuracy Acceptable  : >= {acc_threshold:.4f}")

# 5. Filtrer les candidats (ceux qui sont assez précis)
candidates = [t for t in best_trials if t.values[0] >= acc_threshold]

# 6. Sélectionner le plus petit parmi les candidats
# On trie par taille (values[1]) croissant et on prend le premier
chosen_trial = sorted(candidates, key=lambda t: t.values[1])[0]

# --- Affichage du gain ---
size_max_acc = max_accuracy_trial.values[1]
size_chosen  = chosen_trial.values[1]
reduction = (1 - size_chosen / size_max_acc) * 100

print("\n=== RÉSULTAT DE LA SÉLECTION ===")
print(f"Modèle choisi (ID Trial : {chosen_trial.number})")
print(f" -> Accuracy : {chosen_trial.values[0]:.4f} (Perte de {(max_acc - chosen_trial.values[0]):.4f})")
print(f" -> Taille   : {size_chosen} params")
print(f" -> Gain taille vs Max Accuracy : -{reduction:.2f}% de paramètres !")

print("\n=== MEILLEUR MODÈLE SÉLECTIONNÉ ===")
print(f"   Accuracy attendue : {chosen_trial.values[0]:.4f}")
print(f"   Taille (params)   : {chosen_trial.values[1]}")
print("   Params: ")
for key, value in chosen_trial.params.items():
    print(f"    -{key}: {value}")
print("-------------------------------------")

# 7. Recréation et Réentraînement du modèle choisi
# On utilise les hyperparamètres du "chosen_trial"
model = create_model(chosen_trial.params, INPUT_SHAPE, NUM_CLASSES)

# Concaténation Train + Val pour l'entraînement final (Bonne pratique !)
X_full = np.concatenate((X_train, X_val))
y_full = np.concatenate((y_train, y_val))

# Recréation du dataset complet
train_and_val = tf.data.Dataset.from_tensor_slices((X_full, y_full))
train_and_val = train_and_val.shuffle(1500, reshuffle_each_iteration=True)
# Attention : Assure-toi que le BATCH_SIZE est bien dans les params ou fixe-le
batch_size_final = chosen_trial.params.get("BATCH_SIZE", 32) 
train_and_val = train_and_val.batch(batch_size_final, drop_remainder=True)

# Entraînement final
# Note: "val" ici sert juste de témoin, car le modèle apprend déjà sur ces données via train_and_val
# Idéalement, on devrait évaluer sur un jeu de TEST jamais vu.
validation_evaluation_post_optuna, global_model_post_optuna, history_post_optuna = compile_and_fit(
    model, 
    train_and_val, 
    val, 
    chosen_trial.params, 
    verbose=1 # Mets 1 pour voir que ça tourne
)

print("Affichage des courbes d'apprentissage...")
plot_training_history(history)


# 4. Sauvegarde
# IMPORTANT : Pour Keras/TensorFlow, évite joblib. Utilise la méthode native .save()
# Le format .keras est le nouveau standard, ou .h5
save_path = '/home/zebre/Bureau/eddge_computing/Edge_computing/model/Hanni_Benarib_model.keras'
global_model_post_optuna.save(save_path)
print(f"Modèle sauvegardé sous : {save_path}")

# %% [markdown]
# ### Dépôt sur Kaggle
#
# Il est temps de soumettre vos résultats sur Kaggle. Qu'en pensez vous, êtes vous satisfait de vos performances ? Est-ce que vous vous attendiez à ces performances ?
#
#  <font color=" Darkblue"> **Tips:** Le format d'envoie et des tutoriels sont disponibles sur la page du concours. </font>
#
#  <font color="orange"> **Note anti-plagiat:** Il est impossible que le fichier que vous allez déposer soit le même qu'un autre binôme. Le fichier sera regénérer lors de la correction et doit être similaire avec celui déposé. </font>
#
# A la fin du projet, merci d'envoyer avec les autres fichiers ce fichier Kaggle avec comme nom **NOM1~NOM2_submission.csv**.
#
# > **Ecrire votre texte ici.**

# %%
#Ici, tous le code est à faire. Normalement, tous a déjà été codé ou est facilement trouvable sur internet et sur le site de la compétition !

# %% [markdown]
# ### Visualisation des résultats
#
# Ici tous le code a déjà été fait. Il faut par contre commenter les résultats et les performances que vous avez obtenu et l'utilité de chaque figure.

# %% [markdown]
#  #### Matrice de confusion
#
#  <font color="green">*Cette partie du code est complète, vous n'avez pas besoin de la modifier.* </font>
#
#  > **Ecrire votre texte ici.**

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# (re)load study if needed
study = optuna.load_study(storage=storage_url, study_name=study_name)

# Predictions from the model on the validation dataset
y_prob = global_model_post_optuna.predict(val)
y_pred = y_prob.argmax(axis=1)

# Build reference labels from the tf.data Dataset
ds_labels = []
for images, labels in val.unbatch():
    ds_labels.append(labels)
y_ref = np.array(ds_labels).argmax(axis=1)

# Label names (order must match the numeric label indices)
label_names = ["yes", "no", "up", "down", "left", "right", "on", "off", "stop", "go", "silence", "unknown"]

# Ensure the confusion matrix includes all classes (even if some are absent in y_ref/y_pred)
all_labels = list(range(len(label_names)))

# Draw confusion matrix — pass `labels` so ticks match `display_labels`
ConfusionMatrixDisplay.from_predictions(
    y_ref,
    y_pred,
    labels=all_labels,
    display_labels=label_names,
    cmap='Blues',
    normalize='true',
    ax=plt.subplots(figsize=(12, 12))[1]
)
plt.tight_layout()

# %% [markdown]
# #### Résultat du Fit-tuning
#
#  <font color="green">*Cette partie du code est complète, vous n'avez pas besoin de la modifier.* </font>
#
#  > **Ecrire votre texte ici.**

# %%
plt.figure(figsize=(12,12))
optuna.visualization.plot_optimization_history(
    study,
    target=lambda t: t.values[0],  # On récupère la 1ère valeur retournée par ta fonction objective
    target_name="Accuracy"         # Nom affiché sur l'axe Y
)

# %%
optuna.visualization.plot_optimization_history(
    study,
    target=lambda t: t.values[1],  # On récupère la 2ème valeur retournée par ta fonction objective
    target_name="Model Size (numbers of parmeters)"         # Nom affiché sur l'axe Y
)

# %%
optuna.visualization.plot_slice(
    study,
    target=lambda t: t.values[0],  # On récupère la 1ère valeur retournée par ta fonction objective
    target_name="Accuracy"         # Nom affiché sur l'axe Y
)

# %%
optuna.visualization.plot_optimization_history(
    study,
    target=lambda t: t.values[1],  # On récupère la 2ème valeur retournée par ta fonction objective
    target_name="Model Size (numbers of parmeters)"         # Nom affiché sur l'axe Y
)

# %% [markdown]
# #### Influence des hyperparamètres sur les performances
#
#  <font color="green">*Cette partie du code est complète, vous n'avez pas besoin de la modifier.* </font>
#
#  > **Ecrire votre texte ici.**

# %%
result = optuna.importance.get_param_importances(study,target=lambda t: t.values[0])
plt.figure(figsize=(12, 4.5), dpi=100)
names = list(result.keys())
values = list(result.values())

plt.bar(range(len(result)), np.array(values)*100, tick_label=names, color='#000233')
plt.ylabel("Hyperparameter importance (%)")
plt.show()

# %% [markdown]
# #### Influence des hyperparamètres sur le temps de calcul
#
#  <font color="green">*Cette partie du code est complète, vous n'avez pas besoin de la modifier.* </font>
#
#  > **Ecrire votre texte ici.**

# %%
result = optuna.importance.get_param_importances(study, target=lambda t: t.duration.total_seconds())
plt.figure(figsize=(12, 4.5), dpi=100)
names = list(result.keys())
values = list(result.values())

plt.bar(range(len(result)), np.array(values)*100, tick_label=names, color='#000233')
plt.ylabel("Hyperparameter importance (%)")
plt.show()

# %% [markdown]
# #### Frontière de Pareto [[4]](https://fr.wikipedia.org/wiki/Optimum_de_Pareto)
#
#  <font color="green">*Cette partie du code est complète, vous n'avez pas besoin de la modifier.* </font>
#
#  > **Ecrire votre texte ici.**

# %%
# NOTE: pandas and plt are already imported earlier in the notebook (do not re-import here).
# This cell makes the trials dataframe usage robust for single- and multi-objective studies.

def plot_pareto_frontier(Xs, Ys, maxX=True, maxY=True):
    # From https://sirinnes.wordpress.com/2013/04/25/pareto-frontier-graphic-via-python/
    '''Pareto frontier selection process'''
    sorted_list = sorted([[Xs[i], Ys[i]] for i in range(len(Xs))], reverse=maxY)
    pareto_front = [sorted_list[0]]
    for pair in sorted_list[1:]:
        if maxY:
            if pair[1] >= pareto_front[-1][1]:
                pareto_front.append(pair)
        else:
            if pair[1] <= pareto_front[-1][1]:
                pareto_front.append(pair)

    '''Plotting process'''
    plt.scatter(Xs, Ys)
    pf_X = [pair[0] for pair in pareto_front]
    pf_Y = [pair[1] for pair in pareto_front]
    plt.plot(pf_X, pf_Y)
    plt.xlabel("Poids du modèle (octets)")
    plt.ylabel("Accuracy (%)")
    plt.show()

# Get trials dataframe
df = study.trials_dataframe()

# Determine objective column (support single- and multi-objective naming)
if 'value' in df.columns:
    y_col = 'value'
elif 'values_0' in df.columns:
    y_col = 'values_0'
elif 'values' in df.columns:
    y_col = 'values'
else:
    raise KeyError(f"No objective value column found in trials_dataframe. Available columns: {list(df.columns)}")

# Determine user_attr column for Size
if 'user_attrs_Size' in df.columns:
    x_col = 'user_attrs_Size'
else:
    # try to find a user_attrs column containing 'Size' or take any user_attrs column
    candidates = [c for c in df.columns if 'user_attrs' in c and 'Size' in c]
    if candidates:
        x_col = candidates[0]
    else:
        ua = [c for c in df.columns if c.startswith('user_attrs_')]
        if ua:
            x_col = ua[0]
        else:
            raise KeyError(f"No user_attrs column found in trials_dataframe. Available columns: {list(df.columns)}")

# Prepare data (drop rows with missing values)
plot_df = df[[x_col, y_col]].dropna()
Xs = plot_df[x_col].astype(float).tolist()
Ys = plot_df[y_col].astype(float).tolist()

plot_pareto_frontier(Xs, Ys)

# %% [markdown]
# ## Allégement du modèle post-optimisation
#
# Dans cette dernière partie, nous allons nous intéresser à l'influence des performances lorsque le modèle est allégé. Dans des appareils embarqués, il est nécessaire de trouver un compromis entre la performance du modèle, son poids, et la quantité d'opération.
#
# Au vue du nombre de séances, nous allons nous intéressé ici qu'au poids du système.
#
# Pour cela, vous allez essayé de réduire le poids du meilleur modèle obtenu, puis avoir un regard critique sur les performances à chaque modification.
#
# Voici les techniques d'allégement à essayer:
#   - **La quantification**: Réduire le nombre d'octets des paramètres du modèles et les convertir en entiers [[5]](https://www.tensorflow.org/lite/performance/post_training_quantization).
#   - **L'élagage**: Supprimer les modèles qui ont un impact mineur sur les prédictions [[6]](https://www.tensorflow.org/model_optimization/guide/pruning/pruning_with_keras).
#   - **Le clustering**: Regrouper les poids de chaque couche dans un modèle en un nombre prédéfini de clusters, puis en partageant les valeurs centroïdes pour les poids appartenant à chaque cluster individuel [[7]](https://www.tensorflow.org/model_optimization/guide/clustering/clustering_example).
#   - **La décimation** : Réduire le nombre d'entrée.
#
# <font color=" Darkred"> Progression du TP après cette partie (environ 4h):
#
# Essayez d'avoir la meilleure accuracy avec un poids maximum inférieur à 75 KB.
#
#  <font color=" Darkblue"> **Tips:**  Des tutoriels sont disponibles sur les liens attachés au techniques d'allégement. </font>
#
#  > **Ecrire votre texte ici.**

# %% [markdown]
# Pour cette partie nous sommes partis nous avons suivie les conseils données en [[5]](https://www.tensorflow.org/lite/performance/post_training_quantization).
#
# Pour la quantification. Notre modèle étant optimisé via otpuna aux niveaus de ses hyperparamètres, notre architecture ayant pour but d'être porté sur FPGA (cible difficile à programmer) et notre dataset n'étant pas représentatif de nos données, nous nous sommes cantonés à une quantification en float16 ppur commencer.
# ![Screenshot from 2025-11-24 01-39-04.png](<attachment:Screenshot from 2025-11-24 01-39-04.png>)

# %% [markdown]
# Tensor Flow Lite permet de réaliser cette conversion en:
#
#     - float 16 (réduit de moitié la taille du modèle)
#     - int 8
# Les avanatges d'une telle quantification sont les suivants :
#
#     - Réduction de la taille du modèle de moitié (poids et activation réduit à 16 bits)
#     - Pert d'accuracy minimale
#     - Rend le calul possible sur architecyure GPU
#
# Les désavantages du float 16 sont:
#
#     - Ne réduit pas la latence autant qu'une quantificatio avec calcul en virgule fixe.
#     By default, a float16 quantized model will "dequantize" the weights values to float32 when run on the CPU. (Note that the GPU delegate will not perform this dequantization, since it can operate on float16 data.)

# %% [markdown]
# Pour aller plus loin dans le projet sur la quantification, et voire laquelle serait la plus intéressante pour un bon rapport perfomance/implémentation et embarquabilité sur cible, il nous faut observer ce que donne les résultats de notre modèle avec cette simple quantification, sans détails supplémentaire. Pour cela nous avons rédigé une petite focntion ci dessous pour quantifier nos données ainsi que notre réseaux.

# %%
def fake_quantize(x, bits, frac_bits):
    """
    Simule un format fixe signé Q(1.(bits-1)) avec 'frac_bits' bits de fraction.
    bits = largeur totale (ex: 8) ; frac_bits ~ 7 → Q1.7
    """
    x = x.astype(np.float32)
    scale = 2 ** frac_bits

    qmin = -2 ** (bits - 1)
    qmax =  2 ** (bits - 1) - 1

    x_scaled = np.round(x * scale)
    x_clipped = np.clip(x_scaled, qmin, qmax)
    x_dequant = x_clipped / scale
    return x_dequant.astype(np.float32)

# %% [markdown]
# Etant donné que nous avons pour projet d'essayer d'embarqué l modèle sur carte FPGA, nous devons regarder comment effectuer la quantification des données également.

# %%
# Évaluer modèle de référence et les versions quantifiées
reference_results = model.evaluate(X_val, y_val)
Q1_14_results = model.evaluate(fake_quantize(X_val, bits=16, frac_bits=14), y_val)
Q1_6_results = model.evaluate(fake_quantize(X_val, bits=8, frac_bits=7), y_val)

# Fonction sûre pour éviter division par zéro / types incompatibles
def _safe_ratio(num, den):
	try:
		den_f = float(den)
		num_f = float(num)
		return num_f / den_f if den_f != 0.0 else np.nan
	except Exception:
		return np.nan

precision_loss_Q1_6 = [_safe_ratio(q, r) for q, r in zip(Q1_6_results, reference_results)]
precision_loss_Q1_14 = [_safe_ratio(q, r) for q, r in zip(Q1_14_results, reference_results)]

print("Résultats (quantifié / référence) — ordre: [loss, accuracy, precision, recall]")
print("Résultats en Q1.6 (acc, precision):", precision_loss_Q1_6[1:3])
print("Résultats en Q1.14 (acc, precision):", precision_loss_Q1_14[1:3])

# %%
import tensorflow as tf
import joblib

# Load the model from pickle file
model_path = "/home/zebre/Bureau/eddge_computing/Edge_computing/model/Hanni_Benarib_model.pkl"
loaded_model = joblib.load(model_path)

# Convert the Keras model to TensorFlow Lite format
converter = tf.lite.TFLiteConverter.from_keras_model(loaded_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_types = [tf.float16]
tflite_quant_model = converter.convert()

# Save the TensorFlow Lite model
tflite_model_path = "/home/zebre/Bureau/eddge_computing/Edge_computing/model/Hanni_Benarib_model.tflite"
with open(tflite_model_path, 'wb') as f:
	f.write(tflite_quant_model)

print(f"TFLite model saved to: {tflite_model_path}")
print(f"Model size: {len(tflite_quant_model) / 1024:.2f} KB")

# %% [markdown]
# ### BONUS: Allégement avant optimisation
#
# Relancez un fit-tuning en rajoutant les paramètres d'allégements. Puis, observez les resultats avec une frontière de pareto. Les valeurs minimums de poids de la frontière doivent se trouver en dessous de 50 KB.
#
#  <font color=" Darkblue"> **Tips:** Utilisez 2 métriques lorsque vous lancez la fonction d'activation. </font>
#
#  > **Ecrire votre texte ici.**

# %% [markdown]
# ## Conclusion
#
#
#  <font color=" Darkblue"> **Tips:** Concluez sur vos résultats, les limitations de votre modèle et les perspectives envisagées pour l'améliorer. </font>
#
#
#  <font color=" Darkred"> Progression du TP après cette partie (environ 0h30): </font>
#
#
# > **Ecrire votre texte ici.**
