# %% [markdown]
# <a href="https://colab.research.google.com/github/BenaribIlyes/Edge_computing/blob/main/code/edge_computing_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Travaux Pratiques - N9EE39A Edge Computing
# **Contact: Adrien THIRION ([email](adrien.thirion@nanomade.com))**
# **Créé en Octobre 2023**
#
# L'objectif de ces séances de travaux pratiques est de vous familiariser avec le métier de Data Scientists, plus particulièrement dans un environnement contraint (système embarqué). Celui-ci a été pensé pour développer une vue d'ensemble de toutes les étapes nécessaires lors de la création d'un modèle, jusqu'à ce que celui-ci soit embarqué.
#
# Comme tout bon data scientist, l'utilisation de fonction existante sur internet est vitale !! En effet, l'intelligence artificielle est très présent de nos jours, donc si vous avez un problème, il est presque assuré que quelqu'un ait déjà eu le même !
#
# Le TP va se porter sur un sujet concret: la reconnaissance vocal. Ce sujet rentre dans le thème du Traitement automatique du langage naturel ou NLP [1]) où la demande en IA embarqué est très recherchée (ex. enceinte connecté, smartphone, smartwatches, ..). Pour cela, vous allez vous baser sur une base de données existante se trouvant Kaggle: the TensorFlow Speech Recognition Challenge. Kaggle est un site de competition permettant de récompenser les meilleurs modèles avec des prix décernés aux meilleurs modèles. Cette compétition a été organisée par Google, avec plus de 25 000$ à gagner. Certaines peuvent même dépasser le million de dollard (ex. Netflix Price) donc si vous avez soif d'argent ou que le l'IA vous plaît, allez y jeter un coup d'oeil !
#
# Dans ce projet, vous allez essayer de classer correctement les 12 labels présents dans cette base de donnée via un modèle de convolution 1D ou récursif que vous aurez optimisé. Puis, vous devrez visualiser la variation des performances de ce modèle en fonction de son allégement (dans une volonté de l'embarquer).
#
# Le Rapport devra être fait sur ce jupyter notebook, en Markdown (comme le texte que vous êtes en train de lire).
#
# Ce projet a pour but d'évaluer votre esprit critique, votre analyse d'un problème et votre regard critique sur vos performances. Pour cela, l'entraide est encouragée mais en aucun cas le plagiat. Merci de respecter cela (promis c'est pour votre bien). Expliquez bien votre démarche et la raison de vos choix !!
#
# Le projet sera découpé en 5 TPs de 4h. Un guide de progession sera affiché sur chaque partie pour connaître votre avancement.
#
# Ce projet va être découpé en plusieurs parties:
#
# 1. L'Analyse de la base de donnée.
# 2. L'état de l'art.
# 3. Le Preprocessing.
# 4. L'apprentissage du modèle.
# 5. Les résultats et discussions.
# 6. L'allégement du modèle.
# 7. La conclusion.

# %% [markdown]
# # Analyse de la base de données
#
# La première étape est de télecharger et d'analyser la base de donnée. Pour cela rendez vous sur le site de la compétition:
# https://www.kaggle.com/competitions/tensorflow-speech-recognition-challenge/overview
#
# Pensez à bien regarder la compétition en détail, cela pourra vous être très utile (comme par exemple trouver du code ou des articles).

# %% [markdown]
# # Information sur la base de donnée
#
# Tips: Parlez de tous ce que vous savez des données (quantité d'instances, les labels, la taille d'une time series, sa fréquence d'echantillonage, ...).
#
# Le dossier contient trois fichiers principaux :
# - Train.7z : Les données d'entraînement sont des enregistrements d'une seconde. La fréquence d'échantillonnage est de 16 KHz . Les labels à prédire sont : yes, no, up, down, left, right, on, off, stop, go.
#
# -Test.7z : Contient un dossier de 150,000+ fichiers au format wav.
#
# -Sample_submission.csv - Un exemple de rendu.
# Visualitation d'une donnée et analyse critique
#
# Tips: Faites un subplot de plusieurs labels différents pour voir visuellement les différences.

# %% [markdown]
# # Visualitation d'une donnée et analyse critique
#
# Tips: Faites un subplot de plusieurs labels différents pour voir visuellement les différences.
#
#     Ecrire votre texte ici.

# %%
import matplotlib.pyplot as plt
import numpy as np
import IPython.display as ipd
from scipy.io import wavfile

# %%
#from google.colab import drive # Pour google colab
#drive.mount('/content/drive')  # Pour google colab

# Ajouter ce dossier dans votre drive: https://drive.google.com/drive/folders/1AAiaDTWJzvS6NaZXE_dfJ603QWhhcl0R?usp=sharing
# train_data_path = '/home/zebre/Bureau/IATI/3A/IA_et_materiel/edge_computing/Edge_computing/data/tensorflow-speech-recognition-challenge/train/audio'

# %%
#Pour utiliser le notebook en local

#Préciser le path des données d'entrainements
train_data_path = '/home/zebre/Bureau/eddge_computing/Edge_computing/data/train/audio'

#Préciser le path des données de test
test_data_path = '/home/zebre/Bureau/eddge_computing/Edge_computing/data/test/audio'

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

# Chemin vers les données

labels = os.listdir(train_data_path)[1:]  # On ignore le premier fichier

# Sélection aléatoire de 9 labels
Random_Labels = np.random.choice(labels, size=9, replace=False)

plt.figure(figsize=(15, 8))

for i, label in enumerate(Random_Labels, 1):
    wav_files_path = os.path.join(train_data_path, label)
    random_wav = np.random.choice(os.listdir(wav_files_path))  # un fichier wav aléatoire
    sr, time_series = wavfile.read(os.path.join(wav_files_path, random_wav))

    plt.subplot(3, 3, i)
    plt.plot(time_series)
    plt.grid()
    plt.title(label)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Stockage des données
#  <font color="red"> **ATTENTION:** Respectez l'ordre des labels: 0 = yes, 1 = no, 2 = up, 3 = down, 4 = left, 5 = right, 6 = on, 7 = off, 8 = stop, 9 = go, 10 = silence, 11 = unknown </font>
#
# <font color=" Darkblue"> **Tips:** Réduisez la taille des données d'entrées afin d'éviter la saturation de la mémoire </font>

# %%
import os
import numpy as np
from scipy.io import wavfile
import pandas as pd  # Importer pandas

# Dictionnaire pour identifier les label
Data_Dict = {
      "yes": 0,
      "no": 1,
      "up": 2,
      "down": 3,
      "left": 4,
      "right": 5,
      "on": 6,
      "off": 7,
      "stop": 8,
      "go": 9,
      "_background_noise_": 10,
      "unknown": 11
}

# Dictionnaire inversé pour l'affichage (toujours utile)
ID_to_Label = {v: k for k, v in Data_Dict.items()}

# Constante utilisée dans le code pour représenter l'ID "unknown"
# On récupère la valeur depuis Data_Dict pour éviter NameError si la clé change.
UNKNOWN_ID = Data_Dict.get("unknown", Data_Dict.get("UNKNOWN_ID", 11))


def import_data_as_dataframe(max_files_per_label=100, data_path=train_data_path):
    all_waves, all_labels_id, all_labels_name = [], [], []

    for label in os.listdir(data_path):
        label_path = os.path.join(data_path, label)
        if not os.path.isdir(label_path):
            continue

        label_id = Data_Dict.get(label, Data_Dict["unknown"])
        label_name = ID_to_Label.get(label_id, "unknown")

        # Ne prendre que les fichiers .wav
        wav_files = [f for f in os.listdir(label_path) if f.endswith('.wav')]
        wav_files = wav_files[:max_files_per_label]

        for wav_file in wav_files:
            file_path = os.path.join(label_path, wav_file)
            sr, samples = wavfile.read(file_path)

            # Fixer la durée à 1 seconde (16000 échantillons)
            if len(samples) > 16000:
                samples = samples[:16000]
            else:
                samples = np.pad(samples, (0, 16000 - len(samples)))

            all_waves.append(samples)
            all_labels_id.append(label_id)
            all_labels_name.append(label_name) # Ajout du nom pour le DataFrame

    # Créer le DataFrame
    df = pd.DataFrame({
        'label_id': all_labels_id,
        'label_name': all_labels_name
        # Note : On ne met pas les 'waves' dans le DataFrame principal
        # car c'est lourd et peu pratique. On les retourne séparément.
    })
    
    return np.array(all_waves), df

def import_data(max_files_per_label=500, data_path=train_data_path):
    all_waves, all_labels = [], []
    
    # Compteur global pour les fichiers "unknown"
    unknown_count = 0 
    
    # Pour le suivi (debug)
    print(f"Démarrage de l'importation (max {max_files_per_label} par label ID)...")

    for folder_name in os.listdir(data_path):
        folder_path = os.path.join(data_path, folder_name)
        if not os.path.isdir(folder_path):
            continue

        label_id = Data_Dict.get(folder_name, UNKNOWN_ID)
        wav_files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]
        
        files_to_process = []
        
        # 1. Logique de Limite de Fichiers
        if label_id == UNKNOWN_ID:
            # S'assurer que le quota "unknown" n'est pas déjà atteint
            remaining_slots = max_files_per_label - unknown_count
            
            if remaining_slots <= 0:
                # Quota "unknown" déjà plein, passer au dossier suivant
                continue
            
            # Ne prendre que le nombre de fichiers nécessaire pour atteindre la limite
            num_files = min(len(wav_files), remaining_slots)
            files_to_process = wav_files[:num_files]
            
            # Mettre à jour le compteur global
            unknown_count += num_files
            
        else:
            # Pour les classes connues (ID 0 à 10), la limite est appliquée PAR DOSSIER
            files_to_process = wav_files[:max_files_per_label]

        print(f"  -> Dossier '{folder_name}' (ID {label_id}) : {len(files_to_process)} fichiers traités.")

        # 2. Traitement des Fichiers (Lecture, Padding, MFCC...)
        for wav_file in files_to_process:
            file_path = os.path.join(folder_path, wav_file)
            sr, samples = wavfile.read(file_path)

            # Fixer la durée à 1 seconde (16000 échantillons)
            if len(samples) > 16000:
                samples = samples[:16000]
            else:
                samples = np.pad(samples, (0, 16000 - len(samples)))

            all_waves.append(samples)
            all_labels.append(label_id)

    # Affichage du résultat final pour vérification
    print(f"\nImportation terminée.")
    print(f"Nombre total d'échantillons importés : {len(all_waves)}")
    print(f"Nombre de fichiers 'unknown' (ID {UNKNOWN_ID}) : {unknown_count}")
    
    return np.array(all_waves), np.array(all_labels)

# %%
all_waves,all_labels = import_data(max_files_per_label=1000)
# Out:
# Démarrage de l'importation (max 1000 par label ID)...
#   -> Dossier 'four' (ID 11) : 1000 fichiers traités.
#   -> Dossier 'no' (ID 1) : 1000 fichiers traités.
#   -> Dossier 'off' (ID 7) : 1000 fichiers traités.
#   -> Dossier 'yes' (ID 0) : 1000 fichiers traités.
#   -> Dossier 'up' (ID 2) : 1000 fichiers traités.
#   -> Dossier 'right' (ID 5) : 1000 fichiers traités.
#   -> Dossier 'on' (ID 6) : 1000 fichiers traités.
#   -> Dossier 'go' (ID 9) : 1000 fichiers traités.
#   -> Dossier 'down' (ID 3) : 1000 fichiers traités.
#   -> Dossier 'left' (ID 4) : 1000 fichiers traités.
#   -> Dossier '_background_noise_' (ID 10) : 6 fichiers traités.
#   -> Dossier 'stop' (ID 8) : 1000 fichiers traités.
#
# Importation terminée.
# Nombre total d'échantillons importés : 11006
# Nombre de fichiers 'unknown' (ID 11) : 1000
# /tmp/ipykernel_45397/425760613.py:113: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sr, samples = wavfile.read(file_path)

# %%
# Affichage des tailles
print(f'Taille des données : {all_waves.shape}')
print(f'Taille des labels : {all_labels.shape} \n')

# Exemple de donnée
id_exemple = 34
Exemple = [all_waves[id_exemple], all_labels[id_exemple]]
print(f"Exemple d'échantillon de données : {Exemple[0]}")
print(f"Exemple d'échantillon de label : {Exemple[1]} \n ")

# Récupérer le nom du label à partir de son ID
label_nom = [k for k, v in Data_Dict.items() if v == Exemple[1]][0]
print(f"L'exemple est un enregistrement du label : {label_nom}")

# Lecture audio
ipd.Audio(Exemple[0], rate=16000)
# Out:
# Taille des données : (11006, 16000)
# Taille des labels : (11006,)
#
# Exemple d'échantillon de données : [22 52 57 ...  0  0  0]
# Exemple d'échantillon de label : 11
#
# L'exemple est un enregistrement du label : unknown
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Etat de l'art
#
# Etape importante qui suit: faire un état de l'art. Que cela soit pour innover, ou pour trouver une solution existante pertinente, faire un état de l'art scientifique est essentiel. Ici, vous devez chercher les articles liés à ce projet. Il faut pour cela remplir le tableau et bien marquer leurs références en dessous. De plus, un texte synthétique vous sera demandé pour expliquer selon vous, quels papiers sont les plus pertinants pour la suite de ce projet.
#
# Attention: une analyse critique est nécessaire sur ces papiers (certain papiers peuvent avoir des biais cachés).
#
# <font color="orange"> **Note anti-plagiat:** Au moins 2 références devraient être différente des autres binômes. </font>
#
# &nbsp;
#
#
# <font color="Darkred"> Progression du TP après cette partie (environ 2h):
#
# &nbsp;
#
# ---
#
# Le véritable état de l'art pour ce défi est construit autour de deux axes majeurs : la définition du jeu de données et la conception d'architectures optimisées pour les contraintes d'embarqué.
#
# ### Tableau Récapitulatif
#
# | Article | Références | Preprocessing | Modèle | Solution Embarquée ? | Dataset utilisé | Performances (Baseline) |
# | :--- | :--- | :--- | :--- | :--- | :--- | :--- |
# | **Warden (2018) [1]** | [1] Speech Commands [cite: 1, 10] | Normalisation à 1 seconde, 16 KHz[cite: 1, 5]. Extraction de la section la plus forte pour l'alignement[cite: 1]. | CNN (Convolutional Neural Network) [cite: 1] – Inspiré de Sainath & Parada[cite: 1]. | **Oui, objectif principal.** Modèles petits, faible consommation d'énergie, minimisation des faux positifs[cite: 1]. | **Speech Commands Dataset v2** (105 829 énonciations de 35 mots)[cite: 1]. | **Top-One Accuracy : 88.2%** (Baseline CNN sur V2)[cite: 1]. |
# | **Zhang et al. (2017) [2]** | [2] Hello Edge [cite: 2] | Conversion du signal audio en **représentations 2D** (Spectrogrammes ou Mel-Spectrogrammes)[cite: 2]. | **DS-CNN** (Depthwise Separable CNN) – Architecture la plus efficace pour les contraintes de taille et de performance[cite: 2]. | **Oui.** Comparaison de l'efficacité des architectures pour l'exécution sur microcontrôleurs (CMSIS-NN)[cite: 2, 8]. | Similaire à [1] (Speech Commands V1)[cite: 2]. | Meilleur équilibre entre précision et efficacité énergétique/taille du modèle[cite: 2]. |
#
# ---
#
#
# ## Références
#
# Les références complètes (format IEEE) pour les sources utilisées dans cette analyse :
#
# 1.  P. Warden, "Speech Commands: A Dataset for Limited-Vocabulary Speech Recognition," *arXiv e-prints*, 2018, art. no. arXiv:1804.03209.
# 2.  Y. Zhang, N. Suda, L. Lai et V. Chandra, "Hello Edge: Keyword Spotting on Microcontrollers," *arXiv e-prints*, 2017, art. no. arXiv:1711.07128.
# 3.  (2018) Speech commands dataset version 2. [Online]. Available: http://download.tensorflow.org/data/speech_commands\_v0.02.tar.gz [cite: 1]
# 4.  (2017) Speech commands dataset version 1. [Online]. Available: http://download.tensorflow.org/data/speech\_commands\_v0.01.tar.gz [cite: 1]
# 5.  (2018) Linguistic data consortium. [Online]. Available: https://www.ldc.upenn.edu/ [cite: 1]
# 6.  J. Deng, W. Dong, R. Socher, L.-J. Li, K. Li, and L. Fei-Fei, "ImageNet: A Large-Scale Hierarchical Image Database," in CVPR09, 2009. [cite: 1]
# 7.  T. N. Sainath and C. Parada, "Convolutional Neural Networks for Small-Footprint Keyword Spotting," in Sixteenth Annual Conference of the International Speech Communication Association, 2015. [Online]. Available: https://www.isca-speech.org/archive/interspeech\_2015/papers/i15\_1478.pdf [cite: 1]
# 8.  L. Lai, N. Suda, and V. Chandra, "CMSIS-NN: Efficient Neural Network Kernels for Arm Cortex-M CPUs," ArXiv e-prints, Jan. 2018. [cite: 1]
# 9.  R. Tang and J. Lin, "Deep Residual Learning for Small-Footprint Keyword Spotting," ArXiv e-prints, Oct. 2017. [cite: 1]
# 10. S. Krishna Gouda, S. Kanetkar, D. Harrison, and M. K. Warmuth, "Speech Recognition: Keyword Spotting Through Image Recognition," ArXiv e-prints, Mar. 2018. [cite: 1]

# %% [markdown]
# ## Preprocessing
#
# C'est la partie la plus importante du projet !! Même le modèle le plus performant de la terre ne pourra pas être précis sans des données d'entrées propres. De plus, il est important de réduire la quantité de données d'entrée (Décimation) afin de ne pas avoir un modèle trop lourd.
#
# <font color=" Darkblue"> **Tips:** Commencez par un preprocessing simple, et améliorez le lorsque les modèles seront en cours d'apprentissage. </font>
#
# Voici quelques sources qui pourront vous être utile pour faire votre code, en plus de l'état de l'art précedemment fait:
# - https://medium.com/enjoy-algorithm/pre-processing-of-time-series-data-c50f8a3e7a98
# - https://monkeylearn.com/blog/data-preprocessing/
# - https://machinelearningmastery.com/machine-learning-data-transforms-for-time-series-forecasting/
# - https://haythamfayek.com/2016/04/21/speech-processing-for-machine-learning.html (pour les plus expérimenté d'entre vous)
#
# &nbsp;
#
# <font color=" Darkred"> Progression du TP après cette partie (environ 3h): </font>
# ![56%](https://progress-bar.dev/56)

# %% [markdown]
# ### Zone d'expérimentation
#
# Ici vous êtes libre d'essayer des choses, les visualiser, avoir un regard critique sur la solution que vous décidez de prendre. Utilisez autant de cases de codes et de textes.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.preprocessing import StandardScaler, MinMaxScaler

def Transformations(transformer, num_points=120):
    """
    Met en évidence l'effet de 5 transformations :
     - Power Transform : rend la distribution plus normale
     - Difference Transform : stationnarise la série
     - Seasonal Transform : enlève la saisonnalité
     - Standardisation : moyenne=0, variance=1
     - Normalisation : valeurs entre 0 et 1
    """

    fig, ax = plt.subplots(1, 2, figsize=(14, 5))

    if transformer == 'Power Transform':
        data = np.random.exponential(2.0, num_points)
        data_boxcox, λ = stats.boxcox(data)
        to_plot = [data, data_boxcox]
        titles = ['Raw Data', f'Power Transform (λ = {λ:.3f})']

    elif transformer == 'Difference Transform':
        t = np.arange(num_points)
        data = 0.5 * t + np.random.normal(0, 5, num_points)
        data_diff = np.diff(data, n=1)
        ax[0].plot(t, data); ax[0].set_title('Données brutes (avec tendance)')
        ax[1].plot(t[1:], data_diff); ax[1].set_title('Après différence (stationnaire)')
        for a in ax: a.grid()
        plt.show()
        return

    elif transformer == 'Seasonal Transform':
        # Série avec tendance et saisonnalité
        t = np.arange(num_points)
        period = 12
        data = 10 + 0.3*t + 5*np.sin(2*np.pi*t/period) + np.random.normal(0, 1, num_points)
        # Seasonal difference
        data_seasonal_diff = data[period:] - data[:-period]
        ax[0].plot(t, data); ax[0].set_title('Données brutes (avec saisonnalité)')
        ax[1].plot(t[period:], data_seasonal_diff); ax[1].set_title(f'Après différence saisonnière (période={period})')
        for a in ax: a.grid()
        plt.show()
        return

    elif transformer == 'Standardisation':
        data = 20 + np.sqrt(5) * np.random.normal(scale=5.0, size=(num_points, 1))
        data_trans = StandardScaler().fit_transform(data)
        to_plot = [data, data_trans]
        titles = ['Données brutes', 'Standardisées ']

    elif transformer == 'Normalisation':
        data = 20 + np.sqrt(5) * np.random.normal(scale=5.0, size=(num_points, 1))
        data_trans = MinMaxScaler().fit_transform(data)
        to_plot = [data, data_trans]
        titles = ['Données brutes', 'Normalisées [0,1]']

    else:
        raise ValueError("Transformer doit être l’un des suivants : "
                         "'Power Transform', 'Difference Transform', 'Seasonal Transform', 'Standardisation', 'Normalisation'.")

    # Affichage commun (histogrammes)
    for i, (d, title) in enumerate(zip(to_plot, titles)):
        ax[i].hist(d, bins=30, edgecolor='black')
        ax[i].set_title(title)
        ax[i].set_xlabel('Valeur')
        ax[i].set_ylabel('Fréquence')
        ax[i].grid()

    plt.tight_layout()
    plt.show()

# %%
# Décommenter pour tester la transformation

#Transformations('Power Transform')
#Transformations('Difference Transform')
#Transformations('Seasonal Transform')
#Transformations('Standardisation')
#Transformations('Normalisation')

# %% [markdown]
# **PS** : En général, l'ordre à suivre pour faire du preprocessing avec ces fonctions est : Power Transform, Seasonal Difference, Trend Difference,Standardization, Normalization.

# %%
# ===========================================================
# Fonctions de prétraitement audio (inspirées de la doc)
# ===========================================================

import numpy as np
from scipy.fftpack import dct
from sklearn.preprocessing import MinMaxScaler

def To_normalize(signal, eps=1e-8):
    """Normalise un enregistrement audio en [-1, 1] par son max absolu."""
    signal = signal.astype(np.float32)
    max_abs = np.max(np.abs(signal)) + eps
    return signal / max_abs

def pre_emphasis_filter(signal, coefficient=0.97):
    """"Filtre numérique passe haut (dérivateur) amplififiant les hautes fréquence, fc = 100Hz (valeur classique)"""
    return signal - coefficient * np.roll(signal, 1)


def framing(signal, frame_length, frame_step, sample_rate):
    """Découpe le signal en trames de durée fixe (fenêtrage temporel)."""
    signal_length = len(signal)
    frame_length = int(round(frame_length * sample_rate))
    frame_step = int(round(frame_step * sample_rate))

    num_frames = int(np.floor((signal_length - frame_length) / frame_step)) + 1
    pad_signal_length = num_frames * frame_step + frame_length
    z = np.zeros((pad_signal_length - signal_length))
    pad_signal = np.append(signal, z)

    indices = np.tile(np.arange(0, frame_length), (num_frames, 1)) + \
              np.tile(np.arange(0, num_frames * frame_step, frame_step), (frame_length, 1)).T

    frames = pad_signal[indices.astype(np.int32, copy=False)]
    return frames


def window_hamming(frames):
    """Applique une fenêtre de Hamming pour lisser les trames."""
    frame_length = len(frames[0])
    windowed_frames = np.zeros(frames.shape)
    for i in range(len(frames)):
        windowed_frames[i] = frames[i] * np.hamming(frame_length)
    return windowed_frames


def fft(windowed_frames, NFFT=512):
    """Calcule le spectre de puissance de chaque trame (FFT)."""
    mag_frames = np.absolute(np.fft.rfft(windowed_frames, NFFT))
    pow_frames = ((1.0 / NFFT) * (mag_frames ** 2))
    return pow_frames


def filter_bank(pow_frames, sample_rate, NFFT=512, nfilt=40):
    """Applique un banc de filtres de Mel pour regrouper les fréquences."""
    low_freq_mel = 0
    high_freq_mel = 2595 * np.log10(1 + (sample_rate / 2) / 700)
    mel_points = np.linspace(low_freq_mel, high_freq_mel, nfilt + 2)
    hz_points = 700 * (10**(mel_points / 2595) - 1)
    bin = np.floor((NFFT + 1) * hz_points / sample_rate)

    fbank = np.zeros((nfilt, int(np.floor(NFFT / 2 + 1))))
    for m in range(1, nfilt + 1):
        f_m_minus = int(bin[m - 1])
        f_m = int(bin[m])
        f_m_plus = int(bin[m + 1])

        for k in range(f_m_minus, f_m):
            fbank[m - 1, k] = (k - bin[m - 1]) / (bin[m] - bin[m - 1])
        for k in range(f_m, f_m_plus):
            fbank[m - 1, k] = (bin[m + 1] - k) / (bin[m + 1] - bin[m])

    filter_banks = np.dot(pow_frames, fbank.T)
    filter_banks = np.where(filter_banks == 0, np.finfo(float).eps, filter_banks)
    filter_banks = 20 * np.log10(filter_banks)
    return filter_banks


def mfcc_coeffs(filter_banks, num_ceps=12, ceplifter=22):
    """Extrait les coefficients cepstraux MFCC à partir des filtres de Mel."""
    mfcc = dct(filter_banks, type=2, axis=1, norm='ortho')[:, 1:(num_ceps + 1)]
    (nframes, ncoeff) = mfcc.shape
    n = np.arange(ncoeff)
    lift = 1 + (ceplifter / 2) * np.sin(np.pi * n / ceplifter)
    mfcc *= lift
    return mfcc


def Mean_Norm(Data):
    """Centre les données (MFCC ou filter banks) autour de leur moyenne."""
    Mean_Data = np.zeros(Data.shape)
    for i in range(Data.shape[0]):
        Mean_Data[i] = Data[i] - np.mean(Data[i])
    return Mean_Data

# %%
import librosa
import librosa.display

# Visualisation de l'effet des fonctions précédentes

# Chemin vers les données
labels = os.listdir(train_data_path)[1:]  # On ignore le premier fichier

# Sélection aléatoire d'un fichier wav
Random_Label = np.random.choice(labels, size=len(labels), replace=False)
wav_files_path = os.path.join(train_data_path, Random_Labels[0])
random_wav = np.random.choice(os.listdir(wav_files_path))  # un fichier wav aléatoire
sr, signal = wavfile.read(os.path.join(wav_files_path, random_wav))

# Application des transformations
signal = signal / np.max(np.abs(signal)) # Normalisation
emphasized_signal = pre_emphasis_filter(signal)
frames = framing(signal, frame_length=0.025, frame_step=0.01, sample_rate=sr) # fenêtres de 25ms
windowed_frames = window_hamming(frames)
pow_frames = fft(windowed_frames)
log_spectrogram = 10 * np.log10(pow_frames.T + 1e-8) # Pour la visualisation
filter_banks = filter_bank(pow_frames, sample_rate = sr)
filter_banks = Mean_Norm(filter_banks)
mfcc = mfcc_coeffs(filter_banks, num_ceps=12, ceplifter=22)
mfcc = Mean_Norm(mfcc)


# Débogage
print(f'Taille du signal :{signal.shape}')
print(f'Taille du signal filtré :{emphasized_signal.shape}')
print(f'Taille des fenêtres :{frames.shape}')
print(f'Taille des fenêtres après hamming :{windowed_frames.shape}')
print(f'Taille des fenêtres après fft :{pow_frames.shape}')
print(f'Taille du spectrogramme :{log_spectrogram.shape}')
print(f'Taille des filter banks :{filter_banks.shape}')
print(f'Taille des MFCCs :{mfcc.shape}')

### Affichage des figures

# Signaux Temporels
plt.figure(figsize=(18, 6))
plt.subplot(1, 3, 1)
plt.plot(np.arange(len(signal))/sr,signal)
plt.xlabel("Temps (s)")
plt.ylabel("Amplitude")
plt.grid()
plt.title('Données brutes')

plt.subplot(1, 3, 2)
plt.plot(np.arange(len(emphasized_signal))/sr,emphasized_signal)
plt.xlabel("Temps (s)")
plt.ylabel("Amplitude")
plt.grid()
plt.title('Données filtrées')

plt.subplot(1, 3, 3)
plt.plot(np.arange(len(windowed_frames)),np.mean(windowed_frames, axis=1))
plt.xlabel("Temps (s)")
plt.ylabel("Amplitude")
plt.title('Données après hamming')
plt.grid()

# Signaux Fréquentiels
plt.figure(figsize=(18, 6))
plt.subplot(1, 3, 1)
librosa.display.specshow(log_spectrogram,
                         sr=sr,
                         hop_length=int(0.01 * sr),
                         x_axis='time',
                         y_axis='linear',
                         cmap='turbo')
plt.title('Spectrogramme (FFT par trame)')
plt.xlabel("Temps (s)")
plt.ylabel("Fréquence (Hz)")

plt.subplot(1, 3, 2)
librosa.display.specshow(filter_banks.T, sr=sr, hop_length=int(0.01*sr),
                         x_axis='time', y_axis='mel', cmap='turbo')
plt.xlabel("Temps (s)")
plt.title("Bancs de filtres Mel (énergies en dB)")

plt.subplot(1,3,3)
librosa.display.specshow(mfcc.T, sr=sr, hop_length=int(0.01*sr),
                         x_axis='time', cmap='turbo')
plt.xlabel("Temps (s)")
plt.title("MFCC (Coefficients Cepstraux)")

plt.tight_layout()
plt.show()
# Out:
# Taille du signal :(16000,)
# Taille du signal filtré :(16000,)
# Taille des fenêtres :(98, 400)
# Taille des fenêtres après hamming :(98, 400)
# Taille des fenêtres après fft :(98, 257)
# Taille du spectrogramme :(257, 98)
# Taille des filter banks :(98, 40)
# Taille des MFCCs :(98, 12)

# %% [markdown]
# Pour de l'audio, les démarches à suivre sont donc :
# **Normalisation de l'audio → Pré-accentuation → framing → Fenêtrage → FFT → Banc de filtres Mel → Calcul des MFCC → Normalisation des coefficients.**

# %% [markdown]
# ### Fonction de preprocessing
#
# > **Ecrire votre texte ici.**

# %%
def To_normalize(signal, eps=1e-8):
    """Normalise un enregistrement audio en [-1, 1] par son max absolu."""
    signal = signal.astype(np.float32)
    max_abs = np.max(np.abs(signal)) + eps
    return signal / max_abs


def preprocessing(inputs,
                  type='mfccs',
                  sample_rate=16000,
                  frame_length=0.025,
                  frame_step=0.01,
                  NFFT=512,
                  nfilt=40,
                  num_ceps=12,
                  ceplifter=22):
    """
    inputs : array de forme (nb_fichiers, 16000)
    type   : 'mfccs' | 'spectrogramme' | 'mel'
    """
    clean_inputs = []
    eps = 1e-8

    for i in range(inputs.shape[0]):
        # 1) Normalisation par enregistrement
        x = To_normalize(inputs[i])               # (16000,)

        # 2) Pré-accentuation
        x = pre_emphasis_filter(x)                # (16000,)

        # 3) Framing + fenêtre de Hamming
        frames = framing(x,
                         frame_length=frame_length,
                         frame_step=frame_step,
                         sample_rate=sample_rate)  # (~nb_frames, frame_len)
        windowed_frames = window_hamming(frames)

        # 4) FFT -> spectre de puissance
        pow_frames = fft(windowed_frames, NFFT=NFFT)

        if type == 'mfccs':
            # Banc de filtres Mel
            filter_banks = filter_bank(pow_frames,
                                       sample_rate=sample_rate,
                                       NFFT=NFFT,
                                       nfilt=nfilt)
            filter_banks = Mean_Norm(filter_banks)

            # MFCC
            mfcc = mfcc_coeffs(filter_banks,
                               num_ceps=num_ceps,
                               ceplifter=ceplifter)
            mfcc = Mean_Norm(mfcc)

            max_abs = max(np.max(np.abs(mfcc)), eps)
            clean_inputs.append(mfcc / max_abs)

        elif type == 'spectrogramme':
            # Spectrogramme log
            log_spectrogram = 10 * np.log10(
                np.clip(pow_frames.T, a_min=eps, a_max=None)
            )
            max_abs = max(np.max(np.abs(log_spectrogram)), eps)
            clean_inputs.append(log_spectrogram / max_abs)

        elif type == 'mel':
            # Banc de filtres Mel sans DCT
            filter_banks = filter_bank(pow_frames,
                                       sample_rate=sample_rate,
                                       NFFT=NFFT,
                                       nfilt=nfilt)
            filter_banks = Mean_Norm(filter_banks)
            max_abs = max(np.max(np.abs(filter_banks)), eps)
            clean_inputs.append(filter_banks / max_abs)

        else:
            raise ValueError("type doit être 'mfccs', 'spectrogramme' ou 'mel'.")

    return np.array(clean_inputs, dtype=np.float32)

# %%
'''
print(f'Input before preprocessing: {all_waves.shape}')
processed_waves = preprocessing(all_waves)
print(f'Input after preprocessing: {processed_waves.shape}')
'''
# Out:
# "\nprint(f'Input before preprocessing: {all_waves.shape}')\nprocessed_waves = preprocessing(all_waves)\nprint(f'Input after preprocessing: {processed_waves.shape}')\n"

# %% [markdown]
# Etant donné que le processing prend 15min pour éviter cette étape redondante nous avons chosie de sauveharder les données dans un fichier 'preprocessed_audio.npz'. Le code en dessous est à commenté pour utiliser nos données pré-process.

# %%
'''
print("Sauvegarde des données en cours...")
# 'X' et 'y' sont les noms que nous donnons aux "clés" dans le fichier
np.savez_compressed(
    'preprocessed_audio_mfcc', 
    X=processed_waves, 
    y=all_labels
)
print("Données sauvegardées dans 'code/preprocessed_audio_mfcc.npz'")
'''
# Out:
# '\nprint("Sauvegarde des données en cours...")\n# \'X\' et \'y\' sont les noms que nous donnons aux "clés" dans le fichier\nnp.savez_compressed(\n    \'preprocessed_audio_mfcc\', \n    X=processed_waves, \n    y=all_labels\n)\nprint("Données sauvegardées dans \'code/preprocessed_audio_mfcc.npz\'")\n'

# %% [markdown]
# Pour charger ces données.

# %%
print("Chargement des données depuis le fichier 'preprocessed_audio_mfcc'")
# Charger le fichier .npz
data_file = np.load('preprocessed_audio_mfcc.npz')

# On accéde aux variables par les clés 
X_train_processed = data_file['X']
y_train_processed = data_file['y']

print(f"Données chargées ! Forme X: {X_train_processed.shape}, Forme y: {y_train_processed.shape}")
# Out:
# Chargement des données depuis le fichier 'preprocessed_audio_mfcc'
# Données chargées ! Forme X: (11006, 98, 12), Forme y: (11006,)

# %% [markdown]
# ## Apprentissage du Modèle
# On y est, il est temps de créer un modèle. Pour cela, il vous sera imposé d'utiliser un réseau de convolution 1D [2] (https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv1D). Nous préconisons l'utilisation de Tensorflow mais vous êtes libre d'utiliser d'autres librairies comme Pytorch.
#
# &nbsp;
#
# <font color=" Darkred"> Progression du TP après cette partie (environ 3h): </font>
# ![75%](https://progress-bar.dev/75)

# %% [markdown]
# ### Train set, Validation set
#
# Avant d'entraîner votre modèle, pensez à séparer vos données d'entraînements et vos données de validations. Puis, pensez à créer des batchs pour correspondre à l'entrée de votre modèle.
#
# Plus d'infos ici:
#  - https://www.tensorflow.org/datasets/splits?hl=fr
#  - https://towardsdatascience.com/how-to-split-a-dataframe-into-train-and-test-set-with-python-eaa1630ca7b3
#  - https://www.tensorflow.org/tutorials/customization/custom_training_walkthrough?hl=fr
#
#  <font color=" Darkblue"> **Tips:** Pensez à bien mélanger vos données avant de les séparer. </font>
#
#  <font color="orange"> **Note anti-plagiat:** Le mélange doit avoir une random seed fixe et différente pour chaque groupe. </font>

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split

# Définirion de la seed 
tf.random.set_seed(42)

# Toutes les données
X_Data = X_train_processed
y_Data = y_train_processed
NUM_CLASSES = 12

# 1. Division initiale : Entraînement (80%) et Temporaire (20%)
X_train, x_temp, y_train, y_temp = train_test_split(X_Data, y_Data, test_size=0.3, random_state=42)

# 2. Division de l'ensemble Temporaire : Validation (10%) et Test (10%)
X_val, X_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

print(f"Taille de l'ensemble d'entraînement: {X_train.shape[0]}")
print(f"Taille de l'ensemble de validation: {X_val.shape[0]}")
print(f"Taille de l'ensemble de test: {X_test.shape[0]} \n")

# 3. Encodage des données
y_train = tf.keras.utils.to_categorical(y_train, num_classes=NUM_CLASSES)
y_val = tf.keras.utils.to_categorical(y_val, num_classes=NUM_CLASSES)

# 4. Préparation des Datasets de tf
BATCH_SIZE = 64

X_train = np.expand_dims(X_train, axis=-1)
train = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train = train.batch(BATCH_SIZE, drop_remainder=True)

X_val = np.expand_dims(X_val, axis=-1)
val = tf.data.Dataset.from_tensor_slices((X_val, y_val))
val = val.batch(BATCH_SIZE, drop_remainder=True)

# 5. Vérification des Dimensions
for example_inputs, example_labels in train.take(1):
    print(f'Inputs shape (batch, time/frames, features): {example_inputs.shape}')
    print(f'Labels shape (batch, num_classes): {example_labels.shape}')
# Out:
# Taille de l'ensemble d'entraînement: 7704
# Taille de l'ensemble de validation: 1651
# Taille de l'ensemble de test: 1651
#
# Inputs shape (batch, time/frames, features): (64, 98, 12, 1)
# Labels shape (batch, num_classes): (64, 12)

# %% [markdown]
# ### Baseline
#
# La baseline est importante afin de connaître le seuil où le modèle est performant. A vous de trouver la meilleure baseline et d'expliquer votre choix.
#
# Plus d'infos ici:
# https://towardsdatascience.com/calculating-a-baseline-accuracy-for-a-classification-model-a4b342ceb88f
#
# > **Ecrire votre texte ici.**

# %% [markdown]
# La baseline de notre modèle doit être fixé de sorte a dépassé le Zero Rate, c'est à dire la fréquence de la classe la plus fréquente. On créer la fonction qui nous permets de calculer ce score.

# %%
def calculate_zeroR_with_pandas(labels_series):
    """
    Calcule la précision du ZeroR à partir de nos données.
    """
    if labels_series.empty:
        return 0.0, None, None

    # 1. Compter la fréquence de chaque label (plus simple avec value_counts)
    # value_counts() trie déjà par fréquence (décroissant)
    label_counts = labels_series.value_counts()
    
    # 2. Identifier la classe majoritaire
    major_label_name = label_counts.index[0]
    major_label_count = label_counts.iloc[0]
    
    # 3. Calculer le taux de précision
    total_samples = len(labels_series)
    zeroR_accuracy = major_label_count / total_samples
    
    return zeroR_accuracy, major_label_name

# %% [markdown]
# Boucle pour calculer la baseline à partir datasframe pandas

# %%
# 1. Importer les données
waves, labels_df = import_data_as_dataframe(max_files_per_label=1000, data_path=train_data_path)

print(f"Total d'échantillons importés: {len(labels_df)}")
print("-" * 30)
print("Aperçu du DataFrame des labels :")
print(labels_df.head())
print("-" * 30)

# 2. Calculer le ZeroR
# Nous utilisons la colonne 'label_name' pour des résultats lisibles
accuracy, major_label = calculate_zeroR_with_pandas(labels_df['label_name'])

# 3. Afficher les résultats
print(f"Classe majoritaire (ZeroR): '{major_label}'")
print(f"Précision du ZeroR (Baseline) : {accuracy:.4f} (soit {accuracy*100:.2f}%)")
# Out:
# /tmp/ipykernel_45397/425760613.py:47: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sr, samples = wavfile.read(file_path)
# Total d'échantillons importés: 30006
# ------------------------------
# Aperçu du DataFrame des labels :
#    label_id label_name
# 0        11    unknown
# 1        11    unknown
# 2        11    unknown
# 3        11    unknown
# 4        11    unknown
# ------------------------------
# Classe majoritaire (ZeroR): 'unknown'
# Précision du ZeroR (Baseline) : 0.6665 (soit 66.65%)

# %% [markdown]
# On as donc une baseline de 0.67 à dépassé d'après le ZeroR.

# %%
# TO DO
result_train, result_val = 0, 0 # à effacer

print(f'Train dataset: {result_train}%')
print(f'Validation dataset: {result_val}%')
# Out:
# Train dataset: 0%
# Validation dataset: 0%

# %% [markdown]
# ### Modèle
#
# Vous devez créer une fonction permettant de générer le modèle. Celle-ci doit pouvoir être modifiable en fonction des Hyperparamètres mis en entrée.
#
#  <font color="red"> **ATTENTION:** Une limite de 150 000 paramètres est imposés. </font>
#
# Justification de vos choix (Choix des paramètres modifiables, fonction d'activations, nombres de couches, regularizers, ...) :
# > **Ecrire votre texte ici.**

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# %%
def total_param(model):
  """Calcule et affiche le nombre total de paramètres du modèle."""
  total_params = model.count_params()
  print(f"Nombre de poids du modèle: {total_params:,}")
  return total_params


def create_model(param, input_shape, num_classes):
  """
  Crée un modèle DS-CNN (Depthwise Separable CNN) pour une entrée 2D (ex: MFCCs).
  Les hyperparamètres sont contrôlés par le dictionnaire 'param'.
  """
  model = models.Sequential()

  # --- Couche d'Entrée ---
  model.add(layers.Input(shape=input_shape))

  # --- Bloc Conv2D Standard (pour l'extraction initiale) ---
  model.add(layers.Conv2D(param['conv_filters'], (5, 5), 
                           strides=(1, 1), 
                           padding='same', 
                           activation=param['activation']))
  model.add(layers.BatchNormalization())

  # --- Bloc DS-CNN 1 --- couche clé : SeparableConv2D
  model.add(layers.SeparableConv2D(param['ds_filters_1'], (5, 5), 
                                    padding='same', 
                                    activation=param['activation']))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))

  # --- Bloc DS-CNN 2 ---
  model.add(layers.SeparableConv2D(param['ds_filters_2'], (5, 5), 
                                    padding='same', 
                                    activation=param['activation']))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))

  # --- Tête de Classification ---
  model.add(layers.GlobalAveragePooling2D())
  
  model.add(layers.Dense(param['dense_units'], activation=param['activation']))
  model.add(layers.Dropout(param['dropout_rate']))
  
  # Couche de sortie finale
  model.add(layers.Dense(num_classes, activation='softmax'))
  
  return model
 
# PARAMÈTRES MIS À JOUR (pour le DS-CNN)
param = {
    'activation' : 'relu',
    'conv_filters' : 32,    # Filtres pour la première couche Conv2D
    'ds_filters_1' : 64,    # Filtres pour le premier bloc DS-CNN
    'ds_filters_2' : 64,   # Filtres pour le second bloc DS-CNN
    'dense_units' : 32,     # Neurones dans la couche dense finale
    'dropout_rate' : 0.5      # Taux de dropout pour la régularisation
}

INPUT_SHAPE = (257, 98, 1) # 98 timesteps, 1 canal, 12 coefficients MFCC
NUM_CLASSES= 12

model = create_model(param, INPUT_SHAPE, NUM_CLASSES)

model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 257, 98, 32)    │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 257, 98, 32)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d_8              │ (None, 257, 98, 64)    │         2,912 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 257, 98, 64)    │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 128, 49, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d_9              │ (None, 128, 49, 64)    │         5,760 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 128, 49, 64)    │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 64, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_4      │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 12)             │           396 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,620 (49.30 KB)
#  Trainable params: 12,300 (48.05 KB)
#  Non-trainable params: 320 (1.25 KB)

# %% [markdown]
# ### Fonction d'entraînement
#
# Cette fonction doit prendre un modèle en entrée et l'entrainer grâce au Train set. Puis, retourner les performances obtenues avec le Validation set.
#
# Pour les plus expérimentés d'entre vous: Vous pouvez réaliser une cross validation [[2]](https://datascientest.com/cross-validation).
#
# Justification de vos choix (Choix des paramètres modifiables, optimizer, nombres d'epoch, learning rate, ...) :
# > **Ecrire votre texte ici.**

# %%
def compile_and_fit(model, train, val, param, verbose=1):
    
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                    patience=20, # 20 est bien
                                                    mode='min',
                                                    restore_best_weights=True) # Important !

    # Pour les plus confirmés
    lr = tf.optimizers.schedules.ExponentialDecay(
         initial_learning_rate=1e-2,
         decay_steps=1000,
         decay_rate=0.95)

    # lr =  1e-3 # Augmentation du LR

    model.compile(loss='categorical_crossentropy', 
                metrics=['accuracy',
                tf.keras.metrics.Precision(name='precision'),
                tf.keras.metrics.Recall(name='recall')])

    # 1. Capturer l'historique de l'entraînement
    history = model.fit(train, epochs=train_param['max_epochs'],
                      validation_data=val,
                      callbacks=[early_stopping], 
                      verbose=verbose)

    # 2. Évaluer le modèle (qui a restauré les meilleurs poids)
    validation_evaluation = model.evaluate(val, verbose=0) # verbose=0 pour nettoyer la sortie
    
    # 3. Renvoyer les résultats
    return validation_evaluation, model, history


train_param = {
    # Exemple de paramètres à modifier
    'max_epochs' : 1000,
    'BATCH_SIZE' : 64
}

def plot_training_history(history):
    """
    Trace les courbes d'apprentissage pour la perte, l'accuracy, la précision 
    et le rappel (training vs validation).
    """
    
    # Données de l'historique
    history_data = history.history
    
    # Noms des métriques
    loss = history_data['loss']
    val_loss = history_data['val_loss']
    accuracy = history_data['accuracy']
    val_accuracy = history_data['val_accuracy']
    precision = history_data['precision']
    val_precision = history_data['val_precision']
    recall = history_data['recall']
    val_recall = history_data['val_recall']
    
    epochs = range(1, len(accuracy) + 1)

    # --- Plot 1: Perte (Loss) ---
    plt.figure(figsize=(14, 7))
    plt.subplot(1, 2, 1) # Grille 1x2, premier graphique
    plt.plot(epochs, loss, 'bo-', label='Perte (Entraînement)')
    plt.plot(epochs, val_loss, 'r*-', label='Perte (Validation)')
    plt.title('Courbe de Perte (Loss)')
    plt.xlabel('Époques')
    plt.ylabel('Perte')
    plt.legend()
    plt.grid(True)

    # --- Plot 2: Précision (Accuracy) ---
    plt.subplot(1, 2, 2) # Grille 1x2, deuxième graphique
    plt.plot(epochs, accuracy, 'bo-', label='Accuracy (Entraînement)')
    plt.plot(epochs, val_accuracy, 'r*-', label='Accuracy (Validation)')
    plt.title('Courbe de Précision (Accuracy)')
    plt.xlabel('Époques')
    plt.ylabel('Précision')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout() # Ajuste l'espacement
    plt.show() # Affiche les deux premiers graphiques

    # --- Plot 3: Précision (Precision) vs Rappel (Recall) ---
    plt.figure(figsize=(14, 7))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, precision, 'bo-', label='Précision (Entraînement)')
    plt.plot(epochs, val_precision, 'r*-', label='Précision (Validation)')
    plt.title('Courbe de Précision (Precision)')
    plt.xlabel('Époques')
    plt.ylabel('Précision')
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs, recall, 'bo-', label='Rappel (Entraînement)')
    plt.plot(epochs, val_recall, 'r*-', label='Rappel (Validation)')
    plt.title('Courbe de Rappel (Recall)')
    plt.xlabel('Époques')
    plt.ylabel('Rappel')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show() # Affiche les deux derniers graphiques

# validation_accuracy = compile_and_fit(model, train, val, param)

# %%
# (Assurez-vous que 'model', 'train', 'val', et 'param' sont définis)

# 1. Exécutez l'entraînement ET récupérez l'historique
print("Lancement de l'entraînement...")
validation_eval, trained_model, history = compile_and_fit(model, train, val, param)

print("\nÉvaluation finale sur le set de validation :", validation_eval)

# 2. Tracez les graphiques
print("Affichage des courbes d'apprentissage...")
plot_training_history(history)
# Out:
# Lancement de l'entraînement...
# Epoch 1/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.2059 - loss: 2.2929 - precision: 0.6379 - recall: 0.0048 - val_accuracy: 0.0850 - val_loss: 2.4854 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3691 - loss: 1.8656 - precision: 0.7494 - recall: 0.0759 - val_accuracy: 0.0981 - val_loss: 2.4593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4827 - loss: 1.5496 - precision: 0.7936 - recall: 0.1983 - val_accuracy: 0.1300 - val_loss: 2.3667 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5570 - loss: 1.3223 - precision: 0.8065 - recall: 0.2962 - val_accuracy: 0.3306 - val_loss: 1.8910 - val_precision: 0.8472 - val_recall: 0.0763
# Epoch 5/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6182 - loss: 1.1473 - precision: 0.8150 - recall: 0.3958 - val_accuracy: 0.6888 - val_loss: 1.1144 - val_precision: 0.9286 - val_recall: 0.3088
# Epoch 6/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6581 - loss: 1.0021 - precision: 0.8276 - recall: 0.4737 - val_accuracy: 0.7013 - val_loss: 0.9197 - val_precision: 0.8807 - val_recall: 0.5169
# Epoch 7/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6943 - loss: 0.9127 - precision: 0.8435 - recall: 0.5299 - val_accuracy: 0.7500 - val_loss: 0.7796 - val_precision: 0.8507 - val_recall: 0.6375
# Epoch 8/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7229 - loss: 0.8316 - precision: 0.8530 - recall: 0.5741 - val_accuracy: 0.7156 - val_loss: 0.8688 - val_precision: 0.8256 - val_recall: 0.6212
# Epoch 9/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7388 - loss: 0.7763 - precision: 0.8673 - recall: 0.6120 - val_accuracy: 0.7531 - val_loss: 0.7304 - val_precision: 0.8108 - val_recall: 0.6938
# Epoch 10/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7592 - loss: 0.7131 - precision: 0.8643 - recall: 0.6444 - val_accuracy: 0.7125 - val_loss: 0.8421 - val_precision: 0.7937 - val_recall: 0.6494
# Epoch 11/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7762 - loss: 0.6750 - precision: 0.8799 - recall: 0.6764 - val_accuracy: 0.7006 - val_loss: 0.9427 - val_precision: 0.7657 - val_recall: 0.6538
# Epoch 12/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7943 - loss: 0.6314 - precision: 0.8804 - recall: 0.7013 - val_accuracy: 0.8006 - val_loss: 0.6194 - val_precision: 0.8591 - val_recall: 0.7619
# Epoch 13/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8027 - loss: 0.6053 - precision: 0.8878 - recall: 0.7160 - val_accuracy: 0.7600 - val_loss: 0.7678 - val_precision: 0.8133 - val_recall: 0.7131
# Epoch 14/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8087 - loss: 0.5693 - precision: 0.8872 - recall: 0.7249 - val_accuracy: 0.8462 - val_loss: 0.4697 - val_precision: 0.8883 - val_recall: 0.8150
# Epoch 15/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8251 - loss: 0.5472 - precision: 0.8963 - recall: 0.7509 - val_accuracy: 0.8181 - val_loss: 0.5785 - val_precision: 0.8693 - val_recall: 0.7900
# Epoch 16/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8297 - loss: 0.5299 - precision: 0.8988 - recall: 0.7595 - val_accuracy: 0.8181 - val_loss: 0.5492 - val_precision: 0.8557 - val_recall: 0.7969
# Epoch 17/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8341 - loss: 0.5070 - precision: 0.8993 - recall: 0.7664 - val_accuracy: 0.8313 - val_loss: 0.5786 - val_precision: 0.8672 - val_recall: 0.8081
# Epoch 18/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8410 - loss: 0.4837 - precision: 0.9043 - recall: 0.7850 - val_accuracy: 0.8281 - val_loss: 0.5620 - val_precision: 0.8715 - val_recall: 0.8094
# Epoch 19/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8504 - loss: 0.4663 - precision: 0.9073 - recall: 0.7935 - val_accuracy: 0.8294 - val_loss: 0.5389 - val_precision: 0.8622 - val_recall: 0.8131
# Epoch 20/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8559 - loss: 0.4416 - precision: 0.9129 - recall: 0.8048 - val_accuracy: 0.8419 - val_loss: 0.5052 - val_precision: 0.8797 - val_recall: 0.8225
# Epoch 21/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8591 - loss: 0.4195 - precision: 0.9142 - recall: 0.8139 - val_accuracy: 0.7788 - val_loss: 0.7156 - val_precision: 0.8127 - val_recall: 0.7619
# Epoch 22/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8646 - loss: 0.4221 - precision: 0.9148 - recall: 0.8134 - val_accuracy: 0.8519 - val_loss: 0.4740 - val_precision: 0.8825 - val_recall: 0.8400
# Epoch 23/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8707 - loss: 0.4004 - precision: 0.9242 - recall: 0.8292 - val_accuracy: 0.8500 - val_loss: 0.5134 - val_precision: 0.8810 - val_recall: 0.8331
# Epoch 24/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8733 - loss: 0.3955 - precision: 0.9279 - recall: 0.8362 - val_accuracy: 0.8419 - val_loss: 0.4977 - val_precision: 0.8811 - val_recall: 0.8150
# Epoch 25/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8777 - loss: 0.3809 - precision: 0.9287 - recall: 0.8376 - val_accuracy: 0.8637 - val_loss: 0.4737 - val_precision: 0.8935 - val_recall: 0.8494
# Epoch 26/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8850 - loss: 0.3553 - precision: 0.9284 - recall: 0.8457 - val_accuracy: 0.8744 - val_loss: 0.4224 - val_precision: 0.9077 - val_recall: 0.8606
# Epoch 27/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8820 - loss: 0.3538 - precision: 0.9275 - recall: 0.8435 - val_accuracy: 0.8625 - val_loss: 0.4597 - val_precision: 0.8926 - val_recall: 0.8469
# Epoch 28/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8854 - loss: 0.3410 - precision: 0.9271 - recall: 0.8464 - val_accuracy: 0.8169 - val_loss: 0.6486 - val_precision: 0.8497 - val_recall: 0.8019
# Epoch 29/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8889 - loss: 0.3303 - precision: 0.9294 - recall: 0.8566 - val_accuracy: 0.8275 - val_loss: 0.6450 - val_precision: 0.8496 - val_recall: 0.8156
# Epoch 30/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8905 - loss: 0.3229 - precision: 0.9296 - recall: 0.8562 - val_accuracy: 0.8537 - val_loss: 0.5082 - val_precision: 0.8846 - val_recall: 0.8431
# Epoch 31/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8938 - loss: 0.3109 - precision: 0.9353 - recall: 0.8635 - val_accuracy: 0.8325 - val_loss: 0.6677 - val_precision: 0.8538 - val_recall: 0.8213
# Epoch 32/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8958 - loss: 0.3092 - precision: 0.9325 - recall: 0.8669 - val_accuracy: 0.7763 - val_loss: 0.9550 - val_precision: 0.8090 - val_recall: 0.7600
# Epoch 33/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8973 - loss: 0.3091 - precision: 0.9333 - recall: 0.8687 - val_accuracy: 0.8150 - val_loss: 0.7226 - val_precision: 0.8402 - val_recall: 0.8050
# Epoch 34/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9022 - loss: 0.2910 - precision: 0.9385 - recall: 0.8743 - val_accuracy: 0.8438 - val_loss: 0.6263 - val_precision: 0.8637 - val_recall: 0.8394
# Epoch 35/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9053 - loss: 0.2912 - precision: 0.9392 - recall: 0.8754 - val_accuracy: 0.8675 - val_loss: 0.4576 - val_precision: 0.8943 - val_recall: 0.8569
# Epoch 36/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9096 - loss: 0.2751 - precision: 0.9415 - recall: 0.8827 - val_accuracy: 0.8431 - val_loss: 0.6036 - val_precision: 0.8632 - val_recall: 0.8400
# Epoch 37/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9066 - loss: 0.2668 - precision: 0.9384 - recall: 0.8811 - val_accuracy: 0.8344 - val_loss: 0.7543 - val_precision: 0.8565 - val_recall: 0.8244
# Epoch 38/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9077 - loss: 0.2658 - precision: 0.9393 - recall: 0.8852 - val_accuracy: 0.8250 - val_loss: 0.7155 - val_precision: 0.8477 - val_recall: 0.8175
# Epoch 39/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9129 - loss: 0.2599 - precision: 0.9433 - recall: 0.8880 - val_accuracy: 0.8775 - val_loss: 0.4201 - val_precision: 0.9050 - val_recall: 0.8694
# Epoch 40/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9185 - loss: 0.2396 - precision: 0.9475 - recall: 0.8962 - val_accuracy: 0.8700 - val_loss: 0.5097 - val_precision: 0.8878 - val_recall: 0.8656
# Epoch 41/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9164 - loss: 0.2389 - precision: 0.9495 - recall: 0.8978 - val_accuracy: 0.8775 - val_loss: 0.4204 - val_precision: 0.9052 - val_recall: 0.8712
# Epoch 42/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9165 - loss: 0.2489 - precision: 0.9443 - recall: 0.8948 - val_accuracy: 0.8625 - val_loss: 0.5486 - val_precision: 0.8835 - val_recall: 0.8581
# Epoch 43/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9191 - loss: 0.2327 - precision: 0.9474 - recall: 0.8965 - val_accuracy: 0.8706 - val_loss: 0.5592 - val_precision: 0.8884 - val_recall: 0.8606
# Epoch 44/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9214 - loss: 0.2331 - precision: 0.9488 - recall: 0.9007 - val_accuracy: 0.8569 - val_loss: 0.6001 - val_precision: 0.8722 - val_recall: 0.8487
# Epoch 45/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9206 - loss: 0.2362 - precision: 0.9476 - recall: 0.8999 - val_accuracy: 0.8750 - val_loss: 0.5324 - val_precision: 0.8861 - val_recall: 0.8700
# Epoch 46/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9228 - loss: 0.2242 - precision: 0.9482 - recall: 0.9030 - val_accuracy: 0.8737 - val_loss: 0.4813 - val_precision: 0.8907 - val_recall: 0.8656
# Epoch 47/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9217 - loss: 0.2221 - precision: 0.9508 - recall: 0.9009 - val_accuracy: 0.8519 - val_loss: 0.6268 - val_precision: 0.8731 - val_recall: 0.8469
# Epoch 48/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9215 - loss: 0.2203 - precision: 0.9469 - recall: 0.9007 - val_accuracy: 0.8731 - val_loss: 0.5346 - val_precision: 0.8866 - val_recall: 0.8694
# Epoch 49/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9288 - loss: 0.2163 - precision: 0.9537 - recall: 0.9094 - val_accuracy: 0.8687 - val_loss: 0.5377 - val_precision: 0.8923 - val_recall: 0.8650
# Epoch 50/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9277 - loss: 0.2089 - precision: 0.9509 - recall: 0.9062 - val_accuracy: 0.8763 - val_loss: 0.5801 - val_precision: 0.8922 - val_recall: 0.8694
# Epoch 51/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9289 - loss: 0.1981 - precision: 0.9512 - recall: 0.9129 - val_accuracy: 0.8594 - val_loss: 0.6242 - val_precision: 0.8732 - val_recall: 0.8562
# Epoch 52/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9288 - loss: 0.2103 - precision: 0.9538 - recall: 0.9111 - val_accuracy: 0.8744 - val_loss: 0.4928 - val_precision: 0.9002 - val_recall: 0.8681
# Epoch 53/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9315 - loss: 0.1984 - precision: 0.9545 - recall: 0.9130 - val_accuracy: 0.8769 - val_loss: 0.5572 - val_precision: 0.8921 - val_recall: 0.8731
# Epoch 54/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9326 - loss: 0.1922 - precision: 0.9559 - recall: 0.9181 - val_accuracy: 0.8756 - val_loss: 0.5384 - val_precision: 0.8883 - val_recall: 0.8700
# Epoch 55/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9298 - loss: 0.1994 - precision: 0.9529 - recall: 0.9142 - val_accuracy: 0.8706 - val_loss: 0.6319 - val_precision: 0.8861 - val_recall: 0.8656
# Epoch 56/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9333 - loss: 0.1940 - precision: 0.9536 - recall: 0.9125 - val_accuracy: 0.8850 - val_loss: 0.4950 - val_precision: 0.9008 - val_recall: 0.8800
# Epoch 57/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9348 - loss: 0.1916 - precision: 0.9536 - recall: 0.9189 - val_accuracy: 0.8788 - val_loss: 0.5443 - val_precision: 0.8932 - val_recall: 0.8725
# Epoch 58/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9359 - loss: 0.1850 - precision: 0.9540 - recall: 0.9198 - val_accuracy: 0.8719 - val_loss: 0.5323 - val_precision: 0.8915 - val_recall: 0.8681
# Epoch 59/1000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9342 - loss: 0.1825 - precision: 0.9545 - recall: 0.9203 - val_accuracy: 0.8763 - val_loss: 0.5570 - val_precision: 0.8942 - val_recall: 0.8712
#
# Évaluation finale sur le set de validation : [0.4201427400112152, 0.8774999976158142, 0.9050097465515137, 0.8693749904632568]
# Affichage des courbes d'apprentissage...

# %% [markdown]
# ### Fit tuning des hyperparamètres.
#
# Après avoir défini les hyperparamètres modifiables et vérifier que les fonctions fonctionnent, il est temps de lancer l'optimisation des hyperparamètres. Pour cela je vous invite à utiliser Optuna [[3]](https://optuna.readthedocs.io/en/stable/index.html) qui a plusieurs fonctionnalités:
# *   Une visualisation facilitée.
# *   Un suivi de l'avancement de l'optimisation.
# *   Une possibilité de reprendre l'optimisation sans reprendre depuis le début si un problème arrive durant le traitement.
#
#  <font color=" Darkblue"> **Tips:** Essayez de lancer l'optimisation pendant le TP pour voir si il fonctionne et arretez le. Lancez le pour de bon à la fin de la séance ou pendant la semaine car cela va prendre plusieurs heures, voir plusieurs jours. </font>
#
#  <font color="orange"> **Note anti-plagiat:** L'optimisation doit avoir une random seed fixe et différente pour chaque groupe. </font>
#
#  Merci de justifier vos plages de valeurs et faite un résumé sous forme de tableau :
#  > **Ecrire votre texte ici.**
#
#
#  | Hyperparamètre | Meilleure valeur | Plage | Step | Type de la plage |
# | :---------------- | :------: | :----: | :----: | :----: |
# | -   |  -  | - | - | - |

# %%
import optuna

SEED = 42
np.random.seed(SEED)

def objective(trial):

    param_model = {
        "activation": trial.suggest_categorical("activation", ["relu", "leaky_relu"]), # Objectifr embarqué donc activation simple à coder sur cible
        "conv_filters": trial.suggest_int("conv_filters", 16, 128, step=16),
        "ds_filters_1": trial.suggest_int("ds_filters_1", 16, 128, step=16),
        "ds_filters_2": trial.suggest_int("ds_filters_2", 16, 128, step=16),
        "dense_units": trial.suggest_int("dense_units", 32, 256, step=32),
        "dropout_rate": trial.suggest_float("dropout_rate", 0.1, 0.5),
    }

    param_training = {
        "max_epochs": trial.suggest_int("max_epochs", 10, 100, step=10),
        "BATCH_SIZE": trial.suggest_categorical("BATCH_SIZE", [16, 32, 64, 128]),
    }

    model = create_model(param_model, INPUT_SHAPE, NUM_CLASSES)

    metrics, _ , _= compile_and_fit(model, train, val, param_training, verbose=0)

    trial.set_user_attr("Size", total_param(model))

    # adapte selon ce que renvoie metrics
    return metrics[1]


study_name = "Benarib~Hanni-Tuning"
storage_name = f'/home/zebre/Bureau/eddge_computing/Edge_computing/model/{study_name}.db' #Chemin à créer dans votre drive

storage_url = f"sqlite:///{storage_name}"

study = optuna.create_study(
    direction='maximize',
    study_name=study_name,
    storage=storage_url,
    sampler=optuna.samplers.TPESampler(seed=SEED),
    load_if_exists=True)

study.optimize(objective, n_trials=100)
# Out:
# [I 2025-11-24 01:34:16,842] A new study created in RDB with name: Benarib~Hanni-Tuning
# [I 2025-11-24 01:35:08,522] Trial 0 finished with value: 0.8843749761581421 and parameters: {'activation': 'leaky_relu', 'conv_filters': 96, 'ds_filters_1': 80, 'ds_filters_2': 32, 'dense_units': 64, 'dropout_rate': 0.12323344486727979, 'max_epochs': 90, 'BATCH_SIZE': 128}. Best is trial 0 with value: 0.8843749761581421.
# Nombre de poids du modèle: 20,972
# 2025-11-24 01:35:10.395073: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_875', 56 bytes spill stores, 56 bytes spill loads
#
# 2025-11-24 01:35:10.500327: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_875', 20 bytes spill stores, 20 bytes spill loads
#
# 2025-11-24 01:35:10.780561: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1005', 100 bytes spill stores, 100 bytes spill loads
#
# [I 2025-11-24 01:35:31,788] Trial 1 finished with value: 0.8774999976158142 and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 32, 'ds_filters_2': 48, 'dense_units': 160, 'dropout_rate': 0.2727780074568463, 'max_epochs': 30, 'BATCH_SIZE': 16}. Best is trial 0 with value: 0.8843749761581421.
# Nombre de poids du modèle: 15,292
# [I 2025-11-24 01:36:14,985] Trial 2 finished with value: 0.8799999952316284 and parameters: {'activation': 'leaky_relu', 'conv_filters': 32, 'ds_filters_1': 80, 'ds_filters_2': 80, 'dense_units': 32, 'dropout_rate': 0.34301794076057535, 'max_epochs': 20, 'BATCH_SIZE': 64}. Best is trial 0 with value: 0.8843749761581421.
# Nombre de poids du modèle: 16,508
# [I 2025-11-24 01:36:52,836] Trial 3 finished with value: 0.8550000190734863 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 64, 'ds_filters_2': 16, 'dense_units': 128, 'dropout_rate': 0.11375540844608736, 'max_epochs': 100, 'BATCH_SIZE': 32}. Best is trial 0 with value: 0.8843749761581421.
# Nombre de poids du modèle: 18,172
# 2025-11-24 01:36:54.977384: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1306', 496 bytes spill stores, 496 bytes spill loads
#
# 2025-11-24 01:36:55.322322: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1306', 452 bytes spill stores, 452 bytes spill loads
#
# [I 2025-11-24 01:37:40,741] Trial 4 finished with value: 0.8862500190734863 and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 112, 'ds_filters_2': 128, 'dense_units': 256, 'dropout_rate': 0.3391599915244341, 'max_epochs': 100, 'BATCH_SIZE': 128}. Best is trial 4 with value: 0.8862500190734863.
# Nombre de poids du modèle: 75,820
# [I 2025-11-24 01:38:16,556] Trial 5 finished with value: 0.8687499761581421 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 48, 'ds_filters_2': 48, 'dense_units': 160, 'dropout_rate': 0.15636968998990508, 'max_epochs': 90, 'BATCH_SIZE': 32}. Best is trial 4 with value: 0.8862500190734863.
# Nombre de poids du modèle: 25,292
# 2025-11-24 01:38:17.899886: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1024', 8 bytes spill stores, 8 bytes spill loads
#
# [I 2025-11-24 01:39:36,904] Trial 6 finished with value: 0.8887500166893005 and parameters: {'activation': 'leaky_relu', 'conv_filters': 96, 'ds_filters_1': 96, 'ds_filters_2': 112, 'dense_units': 32, 'dropout_rate': 0.24338629141770907, 'max_epochs': 20, 'BATCH_SIZE': 16}. Best is trial 6 with value: 0.8887500166893005.
# Nombre de poids du modèle: 32,700
# 2025-11-24 01:39:39.175367: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1315', 496 bytes spill stores, 496 bytes spill loads
#
# [I 2025-11-24 01:40:37,849] Trial 7 finished with value: 0.8849999904632568 and parameters: {'activation': 'leaky_relu', 'conv_filters': 96, 'ds_filters_1': 96, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.14783769837532068, 'max_epochs': 80, 'BATCH_SIZE': 64}. Best is trial 6 with value: 0.8887500166893005.
# Nombre de poids du modèle: 48,364
# [I 2025-11-24 01:41:00,254] Trial 8 finished with value: 0.8343750238418579 and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 16, 'ds_filters_2': 16, 'dense_units': 192, 'dropout_rate': 0.22574239243053068, 'max_epochs': 60, 'BATCH_SIZE': 16}. Best is trial 6 with value: 0.8887500166893005.
# Nombre de poids du modèle: 7,532
# 2025-11-24 01:41:01.989356: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1024', 120 bytes spill stores, 120 bytes spill loads
#
# 2025-11-24 01:41:02.258938: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1306', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-11-24 01:41:02.479488: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1306', 80 bytes spill stores, 80 bytes spill loads
#
# 2025-11-24 01:41:02.571940: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1306', 152 bytes spill stores, 152 bytes spill loads
#
# 2025-11-24 01:41:02.779643: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1024', 752 bytes spill stores, 784 bytes spill loads
#
# [I 2025-11-24 01:41:29,313] Trial 9 finished with value: 0.8712499737739563 and parameters: {'activation': 'relu', 'conv_filters': 48, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 224, 'dropout_rate': 0.35336150260416943, 'max_epochs': 90, 'BATCH_SIZE': 64}. Best is trial 6 with value: 0.8887500166893005.
# Nombre de poids du modèle: 41,468
# [I 2025-11-24 01:42:13,511] Trial 10 finished with value: 0.8587499856948853 and parameters: {'activation': 'leaky_relu', 'conv_filters': 64, 'ds_filters_1': 128, 'ds_filters_2': 96, 'dense_units': 64, 'dropout_rate': 0.4630659181130071, 'max_epochs': 10, 'BATCH_SIZE': 16}. Best is trial 6 with value: 0.8887500166893005.
# Nombre de poids du modèle: 35,308
# 2025-11-24 01:42:15.046125: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_906', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-11-24 01:42:15.182217: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_906', 56 bytes spill stores, 56 bytes spill loads
#
# 2025-11-24 01:42:15.367486: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_906', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-11-24 01:42:15.725183: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1334', 264 bytes spill stores, 264 bytes spill loads
#
# 2025-11-24 01:42:15.853703: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1334', 248 bytes spill stores, 248 bytes spill loads
#
# [I 2025-11-24 01:43:25,980] Trial 11 finished with value: 0.8843749761581421 and parameters: {'activation': 'leaky_relu', 'conv_filters': 128, 'ds_filters_1': 112, 'ds_filters_2': 112, 'dense_units': 256, 'dropout_rate': 0.3937448431065479, 'max_epochs': 40, 'BATCH_SIZE': 128}. Best is trial 6 with value: 0.8887500166893005.
# Nombre de poids du modèle: 69,852
# 2025-11-24 01:43:27.974881: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1315', 248 bytes spill stores, 248 bytes spill loads
#
# 2025-11-24 01:43:28.189146: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1315', 264 bytes spill stores, 264 bytes spill loads
#
# [I 2025-11-24 01:44:24,355] Trial 12 finished with value: 0.8725000023841858 and parameters: {'activation': 'leaky_relu', 'conv_filters': 128, 'ds_filters_1': 128, 'ds_filters_2': 96, 'dense_units': 256, 'dropout_rate': 0.23827749809930665, 'max_epochs': 50, 'BATCH_SIZE': 128}. Best is trial 6 with value: 0.8887500166893005.
# Nombre de poids du modèle: 67,948
# 2025-11-24 01:44:26.498261: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1306', 152 bytes spill stores, 152 bytes spill loads
#
# [I 2025-11-24 01:45:06,272] Trial 13 finished with value: 0.893750011920929 and parameters: {'activation': 'relu', 'conv_filters': 80, 'ds_filters_1': 96, 'ds_filters_2': 112, 'dense_units': 96, 'dropout_rate': 0.3059881656083773, 'max_epochs': 70, 'BATCH_SIZE': 128}. Best is trial 13 with value: 0.893750011920929.
# Nombre de poids du modèle: 38,284
# 2025-11-24 01:45:08.751087: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1306', 152 bytes spill stores, 152 bytes spill loads
#
# [I 2025-11-24 01:45:44,072] Trial 14 finished with value: 0.8968750238418579 and parameters: {'activation': 'relu', 'conv_filters': 80, 'ds_filters_1': 96, 'ds_filters_2': 96, 'dense_units': 96, 'dropout_rate': 0.21664940050623915, 'max_epochs': 60, 'BATCH_SIZE': 16}. Best is trial 14 with value: 0.8968750238418579.
# Nombre de poids du modèle: 35,132
# 2025-11-24 01:45:45.889162: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1306', 152 bytes spill stores, 152 bytes spill loads
#
# [I 2025-11-24 01:46:19,509] Trial 15 finished with value: 0.878125011920929 and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 96, 'ds_filters_2': 80, 'dense_units': 96, 'dropout_rate': 0.1780407289572843, 'max_epochs': 70, 'BATCH_SIZE': 16}. Best is trial 14 with value: 0.8968750238418579.
# Nombre de poids du modèle: 29,564
# [I 2025-11-24 01:46:52,950] Trial 16 finished with value: 0.8981249928474426 and parameters: {'activation': 'relu', 'conv_filters': 80, 'ds_filters_1': 64, 'ds_filters_2': 96, 'dense_units': 96, 'dropout_rate': 0.299536487485773, 'max_epochs': 60, 'BATCH_SIZE': 128}. Best is trial 16 with value: 0.8981249928474426.
# Nombre de poids du modèle: 28,540
# [I 2025-11-24 01:47:24,994] Trial 17 finished with value: 0.8799999952316284 and parameters: {'activation': 'relu', 'conv_filters': 80, 'ds_filters_1': 64, 'ds_filters_2': 64, 'dense_units': 96, 'dropout_rate': 0.41977698550806297, 'max_epochs': 50, 'BATCH_SIZE': 32}. Best is trial 16 with value: 0.8981249928474426.
# Nombre de poids du modèle: 23,260
# [I 2025-11-24 01:47:52,507] Trial 18 finished with value: 0.8787500262260437 and parameters: {'activation': 'relu', 'conv_filters': 48, 'ds_filters_1': 48, 'ds_filters_2': 96, 'dense_units': 64, 'dropout_rate': 0.19971080976585623, 'max_epochs': 60, 'BATCH_SIZE': 16}. Best is trial 16 with value: 0.8981249928474426.
# Nombre de poids du modèle: 18,460
# 2025-11-24 01:47:53.919963: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_894', 4 bytes spill stores, 4 bytes spill loads
#
# [I 2025-11-24 01:48:19,618] Trial 19 finished with value: 0.8581249713897705 and parameters: {'activation': 'relu', 'conv_filters': 80, 'ds_filters_1': 64, 'ds_filters_2': 64, 'dense_units': 128, 'dropout_rate': 0.28884903007041923, 'max_epochs': 40, 'BATCH_SIZE': 128}. Best is trial 16 with value: 0.8981249928474426.
# Nombre de poids du modèle: 25,724
# 2025-11-24 01:48:21.321757: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_894', 32 bytes spill stores, 32 bytes spill loads
#
# 2025-11-24 01:48:21.491777: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1024', 756 bytes spill stores, 788 bytes spill loads
#
# 2025-11-24 01:48:21.736064: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1024', 100 bytes spill stores, 100 bytes spill loads
#
# 2025-11-24 01:48:21.864642: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1306', 76 bytes spill stores, 76 bytes spill loads
#
# 2025-11-24 01:48:21.972138: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1306', 152 bytes spill stores, 152 bytes spill loads
#
# [I 2025-11-24 01:48:50,321] Trial 20 finished with value: 0.8700000047683716 and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 80, 'ds_filters_2': 80, 'dense_units': 192, 'dropout_rate': 0.27001533535449485, 'max_epochs': 70, 'BATCH_SIZE': 128}. Best is trial 16 with value: 0.8981249928474426.
# Nombre de poids du modèle: 35,708
# [I 2025-11-24 01:49:26,778] Trial 21 finished with value: 0.8756250143051147 and parameters: {'activation': 'relu', 'conv_filters': 80, 'ds_filters_1': 112, 'ds_filters_2': 112, 'dense_units': 96, 'dropout_rate': 0.32263830259267534, 'max_epochs': 70, 'BATCH_SIZE': 128}. Best is trial 16 with value: 0.8981249928474426.
# Nombre de poids du modèle: 41,836
# [I 2025-11-24 01:50:05,485] Trial 22 finished with value: 0.890625 and parameters: {'activation': 'relu', 'conv_filters': 80, 'ds_filters_1': 96, 'ds_filters_2': 96, 'dense_units': 96, 'dropout_rate': 0.37878420368478183, 'max_epochs': 60, 'BATCH_SIZE': 128}. Best is trial 16 with value: 0.8981249928474426.
# Nombre de poids du modèle: 35,132
# [I 2025-11-24 01:50:52,368] Trial 23 finished with value: 0.8943750262260437 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 80, 'ds_filters_2': 112, 'dense_units': 64, 'dropout_rate': 0.3171820060198744, 'max_epochs': 80, 'BATCH_SIZE': 128}. Best is trial 16 with value: 0.8981249928474426.
# Nombre de poids du modèle: 35,052
# [I 2025-11-24 01:51:30,316] Trial 24 finished with value: 0.8912500143051147 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 48, 'ds_filters_2': 96, 'dense_units': 64, 'dropout_rate': 0.21262126529734618, 'max_epochs': 80, 'BATCH_SIZE': 128}. Best is trial 16 with value: 0.8981249928474426.
# Nombre de poids du modèle: 25,052
# [I 2025-11-24 01:52:36,508] Trial 25 finished with value: 0.9068750143051147 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 80, 'ds_filters_2': 112, 'dense_units': 32, 'dropout_rate': 0.2705061647201294, 'max_epochs': 50, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 31,052
# [I 2025-11-24 01:53:24,142] Trial 26 finished with value: 0.8931249976158142 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 64, 'ds_filters_2': 80, 'dense_units': 32, 'dropout_rate': 0.25933940010005463, 'max_epochs': 40, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 23,756
# 2025-11-24 01:53:25.690248: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1024', 8 bytes spill stores, 8 bytes spill loads
#
# [I 2025-11-24 01:53:57,670] Trial 27 finished with value: 0.890625 and parameters: {'activation': 'relu', 'conv_filters': 48, 'ds_filters_1': 80, 'ds_filters_2': 96, 'dense_units': 32, 'dropout_rate': 0.1909255010328327, 'max_epochs': 50, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 20,540
# [I 2025-11-24 01:54:47,176] Trial 28 finished with value: 0.9018750190734863 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 112, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.4963910655147282, 'max_epochs': 30, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 52,428
# 2025-11-24 01:54:49.058063: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1306', 152 bytes spill stores, 152 bytes spill loads
#
# 2025-11-24 01:54:49.352512: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1306', 80 bytes spill stores, 80 bytes spill loads
#
# 2025-11-24 01:54:49.387225: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1024', 752 bytes spill stores, 784 bytes spill loads
#
# 2025-11-24 01:54:49.401137: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1306', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-11-24 01:54:49.484896: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1024', 120 bytes spill stores, 120 bytes spill loads
#
# [I 2025-11-24 01:55:42,701] Trial 29 finished with value: 0.9037500023841858 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 112, 'ds_filters_2': 128, 'dense_units': 160, 'dropout_rate': 0.4808303978889353, 'max_epochs': 30, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 56,940
# 2025-11-24 01:55:44.485758: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1024', 120 bytes spill stores, 120 bytes spill loads
#
# 2025-11-24 01:55:44.769388: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1306', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-11-24 01:55:44.866559: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1024', 752 bytes spill stores, 784 bytes spill loads
#
# 2025-11-24 01:55:44.897791: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1306', 80 bytes spill stores, 80 bytes spill loads
#
# 2025-11-24 01:55:44.932679: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1306', 152 bytes spill stores, 152 bytes spill loads
#
# [I 2025-11-24 01:56:29,763] Trial 30 finished with value: 0.9006249904632568 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 192, 'dropout_rate': 0.48243340375399635, 'max_epochs': 30, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 65,516
# [I 2025-11-24 01:57:13,281] Trial 31 finished with value: 0.8943750262260437 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 192, 'dropout_rate': 0.4834582360477604, 'max_epochs': 30, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 65,516
# [I 2025-11-24 01:57:58,260] Trial 32 finished with value: 0.8824999928474426 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 112, 'ds_filters_2': 128, 'dense_units': 160, 'dropout_rate': 0.49843639730206174, 'max_epochs': 30, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 56,940
# [I 2025-11-24 01:58:53,450] Trial 33 finished with value: 0.893750011920929 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 224, 'dropout_rate': 0.44326515395928645, 'max_epochs': 20, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 72,956
# 2025-11-24 01:58:55.341851: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_875', 32 bytes spill stores, 32 bytes spill loads
#
# 2025-11-24 01:58:55.405067: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1005', 756 bytes spill stores, 788 bytes spill loads
#
# 2025-11-24 01:58:55.583383: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1287', 152 bytes spill stores, 152 bytes spill loads
#
# 2025-11-24 01:58:55.668561: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1005', 100 bytes spill stores, 100 bytes spill loads
#
# 2025-11-24 01:58:55.741783: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1287', 76 bytes spill stores, 76 bytes spill loads
#
# [I 2025-11-24 01:59:52,477] Trial 34 finished with value: 0.8974999785423279 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 112, 'ds_filters_2': 112, 'dense_units': 160, 'dropout_rate': 0.4436529257037369, 'max_epochs': 10, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 55,180
# [I 2025-11-24 02:00:38,199] Trial 35 finished with value: 0.8899999856948853 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 224, 'dropout_rate': 0.4588577437263405, 'max_epochs': 20, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 70,028
# 2025-11-24 02:00:39.973753: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_894', 32 bytes spill stores, 32 bytes spill loads
#
# 2025-11-24 02:00:40.084585: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1306', 152 bytes spill stores, 152 bytes spill loads
#
# 2025-11-24 02:00:40.255613: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1024', 756 bytes spill stores, 788 bytes spill loads
#
# 2025-11-24 02:00:40.369318: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1024', 100 bytes spill stores, 100 bytes spill loads
#
# 2025-11-24 02:00:40.544399: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1306', 76 bytes spill stores, 76 bytes spill loads
#
# [I 2025-11-24 02:01:33,354] Trial 36 finished with value: 0.8949999809265137 and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 112, 'ds_filters_2': 112, 'dense_units': 192, 'dropout_rate': 0.4134081258928501, 'max_epochs': 30, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 61,852
# [I 2025-11-24 02:02:35,821] Trial 37 finished with value: 0.8912500143051147 and parameters: {'activation': 'leaky_relu', 'conv_filters': 96, 'ds_filters_1': 112, 'ds_filters_2': 128, 'dense_units': 160, 'dropout_rate': 0.49678258614529947, 'max_epochs': 40, 'BATCH_SIZE': 32}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 56,940
# [I 2025-11-24 02:03:26,023] Trial 38 finished with value: 0.9006249904632568 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.4760044982979991, 'max_epochs': 30, 'BATCH_SIZE': 64}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 56,492
# [I 2025-11-24 02:04:12,994] Trial 39 finished with value: 0.8956249952316284 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 112, 'ds_filters_2': 112, 'dense_units': 192, 'dropout_rate': 0.43249266290610067, 'max_epochs': 20, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 59,180
# [I 2025-11-24 02:04:58,285] Trial 40 finished with value: 0.8700000047683716 and parameters: {'activation': 'leaky_relu', 'conv_filters': 96, 'ds_filters_1': 80, 'ds_filters_2': 128, 'dense_units': 160, 'dropout_rate': 0.3582512588513358, 'max_epochs': 40, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 48,812
# [I 2025-11-24 02:05:39,437] Trial 41 finished with value: 0.8793749809265137 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.47326799437057876, 'max_epochs': 30, 'BATCH_SIZE': 64}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 56,492
# [I 2025-11-24 02:06:26,776] Trial 42 finished with value: 0.8774999976158142 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 128, 'ds_filters_2': 32, 'dense_units': 128, 'dropout_rate': 0.47966986608507434, 'max_epochs': 30, 'BATCH_SIZE': 64}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 34,364
# [I 2025-11-24 02:07:11,627] Trial 43 finished with value: 0.8756250143051147 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.45621268092760414, 'max_epochs': 10, 'BATCH_SIZE': 64}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 56,492
# [I 2025-11-24 02:07:59,162] Trial 44 finished with value: 0.893750011920929 and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 112, 'ds_filters_2': 112, 'dense_units': 160, 'dropout_rate': 0.4133696676325248, 'max_epochs': 40, 'BATCH_SIZE': 64}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 57,852
# [I 2025-11-24 02:08:42,051] Trial 45 finished with value: 0.8956249952316284 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 224, 'dropout_rate': 0.3916517047523018, 'max_epochs': 20, 'BATCH_SIZE': 64}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 70,028
# [I 2025-11-24 02:09:28,843] Trial 46 finished with value: 0.8518750071525574 and parameters: {'activation': 'leaky_relu', 'conv_filters': 112, 'ds_filters_1': 16, 'ds_filters_2': 112, 'dense_units': 192, 'dropout_rate': 0.497658353746508, 'max_epochs': 30, 'BATCH_SIZE': 32}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 34,796
# [I 2025-11-24 02:10:18,468] Trial 47 finished with value: 0.90625 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 96, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.4622730400298568, 'max_epochs': 50, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 48,364
# [I 2025-11-24 02:10:41,818] Trial 48 finished with value: 0.856249988079071 and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 96, 'ds_filters_2': 128, 'dense_units': 160, 'dropout_rate': 0.44181056968158244, 'max_epochs': 50, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 40,796
# [I 2025-11-24 02:11:31,088] Trial 49 finished with value: 0.8831250071525574 and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 96, 'ds_filters_2': 112, 'dense_units': 160, 'dropout_rate': 0.4606967137831496, 'max_epochs': 50, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 53,532
# [I 2025-11-24 02:12:18,778] Trial 50 finished with value: 0.8862500190734863 and parameters: {'activation': 'leaky_relu', 'conv_filters': 64, 'ds_filters_1': 96, 'ds_filters_2': 128, 'dense_units': 224, 'dropout_rate': 0.42898427791987237, 'max_epochs': 50, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 57,068
# [I 2025-11-24 02:13:08,476] Trial 51 finished with value: 0.9043750166893005 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 112, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.4758788213530357, 'max_epochs': 40, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 52,428
# [I 2025-11-24 02:13:57,246] Trial 52 finished with value: 0.8999999761581421 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 112, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.483328493870466, 'max_epochs': 40, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 52,428
# [I 2025-11-24 02:14:34,657] Trial 53 finished with value: 0.8987500071525574 and parameters: {'activation': 'relu', 'conv_filters': 80, 'ds_filters_1': 112, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.46609924510238654, 'max_epochs': 40, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 49,756
# [I 2025-11-24 02:15:15,168] Trial 54 finished with value: 0.8924999833106995 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 96, 'ds_filters_2': 112, 'dense_units': 160, 'dropout_rate': 0.448632085237616, 'max_epochs': 50, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 48,700
# [I 2025-11-24 02:15:59,016] Trial 55 finished with value: 0.8974999785423279 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 80, 'ds_filters_2': 48, 'dense_units': 64, 'dropout_rate': 0.40199571937026646, 'max_epochs': 30, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 25,516
# [I 2025-11-24 02:16:41,540] Trial 56 finished with value: 0.8999999761581421 and parameters: {'activation': 'relu', 'conv_filters': 80, 'ds_filters_1': 112, 'ds_filters_2': 112, 'dense_units': 96, 'dropout_rate': 0.4894160348534834, 'max_epochs': 40, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 41,836
# [I 2025-11-24 02:17:25,347] Trial 57 finished with value: 0.8931249976158142 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 96, 'ds_filters_2': 128, 'dense_units': 192, 'dropout_rate': 0.37431283198305204, 'max_epochs': 20, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 59,804
# [I 2025-11-24 02:18:11,433] Trial 58 finished with value: 0.8956249952316284 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 96, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.24599392624927835, 'max_epochs': 60, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 48,364
# [I 2025-11-24 02:18:48,774] Trial 59 finished with value: 0.8899999856948853 and parameters: {'activation': 'relu', 'conv_filters': 80, 'ds_filters_1': 112, 'ds_filters_2': 112, 'dense_units': 256, 'dropout_rate': 0.28281038048900714, 'max_epochs': 40, 'BATCH_SIZE': 32}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 61,836
# [I 2025-11-24 02:19:29,606] Trial 60 finished with value: 0.8899999856948853 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 80, 'ds_filters_2': 112, 'dense_units': 96, 'dropout_rate': 0.14165183688793595, 'max_epochs': 50, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 39,052
# [I 2025-11-24 02:20:13,667] Trial 61 finished with value: 0.8918750286102295 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.4773971523770126, 'max_epochs': 30, 'BATCH_SIZE': 64}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 56,492
# [I 2025-11-24 02:21:01,223] Trial 62 finished with value: 0.9043750166893005 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.470769568840881, 'max_epochs': 30, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 56,492
# [I 2025-11-24 02:21:43,983] Trial 63 finished with value: 0.8956249952316284 and parameters: {'activation': 'relu', 'conv_filters': 80, 'ds_filters_1': 112, 'ds_filters_2': 128, 'dense_units': 160, 'dropout_rate': 0.46738171815453067, 'max_epochs': 30, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 54,268
# 2025-11-24 02:21:45.510540: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1306', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-11-24 02:21:46.032892: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1306', 152 bytes spill stores, 152 bytes spill loads
#
# [I 2025-11-24 02:22:29,125] Trial 64 finished with value: 0.9037500023841858 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 96, 'dropout_rate': 0.42761131392325913, 'max_epochs': 40, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 51,980
# [I 2025-11-24 02:23:07,761] Trial 65 finished with value: 0.8837500214576721 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 112, 'ds_filters_2': 112, 'dense_units': 96, 'dropout_rate': 0.43376678044733186, 'max_epochs': 40, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 44,508
# [I 2025-11-24 02:23:47,790] Trial 66 finished with value: 0.8962500095367432 and parameters: {'activation': 'relu', 'conv_filters': 80, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.4535441464959021, 'max_epochs': 50, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 40,028
# [I 2025-11-24 02:24:22,515] Trial 67 finished with value: 0.8656250238418579 and parameters: {'activation': 'leaky_relu', 'conv_filters': 64, 'ds_filters_1': 96, 'ds_filters_2': 128, 'dense_units': 64, 'dropout_rate': 0.49930323297624296, 'max_epochs': 60, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 34,508
# 2025-11-24 02:24:24.138018: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_875', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-11-24 02:24:24.451793: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_875', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-11-24 02:24:24.587319: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1287', 264 bytes spill stores, 264 bytes spill loads
#
# [I 2025-11-24 02:25:05,723] Trial 68 finished with value: 0.8824999928474426 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 112, 'ds_filters_2': 112, 'dense_units': 128, 'dropout_rate': 0.10472631935684695, 'max_epochs': 40, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 51,180
# [I 2025-11-24 02:25:52,194] Trial 69 finished with value: 0.8974999785423279 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 96, 'dropout_rate': 0.3328991951306634, 'max_epochs': 40, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 51,980
# [I 2025-11-24 02:26:39,729] Trial 70 finished with value: 0.8943750262260437 and parameters: {'activation': 'relu', 'conv_filters': 80, 'ds_filters_1': 112, 'ds_filters_2': 64, 'dense_units': 32, 'dropout_rate': 0.4230979090770206, 'max_epochs': 100, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 26,684
# [I 2025-11-24 02:27:22,702] Trial 71 finished with value: 0.8931249976158142 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.4877173841009291, 'max_epochs': 30, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 56,492
# [I 2025-11-24 02:28:10,323] Trial 72 finished with value: 0.890625 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 160, 'dropout_rate': 0.4637068252240241, 'max_epochs': 20, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 61,004
# [I 2025-11-24 02:28:54,277] Trial 73 finished with value: 0.8962500095367432 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.4715603241867038, 'max_epochs': 50, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 56,492
# [I 2025-11-24 02:29:49,340] Trial 74 finished with value: 0.9049999713897705 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 96, 'dropout_rate': 0.44197126636261425, 'max_epochs': 30, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 54,908
# [I 2025-11-24 02:30:40,519] Trial 75 finished with value: 0.9012500047683716 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 112, 'ds_filters_2': 16, 'dense_units': 64, 'dropout_rate': 0.44206594402054816, 'max_epochs': 40, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 25,804
# [I 2025-11-24 02:31:29,928] Trial 76 finished with value: 0.9037500023841858 and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 80, 'ds_filters_2': 112, 'dense_units': 96, 'dropout_rate': 0.25873651521677665, 'max_epochs': 20, 'BATCH_SIZE': 32}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 41,212
# [I 2025-11-24 02:32:15,567] Trial 77 finished with value: 0.8924999833106995 and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 64, 'ds_filters_2': 96, 'dense_units': 96, 'dropout_rate': 0.2578623001209209, 'max_epochs': 10, 'BATCH_SIZE': 32}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 34,252
# [I 2025-11-24 02:32:56,928] Trial 78 finished with value: 0.8862500190734863 and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 80, 'ds_filters_2': 96, 'dense_units': 96, 'dropout_rate': 0.29832658645347554, 'max_epochs': 20, 'BATCH_SIZE': 32}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 38,316
# [I 2025-11-24 02:33:40,999] Trial 79 finished with value: 0.8868749737739563 and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 80, 'ds_filters_2': 112, 'dense_units': 96, 'dropout_rate': 0.27488626616559947, 'max_epochs': 20, 'BATCH_SIZE': 32}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 41,212
# [I 2025-11-24 02:34:33,344] Trial 80 finished with value: 0.8650000095367432 and parameters: {'activation': 'leaky_relu', 'conv_filters': 112, 'ds_filters_1': 64, 'ds_filters_2': 112, 'dense_units': 96, 'dropout_rate': 0.22329814999196967, 'max_epochs': 30, 'BATCH_SIZE': 32}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 34,988
# [I 2025-11-24 02:35:13,614] Trial 81 finished with value: 0.8949999809265137 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 96, 'ds_filters_2': 128, 'dense_units': 64, 'dropout_rate': 0.2401157992258375, 'max_epochs': 30, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 41,756
# [I 2025-11-24 02:35:51,256] Trial 82 finished with value: 0.8799999952316284 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 80, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.2503934818955147, 'max_epochs': 30, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 46,460
# [I 2025-11-24 02:36:46,924] Trial 83 finished with value: 0.8956249952316284 and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.2668586071548502, 'max_epochs': 20, 'BATCH_SIZE': 32}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 62,348
# [I 2025-11-24 02:37:30,068] Trial 84 finished with value: 0.893750011920929 and parameters: {'activation': 'relu', 'conv_filters': 96, 'ds_filters_1': 96, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.4514917645394017, 'max_epochs': 10, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 48,364
# [I 2025-11-24 02:38:24,659] Trial 85 finished with value: 0.9049999713897705 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 112, 'ds_filters_2': 112, 'dense_units': 64, 'dropout_rate': 0.4891828104385541, 'max_epochs': 40, 'BATCH_SIZE': 16}. Best is trial 25 with value: 0.9068750143051147.
# Nombre de poids du modèle: 43,180
# [I 2025-11-24 02:39:14,764] Trial 86 finished with value: 0.9100000262260437 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 128, 'ds_filters_2': 112, 'dense_units': 32, 'dropout_rate': 0.4079749889039942, 'max_epochs': 40, 'BATCH_SIZE': 16}. Best is trial 86 with value: 0.9100000262260437.
# Nombre de poids du modèle: 43,244
# [I 2025-11-24 02:40:06,274] Trial 87 finished with value: 0.9043750166893005 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 128, 'ds_filters_2': 96, 'dense_units': 32, 'dropout_rate': 0.40200787389174564, 'max_epochs': 40, 'BATCH_SIZE': 16}. Best is trial 86 with value: 0.9100000262260437.
# Nombre de poids du modèle: 40,604
# [I 2025-11-24 02:40:57,203] Trial 88 finished with value: 0.8968750238418579 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 128, 'ds_filters_2': 96, 'dense_units': 32, 'dropout_rate': 0.40024097164669625, 'max_epochs': 50, 'BATCH_SIZE': 16}. Best is trial 86 with value: 0.9100000262260437.
# Nombre de poids du modèle: 40,604
# [I 2025-11-24 02:41:45,617] Trial 89 finished with value: 0.8856250047683716 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 112, 'ds_filters_2': 80, 'dense_units': 32, 'dropout_rate': 0.411348496762522, 'max_epochs': 40, 'BATCH_SIZE': 16}. Best is trial 86 with value: 0.9100000262260437.
# Nombre de poids du modèle: 34,412
# [I 2025-11-24 02:42:37,155] Trial 90 finished with value: 0.9043750166893005 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 128, 'ds_filters_2': 96, 'dense_units': 32, 'dropout_rate': 0.36563889703723046, 'max_epochs': 50, 'BATCH_SIZE': 128}. Best is trial 86 with value: 0.9100000262260437.
# Nombre de poids du modèle: 40,604
# [I 2025-11-24 02:43:36,681] Trial 91 finished with value: 0.893750011920929 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 128, 'ds_filters_2': 80, 'dense_units': 32, 'dropout_rate': 0.3807480522793266, 'max_epochs': 50, 'BATCH_SIZE': 128}. Best is trial 86 with value: 0.9100000262260437.
# Nombre de poids du modèle: 37,964
# [I 2025-11-24 02:44:21,946] Trial 92 finished with value: 0.8987500071525574 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 128, 'ds_filters_2': 96, 'dense_units': 32, 'dropout_rate': 0.43496406469328464, 'max_epochs': 60, 'BATCH_SIZE': 128}. Best is trial 86 with value: 0.9100000262260437.
# Nombre de poids du modèle: 40,604
# [I 2025-11-24 02:45:05,729] Trial 93 finished with value: 0.903124988079071 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 128, 'ds_filters_2': 96, 'dense_units': 32, 'dropout_rate': 0.3870196189900787, 'max_epochs': 50, 'BATCH_SIZE': 128}. Best is trial 86 with value: 0.9100000262260437.
# Nombre de poids du modèle: 40,604
# [I 2025-11-24 02:45:58,608] Trial 94 finished with value: 0.8962500095367432 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 128, 'ds_filters_2': 80, 'dense_units': 32, 'dropout_rate': 0.35512062512175413, 'max_epochs': 40, 'BATCH_SIZE': 128}. Best is trial 86 with value: 0.9100000262260437.
# Nombre de poids du modèle: 37,964
# [I 2025-11-24 02:46:42,435] Trial 95 finished with value: 0.8837500214576721 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 112, 'ds_filters_2': 112, 'dense_units': 64, 'dropout_rate': 0.3708814773449688, 'max_epochs': 50, 'BATCH_SIZE': 16}. Best is trial 86 with value: 0.9100000262260437.
# Nombre de poids du modèle: 43,180
# [I 2025-11-24 02:47:39,368] Trial 96 finished with value: 0.9137499928474426 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 128, 'ds_filters_2': 112, 'dense_units': 64, 'dropout_rate': 0.3644476905034811, 'max_epochs': 40, 'BATCH_SIZE': 16}. Best is trial 96 with value: 0.9137499928474426.
# Nombre de poids du modèle: 47,244
# [I 2025-11-24 02:48:35,974] Trial 97 finished with value: 0.9100000262260437 and parameters: {'activation': 'relu', 'conv_filters': 112, 'ds_filters_1': 128, 'ds_filters_2': 112, 'dense_units': 64, 'dropout_rate': 0.4031511253356774, 'max_epochs': 40, 'BATCH_SIZE': 16}. Best is trial 96 with value: 0.9137499928474426.
# Nombre de poids du modèle: 47,244
# [I 2025-11-24 02:49:25,204] Trial 98 finished with value: 0.9012500047683716 and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 128, 'ds_filters_2': 112, 'dense_units': 64, 'dropout_rate': 0.4036131066455387, 'max_epochs': 40, 'BATCH_SIZE': 16}. Best is trial 96 with value: 0.9137499928474426.
# Nombre de poids du modèle: 50,172
# [I 2025-11-24 02:50:23,501] Trial 99 finished with value: 0.8725000023841858 and parameters: {'activation': 'leaky_relu', 'conv_filters': 112, 'ds_filters_1': 128, 'ds_filters_2': 112, 'dense_units': 64, 'dropout_rate': 0.4179270696315002, 'max_epochs': 40, 'BATCH_SIZE': 16}. Best is trial 96 with value: 0.9137499928474426.
# Nombre de poids du modèle: 47,244

# %%
# Afficher les meilleurs hyperparamètres
print("Best trial:")
trial = study.best_trial

print(f"  Value: {trial.value}")
print("  Params: ")
for key, value in trial.params.items():
    print(f"    {key}: {value}")

# Sauvegarder les meilleurs params dans un fichier texte (facile à lire)
import json
with open("best_params.json", "w") as f:
    json.dump(study.best_params, f, indent=4)
# Out:
# Best trial:
#   Value: 0.9137499928474426
#   Params:
#     activation: relu
#     conv_filters: 112
#     ds_filters_1: 128
#     ds_filters_2: 112
#     dense_units: 64
#     dropout_rate: 0.3644476905034811
#     max_epochs: 40
#     BATCH_SIZE: 16

# %% [markdown]
# ## Résultat et discussion
#
# <font color=" Darkred"> Progression du TP après cette partie (environ 3h): </font>
# ![84%](https://progress-bar.dev/84)

# %% [markdown]
# ### Export du modèle
#
# Merci d'exporter le meilleur modèle et l'envoyer avec le jupyter notebook et la base de données d'entraînement. Lors de l'exportation d'un modèle, il est recommandé d'utiliser la base de donnée d'entrainement, et de validation.
#
#  <font color="green">*Cette partie du code est complète, vous n'avez pas besoin de la modifier.* </font>

# %%
import joblib

# Fix the storage URL format for SQLAlchemy
storage_url_fixed = f"sqlite:///{storage_name.replace('sqlite:///', '')}"
study = optuna.load_study(storage=storage_url_fixed, study_name=study_name)
print("Best trial until now:")
print("   Value: ", study.best_trial.value)
print("   Params: ")
for key, value in study.best_trial.params.items():
    print(f"    -{key}: {value}")
print("----------------------")

model = create_model(study.best_trial.params)

train_and_val = tf.data.Dataset.from_tensor_slices((np.concatenate((X_train, X_val)), np.concatenate((y_train, y_val))))
train_and_val = train_and_val.shuffle(1500, reshuffle_each_iteration=True)
train_and_val = train_and_val.batch(32, drop_remainder=True)


_, global_model = compile_and_fit(model, train_and_val, val, study.best_trial.params, verbose=0)

#joblib.dump(global_model, '/content/drive/MyDrive/TP N9EE39A/NOM1~NOM2_model.pkl')
joblib.dump(global_model, '/model/Hanni_Benarib_model.pkl')
# Out:
# Best trial until now:
#    Value:  0.9137499928474426
#    Params:
#     -activation: relu
#     -conv_filters: 112
#     -ds_filters_1: 128
#     -ds_filters_2: 112
#     -dense_units: 64
#     -dropout_rate: 0.3644476905034811
#     -max_epochs: 40
#     -BATCH_SIZE: 16
# ----------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 13
#      10     print(f"    -{key}: {value}")
#      11 print("----------------------")
# ---> 13 model = create_model(study.best_trial.params)
#      15 train_and_val = tf.data.Dataset.from_tensor_slices((np.concatenate((X_train, X_val)), np.concatenate((y_train, y_val))))
#      16 train_and_val = train_and_val.shuffle(1500, reshuffle_each_iteration=True)
#
# TypeError: create_model() missing 2 required positional arguments: 'input_shape' and 'num_classes'

# %% [markdown]
# ### Dépôt sur Kaggle
#
# Il est temps de soumettre vos résultats sur Kaggle. Qu'en pensez vous, êtes vous satisfait de vos performances ? Est-ce que vous vous attendiez à ces performances ?
#
#  <font color=" Darkblue"> **Tips:** Le format d'envoie et des tutoriels sont disponibles sur la page du concours. </font>
#
#  <font color="orange"> **Note anti-plagiat:** Il est impossible que le fichier que vous allez déposer soit le même qu'un autre binôme. Le fichier sera regénérer lors de la correction et doit être similaire avec celui déposé. </font>
#
# A la fin du projet, merci d'envoyer avec les autres fichiers ce fichier Kaggle avec comme nom **NOM1~NOM2_submission.csv**.
#
# > **Ecrire votre texte ici.**

# %%
#Ici, tous le code est à faire. Normalement, tous a déjà été codé ou est facilement trouvable sur internet et sur le site de la compétition !

# %% [markdown]
# ### Visualisation des résultats
#
# Ici tous le code a déjà été fait. Il faut par contre commenter les résultats et les performances que vous avez obtenu et l'utilité de chaque figure.

# %% [markdown]
#  #### Matrice de confusion
#
#  <font color="green">*Cette partie du code est complète, vous n'avez pas besoin de la modifier.* </font>
#
#  > **Ecrire votre texte ici.**

# %%
from sklearn.metrics import ConfusionMatrixDisplay

study = optuna.load_study(storage=storage_name, study_name=study_name)
model = create_model(study.best_trial.params)
_, model = compile_and_fit(model, train, val, study.best_trial.params, verbose=0)

y_prob= model.predict(val)
y_pred = y_prob.argmax(axis=1)

ds_labels=[]
for images, labels in val.unbatch():
    ds_labels.append(labels)
y_ref = np.array(ds_labels).argmax(axis=1)

label_names = ["yes", "no", "up", "down", "left", "right", "on", "off", "stop", "go", "silence", "unknown"]
ConfusionMatrixDisplay.from_predictions(y_ref, y_pred, cmap='Blues', normalize='true', ax=plt.subplots(figsize=(12,12))[1], display_labels=label_names)

# %% [markdown]
# #### Résultat du Fit-tuning
#
#  <font color="green">*Cette partie du code est complète, vous n'avez pas besoin de la modifier.* </font>
#
#  > **Ecrire votre texte ici.**

# %%
plt.figure(figsize=(12,12))
optuna.visualization.plot_optimization_history(study)

# %%
plt.figure(figsize=(12,12))
optuna.visualization.plot_slice(study)

# %% [markdown]
# #### Influence des hyperparamètres sur les performances
#
#  <font color="green">*Cette partie du code est complète, vous n'avez pas besoin de la modifier.* </font>
#
#  > **Ecrire votre texte ici.**

# %%
result = optuna.importance.get_param_importances(study)
plt.figure(figsize=(12, 4.5), dpi=100)
names = list(result.keys())
values = list(result.values())

plt.bar(range(len(result)), np.array(values)*100, tick_label=names, color='#000233')
plt.ylabel("Hyperparameter importance (%)")
plt.show()

# %% [markdown]
# #### Influence des hyperparamètres sur le temps de calcul
#
#  <font color="green">*Cette partie du code est complète, vous n'avez pas besoin de la modifier.* </font>
#
#  > **Ecrire votre texte ici.**

# %%
result = optuna.importance.get_param_importances(study, target=lambda t: t.duration.total_seconds())
plt.figure(figsize=(12, 4.5), dpi=100)
names = list(result.keys())
values = list(result.values())

plt.bar(range(len(result)), np.array(values)*100, tick_label=names, color='#000233')
plt.ylabel("Hyperparameter importance (%)")
plt.show()

# %% [markdown]
# #### Frontière de Pareto [[4]](https://fr.wikipedia.org/wiki/Optimum_de_Pareto)
#
#  <font color="green">*Cette partie du code est complète, vous n'avez pas besoin de la modifier.* </font>
#
#  > **Ecrire votre texte ici.**

# %%
import pandas

def plot_pareto_frontier(Xs, Ys, maxX=True, maxY=True):
  # From https://sirinnes.wordpress.com/2013/04/25/pareto-frontier-graphic-via-python/
    '''Pareto frontier selection process'''
    sorted_list = sorted([[Xs[i], Ys[i]] for i in range(len(Xs))], reverse=maxY)
    pareto_front = [sorted_list[0]]
    for pair in sorted_list[1:]:
        if maxY:
            if pair[1] >= pareto_front[-1][1]:
                pareto_front.append(pair)
        else:
            if pair[1] <= pareto_front[-1][1]:
                pareto_front.append(pair)

    '''Plotting process'''
    plt.scatter(Xs,Ys)
    pf_X = [pair[0] for pair in pareto_front]
    pf_Y = [pair[1] for pair in pareto_front]
    plt.plot(pf_X, pf_Y)
    plt.xlabel("Poids du modèle (octets)")
    plt.ylabel("Accuracy (%)")
    plt.show()

df = study.trials_dataframe()
plot_pareto_frontier(df['user_attrs_Size'], df['value'])

# %% [markdown]
# ## Allégement du modèle post-optimisation
#
# Dans cette dernière partie, nous allons nous intéresser à l'influence des performances lorsque le modèle est allégé. Dans des appareils embarqués, il est nécessaire de trouver un compromis entre la performance du modèle, son poids, et la quantité d'opération.
#
# Au vue du nombre de séances, nous allons nous intéressé ici qu'au poids du système.
#
# Pour cela, vous allez essayé de réduire le poids du meilleur modèle obtenu, puis avoir un regard critique sur les performances à chaque modification.
#
# Voici les techniques d'allégement à essayer:
#   - **La quantification**: Réduire le nombre d'octets des paramètres du modèles et les convertir en entiers [[5]](https://www.tensorflow.org/lite/performance/post_training_quantization).
#   - **L'élagage**: Supprimer les modèles qui ont un impact mineur sur les prédictions [[6]](https://www.tensorflow.org/model_optimization/guide/pruning/pruning_with_keras).
#   - **Le clustering**: Regrouper les poids de chaque couche dans un modèle en un nombre prédéfini de clusters, puis en partageant les valeurs centroïdes pour les poids appartenant à chaque cluster individuel [[7]](https://www.tensorflow.org/model_optimization/guide/clustering/clustering_example).
#   - **La décimation** : Réduire le nombre d'entrée.
#
# <font color=" Darkred"> Progression du TP après cette partie (environ 4h):
#
# Essayez d'avoir la meilleure accuracy avec un poids maximum inférieur à 75 KB.
#
#  <font color=" Darkblue"> **Tips:**  Des tutoriels sont disponibles sur les liens attachés au techniques d'allégement. </font>
#
#  > **Ecrire votre texte ici.**

# %% [markdown]
# Pour cette partie nous sommes partis niosu avons suivie les conseils données en [[5]](https://www.tensorflow.org/lite/performance/post_training_quantization). Pour la quantification. Notre modèle étant optimisé via otpuna aux niveaus de ses hyperparamètres, notre architecture ayant pour but d'être porté sur FPGA (comparable à un GPU) et notre dataset n'étant pas représentatif de nos données, nous nous sommes cantonés à une quantification en float16. ![Screenshot from 2025-11-24 01-39-04.png](<attachment:Screenshot from 2025-11-24 01-39-04.png>)

# %% [markdown]
# Tensor Flow Lite permet de réaliser cette conversion en:
#     - float 16 (réduit de moitié la taille du modèle)
#     - int 8
# Les avanatges d'une telle quantification sont les suivants :
#
#     Réduciotn de la taille du modèle de moitié (poids et activation réduit à 16 bits)
#     Pert d'accuracy minimale
#     Rend le calul possible sur architecyure GPU
#
# The disadvantages of float16 quantization are as follows:
#
#     It does not reduce latency as much as a quantization to fixed point math.
#     By default, a float16 quantized model will "dequantize" the weights values to float32 when run on the CPU. (Note that the GPU delegate will not perform this dequantization, since it can operate on float16 data.)

# %%
converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_dir)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_types = [tf.float16]
tflite_quant_model = converter.convert()

# %% [markdown]
# ### BONUS: Allégement avant optimisation
#
# Relancez un fit-tuning en rajoutant les paramètres d'allégements. Puis, observez les resultats avec une frontière de pareto. Les valeurs minimums de poids de la frontière doivent se trouver en dessous de 50 KB.
#
#  <font color=" Darkblue"> **Tips:** Utilisez 2 métriques lorsque vous lancez la fonction d'activation. </font>
#
#  > **Ecrire votre texte ici.**

# %% [markdown]
# ## Conclusion
#
#
#  <font color=" Darkblue"> **Tips:** Concluez sur vos résultats, les limitations de votre modèle et les perspectives envisagées pour l'améliorer. </font>
#
#
#  <font color=" Darkred"> Progression du TP après cette partie (environ 0h30): </font>
#
#
# > **Ecrire votre texte ici.**
