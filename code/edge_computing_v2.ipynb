# %% [markdown]
# <a href="https://colab.research.google.com/github/BenaribIlyes/Edge_computing/blob/main/code/edge_computing_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Travaux Pratiques - N9EE39A Edge Computing
# **Contact: Adrien THIRION ([email](adrien.thirion@nanomade.com))**
# **Créé en Octobre 2023**
#
# L'objectif de ces séances de travaux pratiques est de vous familiariser avec le métier de Data Scientists, plus particulièrement dans un environnement contraint (système embarqué). Celui-ci a été pensé pour développer une vue d'ensemble de toutes les étapes nécessaires lors de la création d'un modèle, jusqu'à ce que celui-ci soit embarqué.
#
# Comme tout bon data scientist, l'utilisation de fonction existante sur internet est vitale !! En effet, l'intelligence artificielle est très présent de nos jours, donc si vous avez un problème, il est presque assuré que quelqu'un ait déjà eu le même !
#
# Le TP va se porter sur un sujet concret: la reconnaissance vocal. Ce sujet rentre dans le thème du Traitement automatique du langage naturel ou NLP [1]) où la demande en IA embarqué est très recherchée (ex. enceinte connecté, smartphone, smartwatches, ..). Pour cela, vous allez vous baser sur une base de données existante se trouvant Kaggle: the TensorFlow Speech Recognition Challenge. Kaggle est un site de competition permettant de récompenser les meilleurs modèles avec des prix décernés aux meilleurs modèles. Cette compétition a été organisée par Google, avec plus de 25 000$ à gagner. Certaines peuvent même dépasser le million de dollard (ex. Netflix Price) donc si vous avez soif d'argent ou que le l'IA vous plaît, allez y jeter un coup d'oeil !
#
# Dans ce projet, vous allez essayer de classer correctement les 12 labels présents dans cette base de donnée via un modèle de convolution 1D ou récursif que vous aurez optimisé. Puis, vous devrez visualiser la variation des performances de ce modèle en fonction de son allégement (dans une volonté de l'embarquer).
#
# Le Rapport devra être fait sur ce jupyter notebook, en Markdown (comme le texte que vous êtes en train de lire).
#
# Ce projet a pour but d'évaluer votre esprit critique, votre analyse d'un problème et votre regard critique sur vos performances. Pour cela, l'entraide est encouragée mais en aucun cas le plagiat. Merci de respecter cela (promis c'est pour votre bien). Expliquez bien votre démarche et la raison de vos choix !!
#
# Le projet sera découpé en 5 TPs de 4h. Un guide de progession sera affiché sur chaque partie pour connaître votre avancement.
#
# Ce projet va être découpé en plusieurs parties:
#
# 1. L'Analyse de la base de donnée.
# 2. L'état de l'art.
# 3. Le Preprocessing.
# 4. L'apprentissage du modèle.
# 5. Les résultats et discussions.
# 6. L'allégement du modèle.
# 7. La conclusion.

# %% [markdown]
# # Analyse de la base de données
#
# La première étape est de télecharger et d'analyser la base de donnée. Pour cela rendez vous sur le site de la compétition:
# https://www.kaggle.com/competitions/tensorflow-speech-recognition-challenge/overview
#
# Pensez à bien regarder la compétition en détail, cela pourra vous être très utile (comme par exemple trouver du code ou des articles).

# %% [markdown]
# # Information sur la base de donnée
#
# Tips: Parlez de tous ce que vous savez des données (quantité d'instances, les labels, la taille d'une time series, sa fréquence d'echantillonage, ...).
#
# Le dossier contient trois fichiers principaux :
# - Train.7z : Les données d'entraînement sont des enregistrements d'une seconde. La fréquence d'échantillonnage est de 16 KHz . Les labels à prédire sont : yes, no, up, down, left, right, on, off, stop, go.
#
# -Test.7z : Contient un dossier de 150,000+ fichiers au format wav.
#
# -Sample_submission.csv - Un exemple de rendu.
# Visualitation d'une donnée et analyse critique
#
# Tips: Faites un subplot de plusieurs labels différents pour voir visuellement les différences.

# %% [markdown]
# # Visualitation d'une donnée et analyse critique
#
# Tips: Faites un subplot de plusieurs labels différents pour voir visuellement les différences.
#
#     Ecrire votre texte ici.

# %%
import matplotlib.pyplot as plt
import numpy as np
import IPython.display as ipd
from scipy.io import wavfile

# %%
#from google.colab import drive # Pour google colab
#drive.mount('/content/drive')  # Pour google colab

# Ajouter ce dossier dans votre drive: https://drive.google.com/drive/folders/1AAiaDTWJzvS6NaZXE_dfJ603QWhhcl0R?usp=sharing
# train_data_path = '/home/zebre/Bureau/IATI/3A/IA_et_materiel/edge_computing/Edge_computing/data/tensorflow-speech-recognition-challenge/train/audio'

# %%
#Pour utiliser le notebook en local

#Préciser le path des données d'entrainements
train_data_path = '/home/zebre/Bureau/eddge_computing/Edge_computing/data/train/audio'

#Préciser le path des données de test
test_data_path = '/home/zebre/Bureau/eddge_computing/Edge_computing/data/test/audio'

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

# Chemin vers les données

labels = os.listdir(train_data_path)[1:]  # On ignore le premier fichier

# Sélection aléatoire de 9 labels
Random_Labels = np.random.choice(labels, size=9, replace=False)

plt.figure(figsize=(15, 8))

for i, label in enumerate(Random_Labels, 1):
    wav_files_path = os.path.join(train_data_path, label)
    random_wav = np.random.choice(os.listdir(wav_files_path))  # un fichier wav aléatoire
    sr, time_series = wavfile.read(os.path.join(wav_files_path, random_wav))

    plt.subplot(3, 3, i)
    plt.plot(time_series)
    plt.grid()
    plt.title(label)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Stockage des données
#  <font color="red"> **ATTENTION:** Respectez l'ordre des labels: 0 = yes, 1 = no, 2 = up, 3 = down, 4 = left, 5 = right, 6 = on, 7 = off, 8 = stop, 9 = go, 10 = silence, 11 = unknown </font>
#
# <font color=" Darkblue"> **Tips:** Réduisez la taille des données d'entrées afin d'éviter la saturation de la mémoire </font>

# %%
import os
import numpy as np
from scipy.io import wavfile
import pandas as pd  # Importer pandas

# Dictionnaire pour identifier les label
Data_Dict = {
      "yes": 0,
      "no": 1,
      "up": 2,
      "down": 3,
      "left": 4,
      "right": 5,
      "on": 6,
      "off": 7,
      "stop": 8,
      "go": 9,
      "_background_noise_": 10,
      "unknown": 11
}

# Dictionnaire inversé pour l'affichage (toujours utile)
ID_to_Label = {v: k for k, v in Data_Dict.items()}

# Constante utilisée dans le code pour représenter l'ID "unknown"
# On récupère la valeur depuis Data_Dict pour éviter NameError si la clé change.
UNKNOWN_ID = Data_Dict.get("unknown", Data_Dict.get("UNKNOWN_ID", 11))


def import_data_as_dataframe(max_files_per_label=100, max_unknown=500, data_path=train_data_path, seed=42, shuffle=True):
    ''' Création d'un dataframe avec les données nécéssaires '''
    rows = []

    # 1) Scanner tous les fichiers et construire la méta-table
    for label in os.listdir(data_path):
        label_path = os.path.join(data_path, label)
        if not os.path.isdir(label_path):
            continue

        label_id = Data_Dict.get(label, UNKNOWN_ID)
        label_name = ID_to_Label.get(label_id, "unknown")

        wav_files = [f for f in os.listdir(label_path) if f.endswith(".wav")]

        for wav_file in wav_files:
            file_path = os.path.join(label_path, wav_file)
            rows.append(
                {
                    "file_path": file_path,
                    "label_id": label_id,
                    "label_name": label_name,
                }
            )

    df_all = pd.DataFrame(rows)

    # 2) Sampling par label (avec quota spécial pour UNKNOWN)
    sampled_dfs = []
    rng = np.random.RandomState(seed)

    for label_id, group in df_all.groupby("label_id"):
        if label_id == UNKNOWN_ID:
            n = min(len(group), max_unknown)
        else:
            n = min(len(group), max_files_per_label)

        sampled = group.sample(n=n, random_state=rng)
        sampled_dfs.append(sampled)

    df = pd.concat(sampled_dfs, ignore_index=True)

    # 3) Shuffle global optionnel
    if shuffle:
        df = df.sample(frac=1.0, random_state=seed).reset_index(drop=True)

    # 4) Lecture des waves suivant le DF final
    all_waves = []
    for file_path in df["file_path"]:
        sr, samples = wavfile.read(file_path)

        if len(samples) > 16000:
            samples = samples[:16000]
        else:
            samples = np.pad(samples, (0, 16000 - len(samples)))

        all_waves.append(samples)

    X = np.array(all_waves) 
    # On peut ne garder que les colonnes de labels si tu veux
    df_labels = df[["label_id", "label_name"]].copy()

    return X, df_labels

# %%
waves, labels = import_data_as_dataframe(max_files_per_label=1000, max_unknown=1000, data_path=train_data_path, seed=42, shuffle=True)
print("Formats des données = ",waves.shape)
print("Formats des labels = ",labels.shape)
# Out:
# /tmp/ipykernel_754440/1296560019.py:79: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sr, samples = wavfile.read(file_path)
# Formats des données =  (11006, 16000)
# Formats des labels =  (11006, 2)

# %% [markdown]
# On as 11006 enregsitrement dans nos donnnées même si on en demande 1000 par classe (avec 12 classes) car on ne dispose que de 6 enregsitemnt de silence.

# %%
# Exemple de donnée
id_exemple = 1

# Signal audio
signal_ex = waves[id_exemple]

# ID + nom du label via le DataFrame
label_id_ex = labels.loc[id_exemple, "label_id"]
label_name_ex = labels.loc[id_exemple, "label_name"]

print(f"Exemple d'échantillon de données : {signal_ex}")
print(f"ID du label : {label_id_ex}")
print(f"Nom du label : {label_name_ex}")

# Lecture audio
ipd.Audio(signal_ex, rate=16000)
# Out:
# Exemple d'échantillon de données : [ -48  -90 -102 ...  -63  -66  -70]
# ID du label : 5
# Nom du label : right
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Etat de l'art
#
# Etape importante qui suit: faire un état de l'art. Que cela soit pour innover, ou pour trouver une solution existante pertinente, faire un état de l'art scientifique est essentiel. Ici, vous devez chercher les articles liés à ce projet. Il faut pour cela remplir le tableau et bien marquer leurs références en dessous. De plus, un texte synthétique vous sera demandé pour expliquer selon vous, quels papiers sont les plus pertinants pour la suite de ce projet.
#
# Attention: une analyse critique est nécessaire sur ces papiers (certain papiers peuvent avoir des biais cachés).
#
# <font color="orange"> **Note anti-plagiat:** Au moins 2 références devraient être différente des autres binômes. </font>
#
# &nbsp;
#
#
# <font color="Darkred"> Progression du TP après cette partie (environ 2h):
#
# &nbsp;
#
# ---
#
# Le véritable état de l'art pour ce défi est construit autour de deux axes majeurs : la définition du jeu de données et la conception d'architectures optimisées pour les contraintes d'embarqué.
#
# ### Tableau Récapitulatif
#
# | Article | Références | Preprocessing | Modèle | Solution Embarquée ? | Dataset utilisé | Performances (Baseline) |
# | :--- | :--- | :--- | :--- | :--- | :--- | :--- |
# | **Warden (2018) [1]** | [1] Speech Commands [cite: 1, 10] | Normalisation à 1 seconde, 16 KHz[cite: 1, 5]. Extraction de la section la plus forte pour l'alignement[cite: 1]. | CNN (Convolutional Neural Network) [cite: 1] – Inspiré de Sainath & Parada[cite: 1]. | **Oui, objectif principal.** Modèles petits, faible consommation d'énergie, minimisation des faux positifs[cite: 1]. | **Speech Commands Dataset v2** (105 829 énonciations de 35 mots)[cite: 1]. | **Top-One Accuracy : 88.2%** (Baseline CNN sur V2)[cite: 1]. |
# | **Zhang et al. (2017) [2]** | [2] Hello Edge [cite: 2] | Conversion du signal audio en **représentations 2D** (Spectrogrammes ou Mel-Spectrogrammes)[cite: 2]. | **DS-CNN** (Depthwise Separable CNN) – Architecture la plus efficace pour les contraintes de taille et de performance[cite: 2]. | **Oui.** Comparaison de l'efficacité des architectures pour l'exécution sur microcontrôleurs (CMSIS-NN)[cite: 2, 8]. | Similaire à [1] (Speech Commands V1)[cite: 2]. | Meilleur équilibre entre précision et efficacité énergétique/taille du modèle[cite: 2]. |
#
# ---
#
#
# ## Références
#
# Les références complètes (format IEEE) pour les sources utilisées dans cette analyse :
#
# 1.  P. Warden, "Speech Commands: A Dataset for Limited-Vocabulary Speech Recognition," *arXiv e-prints*, 2018, art. no. arXiv:1804.03209.
# 2.  Y. Zhang, N. Suda, L. Lai et V. Chandra, "Hello Edge: Keyword Spotting on Microcontrollers," *arXiv e-prints*, 2017, art. no. arXiv:1711.07128.
# 3.  (2018) Speech commands dataset version 2. [Online]. Available: http://download.tensorflow.org/data/speech_commands\_v0.02.tar.gz [cite: 1]
# 4.  (2017) Speech commands dataset version 1. [Online]. Available: http://download.tensorflow.org/data/speech\_commands\_v0.01.tar.gz [cite: 1]
# 5.  (2018) Linguistic data consortium. [Online]. Available: https://www.ldc.upenn.edu/ [cite: 1]
# 6.  J. Deng, W. Dong, R. Socher, L.-J. Li, K. Li, and L. Fei-Fei, "ImageNet: A Large-Scale Hierarchical Image Database," in CVPR09, 2009. [cite: 1]
# 7.  T. N. Sainath and C. Parada, "Convolutional Neural Networks for Small-Footprint Keyword Spotting," in Sixteenth Annual Conference of the International Speech Communication Association, 2015. [Online]. Available: https://www.isca-speech.org/archive/interspeech\_2015/papers/i15\_1478.pdf [cite: 1]
# 8.  L. Lai, N. Suda, and V. Chandra, "CMSIS-NN: Efficient Neural Network Kernels for Arm Cortex-M CPUs," ArXiv e-prints, Jan. 2018. [cite: 1]
# 9.  R. Tang and J. Lin, "Deep Residual Learning for Small-Footprint Keyword Spotting," ArXiv e-prints, Oct. 2017. [cite: 1]
# 10. S. Krishna Gouda, S. Kanetkar, D. Harrison, and M. K. Warmuth, "Speech Recognition: Keyword Spotting Through Image Recognition," ArXiv e-prints, Mar. 2018. [cite: 1]

# %% [markdown]
# ## Preprocessing
#
# C'est la partie la plus importante du projet !! Même le modèle le plus performant de la terre ne pourra pas être précis sans des données d'entrées propres. De plus, il est important de réduire la quantité de données d'entrée (Décimation) afin de ne pas avoir un modèle trop lourd.
#
# <font color=" Darkblue"> **Tips:** Commencez par un preprocessing simple, et améliorez le lorsque les modèles seront en cours d'apprentissage. </font>
#
# Voici quelques sources qui pourront vous être utile pour faire votre code, en plus de l'état de l'art précedemment fait:
# - https://medium.com/enjoy-algorithm/pre-processing-of-time-series-data-c50f8a3e7a98
# - https://monkeylearn.com/blog/data-preprocessing/
# - https://machinelearningmastery.com/machine-learning-data-transforms-for-time-series-forecasting/
# - https://haythamfayek.com/2016/04/21/speech-processing-for-machine-learning.html (pour les plus expérimenté d'entre vous)
#
# &nbsp;
#
# <font color=" Darkred"> Progression du TP après cette partie (environ 3h): </font>
# ![56%](https://progress-bar.dev/56)

# %% [markdown]
# ### Zone d'expérimentation
#
# Ici vous êtes libre d'essayer des choses, les visualiser, avoir un regard critique sur la solution que vous décidez de prendre. Utilisez autant de cases de codes et de textes.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.preprocessing import StandardScaler, MinMaxScaler

def Transformations(transformer, num_points=120):
    """
    Met en évidence l'effet de 5 transformations :
     - Power Transform : rend la distribution plus normale
     - Difference Transform : stationnarise la série
     - Seasonal Transform : enlève la saisonnalité
     - Standardisation : moyenne=0, variance=1
     - Normalisation : valeurs entre 0 et 1
    """

    fig, ax = plt.subplots(1, 2, figsize=(14, 5))

    if transformer == 'Power Transform':
        data = np.random.exponential(2.0, num_points)
        data_boxcox, λ = stats.boxcox(data)
        to_plot = [data, data_boxcox]
        titles = ['Raw Data', f'Power Transform (λ = {λ:.3f})']

    elif transformer == 'Difference Transform':
        t = np.arange(num_points)
        data = 0.5 * t + np.random.normal(0, 5, num_points)
        data_diff = np.diff(data, n=1)
        ax[0].plot(t, data); ax[0].set_title('Données brutes (avec tendance)')
        ax[1].plot(t[1:], data_diff); ax[1].set_title('Après différence (stationnaire)')
        for a in ax: a.grid()
        plt.show()
        return

    elif transformer == 'Seasonal Transform':
        # Série avec tendance et saisonnalité
        t = np.arange(num_points)
        period = 12
        data = 10 + 0.3*t + 5*np.sin(2*np.pi*t/period) + np.random.normal(0, 1, num_points)
        # Seasonal difference
        data_seasonal_diff = data[period:] - data[:-period]
        ax[0].plot(t, data); ax[0].set_title('Données brutes (avec saisonnalité)')
        ax[1].plot(t[period:], data_seasonal_diff); ax[1].set_title(f'Après différence saisonnière (période={period})')
        for a in ax: a.grid()
        plt.show()
        return

    elif transformer == 'Standardisation':
        data = 20 + np.sqrt(5) * np.random.normal(scale=5.0, size=(num_points, 1))
        data_trans = StandardScaler().fit_transform(data)
        to_plot = [data, data_trans]
        titles = ['Données brutes', 'Standardisées ']

    elif transformer == 'Normalisation':
        data = 20 + np.sqrt(5) * np.random.normal(scale=5.0, size=(num_points, 1))
        data_trans = MinMaxScaler().fit_transform(data)
        to_plot = [data, data_trans]
        titles = ['Données brutes', 'Normalisées [0,1]']

    else:
        raise ValueError("Transformer doit être l’un des suivants : "
                         "'Power Transform', 'Difference Transform', 'Seasonal Transform', 'Standardisation', 'Normalisation'.")

    # Affichage commun (histogrammes)
    for i, (d, title) in enumerate(zip(to_plot, titles)):
        ax[i].hist(d, bins=30, edgecolor='black')
        ax[i].set_title(title)
        ax[i].set_xlabel('Valeur')
        ax[i].set_ylabel('Fréquence')
        ax[i].grid()

    plt.tight_layout()
    plt.show()

# %%
# Décommenter pour tester la transformation

#Transformations('Power Transform')
#Transformations('Difference Transform')
#Transformations('Seasonal Transform')
#Transformations('Standardisation')
#Transformations('Normalisation')

# %% [markdown]
# **PS** : En général, l'ordre à suivre pour faire du preprocessing avec ces fonctions est : Power Transform, Seasonal Difference, Trend Difference,Standardization, Normalization.

# %%
# ===========================================================
# Fonctions de prétraitement audio (inspirées de la doc)
# ===========================================================

import numpy as np
from scipy.fftpack import dct
from sklearn.preprocessing import MinMaxScaler

def To_normalize(signal, eps=1e-8):
    """Normalise un enregistrement audio en [-1, 1] par son max absolu."""
    signal = signal.astype(np.float32)
    max_abs = np.max(np.abs(signal)) + eps
    return signal / max_abs

def pre_emphasis_filter(signal, coefficient=0.97):
    """"Filtre numérique passe haut (dérivateur) amplififiant les hautes fréquence, fc = 100Hz (valeur classique)"""
    return signal - coefficient * np.roll(signal, 1)


def framing(signal, frame_length, frame_step, sample_rate):
    """Découpe le signal en trames de durée fixe (fenêtrage temporel)."""
    signal_length = len(signal)
    frame_length = int(round(frame_length * sample_rate))
    frame_step = int(round(frame_step * sample_rate))

    num_frames = int(np.floor((signal_length - frame_length) / frame_step)) + 1
    pad_signal_length = num_frames * frame_step + frame_length
    z = np.zeros((pad_signal_length - signal_length))
    pad_signal = np.append(signal, z)

    indices = np.tile(np.arange(0, frame_length), (num_frames, 1)) + \
              np.tile(np.arange(0, num_frames * frame_step, frame_step), (frame_length, 1)).T

    frames = pad_signal[indices.astype(np.int32, copy=False)]
    return frames


def window_hamming(frames):
    """Applique une fenêtre de Hamming pour lisser les trames."""
    frame_length = len(frames[0])
    windowed_frames = np.zeros(frames.shape)
    for i in range(len(frames)):
        windowed_frames[i] = frames[i] * np.hamming(frame_length)
    return windowed_frames


def fft(windowed_frames, NFFT=512):
    """Calcule le spectre de puissance de chaque trame (FFT)."""
    mag_frames = np.absolute(np.fft.rfft(windowed_frames, NFFT))
    pow_frames = ((1.0 / NFFT) * (mag_frames ** 2))
    return pow_frames


def filter_bank(pow_frames, sample_rate, NFFT=512, nfilt=40):
    """Applique un banc de filtres de Mel pour regrouper les fréquences."""
    low_freq_mel = 0
    high_freq_mel = 2595 * np.log10(1 + (sample_rate / 2) / 700)
    mel_points = np.linspace(low_freq_mel, high_freq_mel, nfilt + 2)
    hz_points = 700 * (10**(mel_points / 2595) - 1)
    bin = np.floor((NFFT + 1) * hz_points / sample_rate)

    fbank = np.zeros((nfilt, int(np.floor(NFFT / 2 + 1))))
    for m in range(1, nfilt + 1):
        f_m_minus = int(bin[m - 1])
        f_m = int(bin[m])
        f_m_plus = int(bin[m + 1])

        for k in range(f_m_minus, f_m):
            fbank[m - 1, k] = (k - bin[m - 1]) / (bin[m] - bin[m - 1])
        for k in range(f_m, f_m_plus):
            fbank[m - 1, k] = (bin[m + 1] - k) / (bin[m + 1] - bin[m])

    filter_banks = np.dot(pow_frames, fbank.T)
    filter_banks = np.where(filter_banks == 0, np.finfo(float).eps, filter_banks)
    filter_banks = 20 * np.log10(filter_banks)
    return filter_banks


def mfcc_coeffs(filter_banks, num_ceps=12, ceplifter=22):
    """Extrait les coefficients cepstraux MFCC à partir des filtres de Mel."""
    mfcc = dct(filter_banks, type=2, axis=1, norm='ortho')[:, 1:(num_ceps + 1)]
    (nframes, ncoeff) = mfcc.shape
    n = np.arange(ncoeff)
    lift = 1 + (ceplifter / 2) * np.sin(np.pi * n / ceplifter)
    mfcc *= lift
    return mfcc


def Mean_Norm(Data):
    """Centre les données (MFCC ou filter banks) autour de leur moyenne."""
    Mean_Data = np.zeros(Data.shape)
    for i in range(Data.shape[0]):
        Mean_Data[i] = Data[i] - np.mean(Data[i])
    return Mean_Data

# %%
import librosa
import librosa.display

# Visualisation de l'effet des fonctions précédentes

# Chemin vers les données
labels = os.listdir(train_data_path)[1:]  # On ignore le premier fichier

# Sélection aléatoire d'un fichier wav
Random_Label = np.random.choice(labels, size=len(labels), replace=False)
wav_files_path = os.path.join(train_data_path, Random_Labels[0])
random_wav = np.random.choice(os.listdir(wav_files_path))  # un fichier wav aléatoire
sr, signal = wavfile.read(os.path.join(wav_files_path, random_wav))

# Application des transformations
signal = signal / np.max(np.abs(signal)) # Normalisation
emphasized_signal = pre_emphasis_filter(signal)
frames = framing(signal, frame_length=0.025, frame_step=0.01, sample_rate=sr) # fenêtres de 25ms
windowed_frames = window_hamming(frames)
pow_frames = fft(windowed_frames)
log_spectrogram = 10 * np.log10(pow_frames.T + 1e-8) # Pour la visualisation
filter_banks = filter_bank(pow_frames, sample_rate = sr)
filter_banks = Mean_Norm(filter_banks)
mfcc = mfcc_coeffs(filter_banks, num_ceps=12, ceplifter=22)
mfcc = Mean_Norm(mfcc)


# Débogage
print(f'Taille du signal :{signal.shape}')
print(f'Taille du signal filtré :{emphasized_signal.shape}')
print(f'Taille des fenêtres :{frames.shape}')
print(f'Taille des fenêtres après hamming :{windowed_frames.shape}')
print(f'Taille des fenêtres après fft :{pow_frames.shape}')
print(f'Taille du spectrogramme :{log_spectrogram.shape}')
print(f'Taille des filter banks :{filter_banks.shape}')
print(f'Taille des MFCCs :{mfcc.shape}')

### Affichage des figures

# Signaux Temporels
plt.figure(figsize=(18, 6))
plt.subplot(1, 3, 1)
plt.plot(np.arange(len(signal))/sr,signal)
plt.xlabel("Temps (s)")
plt.ylabel("Amplitude")
plt.grid()
plt.title('Données brutes')

plt.subplot(1, 3, 2)
plt.plot(np.arange(len(emphasized_signal))/sr,emphasized_signal)
plt.xlabel("Temps (s)")
plt.ylabel("Amplitude")
plt.grid()
plt.title('Données filtrées')

plt.subplot(1, 3, 3)
plt.plot(np.arange(len(windowed_frames)),np.mean(windowed_frames, axis=1))
plt.xlabel("Temps (s)")
plt.ylabel("Amplitude")
plt.title('Données après hamming')
plt.grid()

# Signaux Fréquentiels
plt.figure(figsize=(18, 6))
plt.subplot(1, 3, 1)
librosa.display.specshow(log_spectrogram,
                         sr=sr,
                         hop_length=int(0.01 * sr),
                         x_axis='time',
                         y_axis='linear',
                         cmap='turbo')
plt.title('Spectrogramme (FFT par trame)')
plt.xlabel("Temps (s)")
plt.ylabel("Fréquence (Hz)")

plt.subplot(1, 3, 2)
librosa.display.specshow(filter_banks.T, sr=sr, hop_length=int(0.01*sr),
                         x_axis='time', y_axis='mel', cmap='turbo')
plt.xlabel("Temps (s)")
plt.title("Bancs de filtres Mel (énergies en dB)")

plt.subplot(1,3,3)
librosa.display.specshow(mfcc.T, sr=sr, hop_length=int(0.01*sr),
                         x_axis='time', cmap='turbo')
plt.xlabel("Temps (s)")
plt.title("MFCC (Coefficients Cepstraux)")

plt.tight_layout()
plt.show()
# Out:
# Taille du signal :(16000,)
# Taille du signal filtré :(16000,)
# Taille des fenêtres :(98, 400)
# Taille des fenêtres après hamming :(98, 400)
# Taille des fenêtres après fft :(98, 257)
# Taille du spectrogramme :(257, 98)
# Taille des filter banks :(98, 40)
# Taille des MFCCs :(98, 12)

# %% [markdown]
# Pour de l'audio, les démarches à suivre sont donc :
# **Normalisation de l'audio → Pré-accentuation → framing → Fenêtrage → FFT → Banc de filtres Mel → Calcul des MFCC → Normalisation des coefficients.**

# %% [markdown]
# ### Fonction de preprocessing
#
# > **Ecrire votre texte ici.**

# %%
def To_normalize(signal, eps=1e-8):
    """Normalise un enregistrement audio en [-1, 1] par son max absolu."""
    signal = signal.astype(np.float32)
    max_abs = np.max(np.abs(signal)) + eps
    return signal / max_abs


def preprocessing(inputs,
                  type='mfccs',
                  sample_rate=16000,
                  frame_length=0.025,
                  frame_step=0.01,
                  NFFT=512,
                  nfilt=40,
                  num_ceps=12,
                  ceplifter=22):
    """
    inputs : array de forme (nb_fichiers, 16000)
    type   : 'mfccs' | 'spectrogramme' | 'mel'
    """
    clean_inputs = []
    eps = 1e-8

    for i in range(inputs.shape[0]):
        # 1) Normalisation par enregistrement
        x = To_normalize(inputs[i])               # (16000,)

        # 2) Pré-accentuation
        x = pre_emphasis_filter(x)                # (16000,)

        # 3) Framing + fenêtre de Hamming
        frames = framing(x,
                         frame_length=frame_length,
                         frame_step=frame_step,
                         sample_rate=sample_rate)  # (~nb_frames, frame_len)
        windowed_frames = window_hamming(frames)

        # 4) FFT -> spectre de puissance
        pow_frames = fft(windowed_frames, NFFT=NFFT)

        if type == 'mfccs':
            # Banc de filtres Mel
            filter_banks = filter_bank(pow_frames,
                                       sample_rate=sample_rate,
                                       NFFT=NFFT,
                                       nfilt=nfilt)
            filter_banks = Mean_Norm(filter_banks)

            # MFCC
            mfcc = mfcc_coeffs(filter_banks,
                               num_ceps=num_ceps,
                               ceplifter=ceplifter)
            mfcc = Mean_Norm(mfcc)

            max_abs = max(np.max(np.abs(mfcc)), eps)
            clean_inputs.append(mfcc / max_abs)

        elif type == 'spectrogramme':
            # Spectrogramme log
            log_spectrogram = 10 * np.log10(
                np.clip(pow_frames.T, a_min=eps, a_max=None)
            )
            max_abs = max(np.max(np.abs(log_spectrogram)), eps)
            clean_inputs.append(log_spectrogram / max_abs)

        elif type == 'mel':
            # Banc de filtres Mel sans DCT
            filter_banks = filter_bank(pow_frames,
                                       sample_rate=sample_rate,
                                       NFFT=NFFT,
                                       nfilt=nfilt)
            filter_banks = Mean_Norm(filter_banks)
            max_abs = max(np.max(np.abs(filter_banks)), eps)
            clean_inputs.append(filter_banks / max_abs)

        else:
            raise ValueError("type doit être 'mfccs', 'spectrogramme' ou 'mel'.")

    return np.array(clean_inputs, dtype=np.float32)

# %%
'''
print(f'Input before preprocessing: {all_waves.shape}')
processed_waves = preprocessing(all_waves)
print(f'Input after preprocessing: {processed_waves.shape}')
'''
# Out:
# "\nprint(f'Input before preprocessing: {all_waves.shape}')\nprocessed_waves = preprocessing(all_waves)\nprint(f'Input after preprocessing: {processed_waves.shape}')\n"

# %% [markdown]
# Etant donné que le processing prend 15min pour éviter cette étape redondante nous avons chosie de sauveharder les données dans un fichier 'preprocessed_audio.npz'. Le code en dessous est à commenté pour utiliser nos données pré-process.

# %%
'''
print("Sauvegarde des données en cours...")
# 'X' et 'y' sont les noms que nous donnons aux "clés" dans le fichier
np.savez_compressed(
    'preprocessed_audio_mfcc', 
    X=processed_waves, 
    y=all_labels
)
print("Données sauvegardées dans 'code/preprocessed_audio_mfcc.npz'")
'''
# Out:
# '\nprint("Sauvegarde des données en cours...")\n# \'X\' et \'y\' sont les noms que nous donnons aux "clés" dans le fichier\nnp.savez_compressed(\n    \'preprocessed_audio_mfcc\', \n    X=processed_waves, \n    y=all_labels\n)\nprint("Données sauvegardées dans \'code/preprocessed_audio_mfcc.npz\'")\n'

# %% [markdown]
# Pour charger ces données.

# %%
print("Chargement des données depuis le fichier 'preprocessed_audio_mfcc'")
# Charger le fichier .npz
data_file = np.load('preprocessed_audio_mfcc.npz')

# On accéde aux variables par les clés 
X_train_processed = data_file['X']
y_train_processed = data_file['y']

print(f"Données chargées ! Forme X: {X_train_processed.shape}, Forme y: {y_train_processed.shape}")
# Out:
# Chargement des données depuis le fichier 'preprocessed_audio_mfcc'
# Données chargées ! Forme X: (11006, 98, 12), Forme y: (11006,)

# %% [markdown]
# ## Apprentissage du Modèle
# On y est, il est temps de créer un modèle. Pour cela, il vous sera imposé d'utiliser un réseau de convolution 1D [2] (https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv1D). Nous préconisons l'utilisation de Tensorflow mais vous êtes libre d'utiliser d'autres librairies comme Pytorch.
#
# &nbsp;
#
# <font color=" Darkred"> Progression du TP après cette partie (environ 3h): </font>
# ![75%](https://progress-bar.dev/75)

# %% [markdown]
# ### Train set, Validation set
#
# Avant d'entraîner votre modèle, pensez à séparer vos données d'entraînements et vos données de validations. Puis, pensez à créer des batchs pour correspondre à l'entrée de votre modèle.
#
# Plus d'infos ici:
#  - https://www.tensorflow.org/datasets/splits?hl=fr
#  - https://towardsdatascience.com/how-to-split-a-dataframe-into-train-and-test-set-with-python-eaa1630ca7b3
#  - https://www.tensorflow.org/tutorials/customization/custom_training_walkthrough?hl=fr
#
#  <font color=" Darkblue"> **Tips:** Pensez à bien mélanger vos données avant de les séparer. </font>
#
#  <font color="orange"> **Note anti-plagiat:** Le mélange doit avoir une random seed fixe et différente pour chaque groupe. </font>

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split

# Définirion de la seed 
tf.random.set_seed(42)

# Toutes les données
X_Data = X_train_processed
y_Data = y_train_processed
NUM_CLASSES = 12

# 1. Division initiale : Entraînement (80%) et Temporaire (20%)
X_train, x_temp, y_train, y_temp = train_test_split(X_Data, y_Data, test_size=0.3, random_state=42)

# 2. Division de l'ensemble Temporaire : Validation (10%) et Test (10%)
X_val, X_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

print(f"Taille de l'ensemble d'entraînement: {X_train.shape[0]}")
print(f"Taille de l'ensemble de validation: {X_val.shape[0]}")
print(f"Taille de l'ensemble de test: {X_test.shape[0]} \n")

# 3. Encodage des données
y_train = tf.keras.utils.to_categorical(y_train, num_classes=NUM_CLASSES)
y_val = tf.keras.utils.to_categorical(y_val, num_classes=NUM_CLASSES)

# 4. Préparation des Datasets de tf
BATCH_SIZE = 64

X_train = np.expand_dims(X_train, axis=-1)
train = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train = train.batch(BATCH_SIZE, drop_remainder=True)

X_val = np.expand_dims(X_val, axis=-1)
val = tf.data.Dataset.from_tensor_slices((X_val, y_val))
val = val.batch(BATCH_SIZE, drop_remainder=True)

# 5. Vérification des Dimensions
for example_inputs, example_labels in train.take(1):
    print(f'Inputs shape (batch, time/frames, features): {example_inputs.shape}')
    print(f'Labels shape (batch, num_classes): {example_labels.shape}')
# Out:
# 2025-11-28 03:27:14.680517: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-28 03:27:14.688421: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764296834.698484  754440 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764296834.701749  754440 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-28 03:27:14.712858: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Taille de l'ensemble d'entraînement: 7704
# Taille de l'ensemble de validation: 1651
# Taille de l'ensemble de test: 1651
#
# Inputs shape (batch, time/frames, features): (64, 98, 12, 1)
# Labels shape (batch, num_classes): (64, 12)
# I0000 00:00:1764296835.965967  754440 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5615 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2025-11-28 03:27:16.112539: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ### Baseline
#
# La baseline est importante afin de connaître le seuil où le modèle est performant. A vous de trouver la meilleure baseline et d'expliquer votre choix.
#
# Plus d'infos ici:
# https://towardsdatascience.com/calculating-a-baseline-accuracy-for-a-classification-model-a4b342ceb88f
#
# > **Ecrire votre texte ici.**

# %% [markdown]
# La baseline de notre modèle doit être fixé de sorte a dépassé le Zero Rate, c'est à dire la fréquence de la classe la plus fréquente. On créer la fonction qui nous permets de calculer ce score.

# %%
def calculate_zeroR_with_pandas(labels_series):
    """
    Calcule la précision du ZeroR à partir de nos données.
    """
    if labels_series.empty:
        return 0.0, None, None

    # 1. Compter la fréquence de chaque label (plus simple avec value_counts)
    # value_counts() trie déjà par fréquence (décroissant)
    label_counts = labels_series.value_counts()
    
    # 2. Identifier la classe majoritaire
    major_label_name = label_counts.index[0]
    major_label_count = label_counts.iloc[0]
    
    # 3. Calculer le taux de précision
    total_samples = len(labels_series)
    zeroR_accuracy = major_label_count / total_samples
    
    return zeroR_accuracy, major_label_name

# %% [markdown]
# Boucle pour calculer la baseline à partir datasframe pandas

# %%
# 1. Importer les données
waves, labels_df = import_data_as_dataframe(max_files_per_label=1000, data_path=train_data_path)

print(f"Total d'échantillons importés: {len(labels_df)}")
print("-" * 30)
print("Aperçu du DataFrame des labels :")
print(labels_df.head())
print("-" * 30)

# 2. Calculer le ZeroR
# Nous utilisons la colonne 'label_name' pour des résultats lisibles
accuracy, major_label = calculate_zeroR_with_pandas(labels_df['label_name'])

# 3. Afficher les résultats
print(f"Classe majoritaire (ZeroR): '{major_label}'")
print(f"Précision du ZeroR (Baseline) : {accuracy:.4f} (soit {accuracy*100:.2f}%)")
# Out:
# /tmp/ipykernel_754440/1296560019.py:79: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sr, samples = wavfile.read(file_path)
# Total d'échantillons importés: 10506
# ------------------------------
# Aperçu du DataFrame des labels :
#    label_id label_name
# 0         0        yes
# 1         9         go
# 2         5      right
# 3         4       left
# 4         4       left
# ------------------------------
# Classe majoritaire (ZeroR): 'yes'
# Précision du ZeroR (Baseline) : 0.0952 (soit 9.52%)

# %% [markdown]
# On as donc une baseline de 0.67 à dépassé d'après le ZeroR.

# %%
# TO DO
result_train, result_val = 0, 0 # à effacer

print(f'Train dataset: {result_train}%')
print(f'Validation dataset: {result_val}%')
# Out:
# Train dataset: 0%
# Validation dataset: 0%

# %% [markdown]
# ### Modèle
#
# Vous devez créer une fonction permettant de générer le modèle. Celle-ci doit pouvoir être modifiable en fonction des Hyperparamètres mis en entrée.
#
#  <font color="red"> **ATTENTION:** Une limite de 150 000 paramètres est imposés. </font>
#
# Justification de vos choix (Choix des paramètres modifiables, fonction d'activations, nombres de couches, regularizers, ...) :
# > **Ecrire votre texte ici.**

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# %%
def total_param(model):
  """Calcule et affiche le nombre total de paramètres du modèle."""
  total_params = model.count_params()
  print(f"Nombre de poids du modèle: {total_params:,}")
  return total_params


def create_model(param, input_shape, num_classes):
  """
  Crée un modèle DS-CNN (Depthwise Separable CNN) pour une entrée 2D (ex: MFCCs).
  Les hyperparamètres sont contrôlés par le dictionnaire 'param'.
  """
  model = models.Sequential()

  # taille du kernel (tombe sur 3 si clé absente)
  k = param.get('kernell', 3)

  # --- Couche d'Entrée ---
  model.add(layers.Input(shape=input_shape))

  # --- Bloc Conv2D Standard (pour l'extraction initiale) ---
  model.add(layers.Conv2D(param['conv_filters'], (k, k), 
                           strides=(1, 1), 
                           padding='same', 
                           activation=param['activation']))
  model.add(layers.BatchNormalization())

  # --- Bloc DS-CNN 1 --- couche clé : SeparableConv2D
  model.add(layers.SeparableConv2D(param['ds_filters_1'], (k, k), 
                                    padding='same', 
                                    activation=param['activation']))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))

  # --- Bloc DS-CNN 2 ---
  model.add(layers.SeparableConv2D(param['ds_filters_2'], (k, k), 
                                    padding='same', 
                                    activation=param['activation']))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))

  # --- Tête de Classification ---
  model.add(layers.GlobalAveragePooling2D())
  
  model.add(layers.Dense(param['dense_units'], activation=param['activation']))
  model.add(layers.Dropout(param['dropout_rate']))
  
  # Couche de sortie finale
  model.add(layers.Dense(num_classes, activation='softmax'))
  
  return model
 
# PARAMÈTRES MIS À JOUR (pour le DS-CNN)
param = {
    'activation'    : 'relu',
    'conv_filters'  : 32,    # Filtres pour la première couche Conv2D
    'ds_filters_1'  : 64,    # Filtres pour le premier bloc DS-CNN
    'ds_filters_2'  : 64,    # Filtres pour le second bloc DS-CNN
    'dense_units'   : 32,    # Neurones dans la couche dense finale
    'dropout_rate'  : 0.5,   # Taux de dropout pour la régularisation
    'kernell'       : 3      # Taille des kernels pour la convolution 
}

# Remarque : vos entrées MFCC pré-traitées ont la forme (98, 12, 1) dans les batches.
# Adapter INPUT_SHAPE pour correspondre aux données (frames, coeffs, channels).
INPUT_SHAPE = (98, 12, 1)  # 98 timesteps, 12 coefficients MFCC, 1 canal
NUM_CLASSES= 12

model = create_model(param, INPUT_SHAPE, NUM_CLASSES)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 98, 12, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 98, 12, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d                │ (None, 98, 12, 64)     │         2,400 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 98, 12, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 49, 6, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d_1              │ (None, 49, 6, 64)      │         4,736 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 49, 6, 64)      │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 24, 3, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 12)             │           396 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,572 (41.30 KB)
#  Trainable params: 10,252 (40.05 KB)
#  Non-trainable params: 320 (1.25 KB)

# %% [markdown]
# ### Fonction d'entraînement
#
# Cette fonction doit prendre un modèle en entrée et l'entrainer grâce au Train set. Puis, retourner les performances obtenues avec le Validation set.
#
# Pour les plus expérimentés d'entre vous: Vous pouvez réaliser une cross validation [[2]](https://datascientest.com/cross-validation).
#
# Justification de vos choix (Choix des paramètres modifiables, optimizer, nombres d'epoch, learning rate, ...) :
# > **Ecrire votre texte ici.**

# %%
def compile_and_fit(model, train, val, param, verbose=1):
    
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                    patience=20, # 20 est bien
                                                    mode='min',
                                                    restore_best_weights=True) # Important !

    # Pour les plus confirmés
    lr = tf.optimizers.schedules.ExponentialDecay(
         initial_learning_rate=1e-2,
         decay_steps=1000,
         decay_rate=0.95)

    # lr =  1e-3 # Augmentation du LR

    model.compile(loss='categorical_crossentropy', 
                metrics=['accuracy',
                tf.keras.metrics.Precision(name='precision'),
                tf.keras.metrics.Recall(name='recall')])

    # 1. Capturer l'historique de l'entraînement
    history = model.fit(train, epochs=train_param['max_epochs'],
                      validation_data=val,
                      callbacks=[early_stopping], 
                      verbose=verbose)

    # 2. Évaluer le modèle (qui a restauré les meilleurs poids)
    validation_evaluation = model.evaluate(val, verbose=0) # verbose=0 pour nettoyer la sortie
    
    # 3. Renvoyer les résultats
    return validation_evaluation, model, history


train_param = {
    # Exemple de paramètres à modifier
    'max_epochs' : 100, # On fixe max_epochs haut et utilise early stopping 
    'BATCH_SIZE' : 64
}

def plot_training_history(history):
    """
    Trace les courbes d'apprentissage pour la perte, l'accuracy, la précision 
    et le rappel (training vs validation).
    """
    
    # Données de l'historique
    history_data = history.history
    
    # Noms des métriques
    loss = history_data['loss']
    val_loss = history_data['val_loss']
    accuracy = history_data['accuracy']
    val_accuracy = history_data['val_accuracy']
    precision = history_data['precision']
    val_precision = history_data['val_precision']
    recall = history_data['recall']
    val_recall = history_data['val_recall']
    
    epochs = range(1, len(accuracy) + 1)

    # --- Plot 1: Perte (Loss) ---
    plt.figure(figsize=(14, 7))
    plt.subplot(1, 2, 1) # Grille 1x2, premier graphique
    plt.plot(epochs, loss, 'bo-', label='Perte (Entraînement)')
    plt.plot(epochs, val_loss, 'r*-', label='Perte (Validation)')
    plt.title('Courbe de Perte (Loss)')
    plt.xlabel('Époques')
    plt.ylabel('Perte')
    plt.legend()
    plt.grid(True)

    # --- Plot 2: Précision (Accuracy) ---
    plt.subplot(1, 2, 2) # Grille 1x2, deuxième graphique
    plt.plot(epochs, accuracy, 'bo-', label='Accuracy (EnMabor), esttraînement)')
    plt.plot(epochs, val_accuracy, 'r*-', label='Accuracy (Validation)')
    plt.title('Courbe de Précision (Accuracy)')
    plt.xlabel('Époques')
    plt.ylabel('Précision')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout() # Ajuste l'espacement
    plt.show() # Affiche les deux premiers graphiques

    # --- Plot 3: Précision (Precision) vs Rappel (Recall) ---
    plt.figure(figsize=(14, 7))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, precision, 'bo-', label='Précision (Entraînement)')
    plt.plot(epochs, val_precision, 'r*-', label='Précision (Validation)')
    plt.title('Courbe de Précision (Precision)')
    plt.xlabel('Époques')
    plt.ylabel('Précision')
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs, recall, 'bo-', label='Rappel (Entraînement)')
    plt.plot(epochs, val_recall, 'r*-', label='Rappel (Validation)')
    plt.title('Courbe de Rappel (Recall)')
    plt.xlabel('Époques')
    plt.ylabel('Rappel')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show() # Affiche les deux derniers graphiques

# validation_accuracy = compile_and_fit(model, train, val, param)

# %%
# (Assurez-vous que 'model', 'train', 'val', et 'param' sont définis)

# 1. Exécutez l'entraînement ET récupérez l'historique
print("Lancement de l'entraînement...")
validation_eval, trained_model, history = compile_and_fit(model, train, val, param)

print("\nÉvaluation finale sur le set de validation :", validation_eval)

# 2. Tracez les graphiques
print("Affichage des courbes d'apprentissage...")
plot_training_history(history)
# Out:
# Lancement de l'entraînement...
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764296838.034122  754510 service.cc:148] XLA service 0x70213c020430 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1764296838.034138  754510 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4060, Compute Capability 8.9
# 2025-11-28 03:27:18.074695: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1764296838.182532  754510 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  46/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1149 - loss: 2.5233 - precision: 0.0000e+00 - recall: 0.0000e+00
# I0000 00:00:1764296840.865752  754510 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.1635 - loss: 2.3529 - precision: 0.5000 - recall: 1.3021e-04 - val_accuracy: 0.0919 - val_loss: 2.5025 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2815 - loss: 2.0809 - precision: 0.7184 - recall: 0.0096 - val_accuracy: 0.0919 - val_loss: 2.5302 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3469 - loss: 1.8673 - precision: 0.7068 - recall: 0.0527 - val_accuracy: 0.1400 - val_loss: 2.4943 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4198 - loss: 1.6659 - precision: 0.7549 - recall: 0.1199 - val_accuracy: 0.1944 - val_loss: 2.3875 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4866 - loss: 1.4981 - precision: 0.7820 - recall: 0.1952 - val_accuracy: 0.3181 - val_loss: 1.9513 - val_precision: 0.8750 - val_recall: 0.0088
# Epoch 6/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5228 - loss: 1.3800 - precision: 0.7801 - recall: 0.2466 - val_accuracy: 0.4744 - val_loss: 1.4506 - val_precision: 0.8762 - val_recall: 0.1769
# Epoch 7/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5612 - loss: 1.2678 - precision: 0.7936 - recall: 0.3120 - val_accuracy: 0.6662 - val_loss: 1.0653 - val_precision: 0.8775 - val_recall: 0.3537
# Epoch 8/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5885 - loss: 1.2059 - precision: 0.7796 - recall: 0.3542 - val_accuracy: 0.7038 - val_loss: 0.9732 - val_precision: 0.9129 - val_recall: 0.4194
# Epoch 9/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6145 - loss: 1.1244 - precision: 0.8031 - recall: 0.3990 - val_accuracy: 0.7119 - val_loss: 0.8979 - val_precision: 0.8842 - val_recall: 0.4869
# Epoch 10/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6413 - loss: 1.0613 - precision: 0.8110 - recall: 0.4421 - val_accuracy: 0.7094 - val_loss: 0.9078 - val_precision: 0.8687 - val_recall: 0.5088
# Epoch 11/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6478 - loss: 1.0310 - precision: 0.8145 - recall: 0.4625 - val_accuracy: 0.7337 - val_loss: 0.8282 - val_precision: 0.8783 - val_recall: 0.5550
# Epoch 12/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6668 - loss: 0.9615 - precision: 0.8206 - recall: 0.5044 - val_accuracy: 0.7531 - val_loss: 0.7930 - val_precision: 0.8767 - val_recall: 0.6000
# Epoch 13/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6797 - loss: 0.9336 - precision: 0.8304 - recall: 0.5201 - val_accuracy: 0.7350 - val_loss: 0.8286 - val_precision: 0.8612 - val_recall: 0.6012
# Epoch 14/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6905 - loss: 0.9014 - precision: 0.8226 - recall: 0.5414 - val_accuracy: 0.7525 - val_loss: 0.7505 - val_precision: 0.8457 - val_recall: 0.6475
# Epoch 15/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7013 - loss: 0.8656 - precision: 0.8218 - recall: 0.5577 - val_accuracy: 0.7106 - val_loss: 0.8840 - val_precision: 0.8338 - val_recall: 0.6081
# Epoch 16/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7065 - loss: 0.8400 - precision: 0.8343 - recall: 0.5775 - val_accuracy: 0.7519 - val_loss: 0.7529 - val_precision: 0.8536 - val_recall: 0.6525
# Epoch 17/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7164 - loss: 0.8206 - precision: 0.8339 - recall: 0.5879 - val_accuracy: 0.7719 - val_loss: 0.7137 - val_precision: 0.8673 - val_recall: 0.6737
# Epoch 18/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7319 - loss: 0.7884 - precision: 0.8471 - recall: 0.6124 - val_accuracy: 0.7731 - val_loss: 0.6940 - val_precision: 0.8625 - val_recall: 0.6744
# Epoch 19/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7371 - loss: 0.7722 - precision: 0.8417 - recall: 0.6240 - val_accuracy: 0.7494 - val_loss: 0.7132 - val_precision: 0.8375 - val_recall: 0.6762
# Epoch 20/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7423 - loss: 0.7448 - precision: 0.8424 - recall: 0.6395 - val_accuracy: 0.6844 - val_loss: 0.9534 - val_precision: 0.7477 - val_recall: 0.6150
# Epoch 21/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7453 - loss: 0.7332 - precision: 0.8459 - recall: 0.6353 - val_accuracy: 0.7912 - val_loss: 0.6510 - val_precision: 0.8727 - val_recall: 0.7069
# Epoch 22/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7508 - loss: 0.7054 - precision: 0.8507 - recall: 0.6530 - val_accuracy: 0.7819 - val_loss: 0.6405 - val_precision: 0.8585 - val_recall: 0.7206
# Epoch 23/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7565 - loss: 0.7023 - precision: 0.8485 - recall: 0.6579 - val_accuracy: 0.7325 - val_loss: 0.8287 - val_precision: 0.8355 - val_recall: 0.6475
# Epoch 24/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7645 - loss: 0.6867 - precision: 0.8517 - recall: 0.6685 - val_accuracy: 0.7513 - val_loss: 0.7839 - val_precision: 0.8251 - val_recall: 0.6900
# Epoch 25/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7779 - loss: 0.6518 - precision: 0.8612 - recall: 0.6905 - val_accuracy: 0.7756 - val_loss: 0.6782 - val_precision: 0.8425 - val_recall: 0.7256
# Epoch 26/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7681 - loss: 0.6530 - precision: 0.8565 - recall: 0.6816 - val_accuracy: 0.7806 - val_loss: 0.6698 - val_precision: 0.8431 - val_recall: 0.7256
# Epoch 27/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7783 - loss: 0.6343 - precision: 0.8609 - recall: 0.7033 - val_accuracy: 0.7962 - val_loss: 0.6170 - val_precision: 0.8607 - val_recall: 0.7375
# Epoch 28/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7789 - loss: 0.6308 - precision: 0.8621 - recall: 0.6983 - val_accuracy: 0.7619 - val_loss: 0.7172 - val_precision: 0.8181 - val_recall: 0.7138
# Epoch 29/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7949 - loss: 0.6023 - precision: 0.8711 - recall: 0.7207 - val_accuracy: 0.7725 - val_loss: 0.6845 - val_precision: 0.8430 - val_recall: 0.7212
# Epoch 30/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7915 - loss: 0.5911 - precision: 0.8703 - recall: 0.7182 - val_accuracy: 0.7569 - val_loss: 0.7563 - val_precision: 0.8083 - val_recall: 0.7088
# Epoch 31/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8000 - loss: 0.5757 - precision: 0.8817 - recall: 0.7290 - val_accuracy: 0.7906 - val_loss: 0.6382 - val_precision: 0.8424 - val_recall: 0.7519
# Epoch 32/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8040 - loss: 0.5673 - precision: 0.8780 - recall: 0.7345 - val_accuracy: 0.8131 - val_loss: 0.5864 - val_precision: 0.8605 - val_recall: 0.7825
# Epoch 33/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8078 - loss: 0.5550 - precision: 0.8791 - recall: 0.7414 - val_accuracy: 0.7025 - val_loss: 0.9818 - val_precision: 0.7441 - val_recall: 0.6687
# Epoch 34/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8081 - loss: 0.5505 - precision: 0.8798 - recall: 0.7368 - val_accuracy: 0.7538 - val_loss: 0.7647 - val_precision: 0.7949 - val_recall: 0.7194
# Epoch 35/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8099 - loss: 0.5335 - precision: 0.8843 - recall: 0.7507 - val_accuracy: 0.7169 - val_loss: 0.8987 - val_precision: 0.7636 - val_recall: 0.6906
# Epoch 36/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8148 - loss: 0.5322 - precision: 0.8828 - recall: 0.7501 - val_accuracy: 0.7706 - val_loss: 0.7033 - val_precision: 0.8134 - val_recall: 0.7494
# Epoch 37/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8204 - loss: 0.5131 - precision: 0.8867 - recall: 0.7611 - val_accuracy: 0.7188 - val_loss: 0.9546 - val_precision: 0.7631 - val_recall: 0.6925
# Epoch 38/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8299 - loss: 0.4951 - precision: 0.8932 - recall: 0.7729 - val_accuracy: 0.7763 - val_loss: 0.7396 - val_precision: 0.8125 - val_recall: 0.7638
# Epoch 39/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8242 - loss: 0.4926 - precision: 0.8864 - recall: 0.7734 - val_accuracy: 0.8188 - val_loss: 0.5520 - val_precision: 0.8632 - val_recall: 0.7969
# Epoch 40/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8288 - loss: 0.4917 - precision: 0.8842 - recall: 0.7725 - val_accuracy: 0.8138 - val_loss: 0.5802 - val_precision: 0.8530 - val_recall: 0.7944
# Epoch 41/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8323 - loss: 0.4920 - precision: 0.8888 - recall: 0.7757 - val_accuracy: 0.7869 - val_loss: 0.6953 - val_precision: 0.8201 - val_recall: 0.7719
# Epoch 42/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8341 - loss: 0.4708 - precision: 0.8924 - recall: 0.7811 - val_accuracy: 0.7725 - val_loss: 0.7617 - val_precision: 0.8173 - val_recall: 0.7437
# Epoch 43/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8328 - loss: 0.4802 - precision: 0.8893 - recall: 0.7775 - val_accuracy: 0.7775 - val_loss: 0.7183 - val_precision: 0.8184 - val_recall: 0.7494
# Epoch 44/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8387 - loss: 0.4626 - precision: 0.8949 - recall: 0.7897 - val_accuracy: 0.8269 - val_loss: 0.5895 - val_precision: 0.8559 - val_recall: 0.8094
# Epoch 45/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8441 - loss: 0.4571 - precision: 0.8991 - recall: 0.7992 - val_accuracy: 0.8081 - val_loss: 0.6390 - val_precision: 0.8486 - val_recall: 0.7881
# Epoch 46/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8402 - loss: 0.4505 - precision: 0.8954 - recall: 0.7939 - val_accuracy: 0.8144 - val_loss: 0.6298 - val_precision: 0.8467 - val_recall: 0.7906
# Epoch 47/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8496 - loss: 0.4393 - precision: 0.9012 - recall: 0.8065 - val_accuracy: 0.8238 - val_loss: 0.5951 - val_precision: 0.8558 - val_recall: 0.8087
# Epoch 48/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8536 - loss: 0.4173 - precision: 0.9029 - recall: 0.8083 - val_accuracy: 0.7806 - val_loss: 0.8683 - val_precision: 0.8143 - val_recall: 0.7700
# Epoch 49/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8548 - loss: 0.4165 - precision: 0.9049 - recall: 0.8139 - val_accuracy: 0.8131 - val_loss: 0.6636 - val_precision: 0.8485 - val_recall: 0.7875
# Epoch 50/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8603 - loss: 0.4070 - precision: 0.9056 - recall: 0.8197 - val_accuracy: 0.8356 - val_loss: 0.5243 - val_precision: 0.8634 - val_recall: 0.8175
# Epoch 51/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8561 - loss: 0.4042 - precision: 0.9030 - recall: 0.8135 - val_accuracy: 0.8331 - val_loss: 0.5971 - val_precision: 0.8649 - val_recall: 0.8163
# Epoch 52/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8572 - loss: 0.3981 - precision: 0.9006 - recall: 0.8190 - val_accuracy: 0.8281 - val_loss: 0.6455 - val_precision: 0.8520 - val_recall: 0.8094
# Epoch 53/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8587 - loss: 0.4007 - precision: 0.9072 - recall: 0.8161 - val_accuracy: 0.8419 - val_loss: 0.6066 - val_precision: 0.8780 - val_recall: 0.8231
# Epoch 54/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8632 - loss: 0.3853 - precision: 0.9060 - recall: 0.8255 - val_accuracy: 0.8438 - val_loss: 0.5475 - val_precision: 0.8714 - val_recall: 0.8300
# Epoch 55/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8618 - loss: 0.3796 - precision: 0.9049 - recall: 0.8243 - val_accuracy: 0.8381 - val_loss: 0.6177 - val_precision: 0.8687 - val_recall: 0.8188
# Epoch 56/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8665 - loss: 0.3774 - precision: 0.9111 - recall: 0.8299 - val_accuracy: 0.8650 - val_loss: 0.4860 - val_precision: 0.8978 - val_recall: 0.8512
# Epoch 57/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8663 - loss: 0.3830 - precision: 0.9105 - recall: 0.8281 - val_accuracy: 0.8344 - val_loss: 0.6618 - val_precision: 0.8547 - val_recall: 0.8275
# Epoch 58/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8697 - loss: 0.3685 - precision: 0.9140 - recall: 0.8358 - val_accuracy: 0.8419 - val_loss: 0.5924 - val_precision: 0.8677 - val_recall: 0.8363
# Epoch 59/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8730 - loss: 0.3565 - precision: 0.9147 - recall: 0.8404 - val_accuracy: 0.8500 - val_loss: 0.5127 - val_precision: 0.8774 - val_recall: 0.8363
# Epoch 60/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8736 - loss: 0.3596 - precision: 0.9155 - recall: 0.8378 - val_accuracy: 0.8238 - val_loss: 0.7541 - val_precision: 0.8466 - val_recall: 0.8106
# Epoch 61/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8727 - loss: 0.3553 - precision: 0.9134 - recall: 0.8388 - val_accuracy: 0.8319 - val_loss: 0.6049 - val_precision: 0.8585 - val_recall: 0.8188
# Epoch 62/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8723 - loss: 0.3625 - precision: 0.9123 - recall: 0.8384 - val_accuracy: 0.8075 - val_loss: 0.8257 - val_precision: 0.8251 - val_recall: 0.7931
# Epoch 63/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8738 - loss: 0.3558 - precision: 0.9110 - recall: 0.8375 - val_accuracy: 0.8156 - val_loss: 0.7773 - val_precision: 0.8390 - val_recall: 0.8012
# Epoch 64/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8745 - loss: 0.3487 - precision: 0.9141 - recall: 0.8436 - val_accuracy: 0.8181 - val_loss: 0.7280 - val_precision: 0.8447 - val_recall: 0.8025
# Epoch 65/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8767 - loss: 0.3454 - precision: 0.9168 - recall: 0.8409 - val_accuracy: 0.8375 - val_loss: 0.6496 - val_precision: 0.8618 - val_recall: 0.8263
# Epoch 66/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8816 - loss: 0.3280 - precision: 0.9165 - recall: 0.8521 - val_accuracy: 0.8394 - val_loss: 0.7073 - val_precision: 0.8554 - val_recall: 0.8281
# Epoch 67/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8806 - loss: 0.3273 - precision: 0.9149 - recall: 0.8527 - val_accuracy: 0.8350 - val_loss: 0.6388 - val_precision: 0.8599 - val_recall: 0.8213
# Epoch 68/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8806 - loss: 0.3280 - precision: 0.9186 - recall: 0.8496 - val_accuracy: 0.8213 - val_loss: 0.8218 - val_precision: 0.8453 - val_recall: 0.8094
# Epoch 69/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8827 - loss: 0.3282 - precision: 0.9218 - recall: 0.8518 - val_accuracy: 0.8319 - val_loss: 0.7813 - val_precision: 0.8471 - val_recall: 0.8275
# Epoch 70/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8784 - loss: 0.3359 - precision: 0.9185 - recall: 0.8551 - val_accuracy: 0.8494 - val_loss: 0.5670 - val_precision: 0.8749 - val_recall: 0.8350
# Epoch 71/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8913 - loss: 0.3141 - precision: 0.9230 - recall: 0.8615 - val_accuracy: 0.8450 - val_loss: 0.6753 - val_precision: 0.8669 - val_recall: 0.8388
# Epoch 72/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8806 - loss: 0.3228 - precision: 0.9177 - recall: 0.8526 - val_accuracy: 0.8438 - val_loss: 0.5887 - val_precision: 0.8611 - val_recall: 0.8369
# Epoch 73/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8866 - loss: 0.3231 - precision: 0.9205 - recall: 0.8549 - val_accuracy: 0.8225 - val_loss: 0.7231 - val_precision: 0.8396 - val_recall: 0.8144
# Epoch 74/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8857 - loss: 0.3166 - precision: 0.9208 - recall: 0.8611 - val_accuracy: 0.8356 - val_loss: 0.6913 - val_precision: 0.8597 - val_recall: 0.8231
# Epoch 75/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8945 - loss: 0.3020 - precision: 0.9274 - recall: 0.8648 - val_accuracy: 0.8381 - val_loss: 0.6653 - val_precision: 0.8526 - val_recall: 0.8313
# Epoch 76/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8866 - loss: 0.3116 - precision: 0.9212 - recall: 0.8617 - val_accuracy: 0.8288 - val_loss: 0.6829 - val_precision: 0.8604 - val_recall: 0.8169
#
# Évaluation finale sur le set de validation : [0.4860078692436218, 0.8650000095367432, 0.8978246450424194, 0.8512499928474426]
# Affichage des courbes d'apprentissage...

# %% [markdown]
# ### Fit tuning des hyperparamètres.
#
# Après avoir défini les hyperparamètres modifiables et vérifier que les fonctions fonctionnent, il est temps de lancer l'optimisation des hyperparamètres. Pour cela je vous invite à utiliser Optuna [[3]](https://optuna.readthedocs.io/en/stable/index.html) qui a plusieurs fonctionnalités:
# *   Une visualisation facilitée.
# *   Un suivi de l'avancement de l'optimisation.
# *   Une possibilité de reprendre l'optimisation sans reprendre depuis le début si un problème arrive durant le traitement.
#
#  <font color=" Darkblue"> **Tips:** Essayez de lancer l'optimisation pendant le TP pour voir si il fonctionne et arretez le. Lancez le pour de bon à la fin de la séance ou pendant la semaine car cela va prendre plusieurs heures, voir plusieurs jours. </font>
#
#  <font color="orange"> **Note anti-plagiat:** L'optimisation doit avoir une random seed fixe et différente pour chaque groupe. </font>
#
#  Merci de justifier vos plages de valeurs et faite un résumé sous forme de tableau :
#  > **Ecrire votre texte ici.**
#
#
#  | Hyperparamètre | Meilleure valeur | Plage | Step | Type de la plage |
# | :---------------- | :------: | :----: | :----: | :----: |
# | -   |  -  | - | - | - |

# %%
import optuna

SEED = 42
np.random.seed(SEED)

ALPHA = 1e-6 # Sert de méthode de pénalisation 

def objective(trial):
    # 1) Tirage des hyperparamètres
    param_model = {
        "activation"  : trial.suggest_categorical("activation", ["relu", "leaky_relu"]),
        "conv_filters": trial.suggest_categorical("conv_filters", [16, 32, 64, 128]), # on reste en puissance de dexu pour simplififer implémentation
        "ds_filters_1": trial.suggest_categorical("ds_filters_1", [16, 32, 64, 128]),
        "ds_filters_2": trial.suggest_categorical("ds_filters_2", [16, 32, 64, 128]),
        "dense_units" : trial.suggest_categorical("dense_units", [16, 32, 64, 128]),
        "dropout_rate": trial.suggest_float("dropout_rate", 0.1, 0.5),
        "kernell"     :  3 # Fixé pour simplififer la zone de recherche des hyperparamètre en accord avec littérature
    }
    param_training = {
        "BATCH_SIZE": trial.suggest_categorical("BATCH_SIZE", [16, 32, 64, 128]),
    }

    # 2) Création + taille du modèle
    model = create_model(param_model, INPUT_SHAPE, NUM_CLASSES)
    size = total_param(model)
    trial.set_user_attr("Size", size)

    # 3) Entraînement + métriques
    metrics, _, _ = compile_and_fit(model, train, val, param_training, verbose=0)
    val_acc = metrics[1]  # adapte si besoin

    # 4) On renvoie 2 objectifs : (à max, à min)
    return val_acc, size   # 1er objectif = accuracy, 2e = taille


study_name = "Benarib~Hanni-Tuning-embedded"
storage_name = f'/home/zebre/Bureau/eddge_computing/Edge_computing/model/{study_name}.db' #Chemin à créer dans votre drive

storage_url = f"sqlite:///{storage_name}"


study = optuna.create_study(
    directions=["maximize", "minimize"],
    study_name="Benarib~Hanni-Tuning-embedded",
    storage=storage_url,
    sampler=optuna.samplers.TPESampler(seed=SEED),
    load_if_exists=True,
)
# Out:
# [I 2025-11-28 03:34:30,946] A new study created in RDB with name: Benarib~Hanni-Tuning-embedded

# %%
study.optimize(objective, n_trials=300)
# Out:
# Nombre de poids du modèle: 8,284
# [I 2025-11-28 03:35:00,067] Trial 0 finished with values: [0.7787500023841858, 8284.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 16, 'ds_filters_1': 32, 'ds_filters_2': 32, 'dense_units': 128, 'dropout_rate': 0.2727780074568463, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 3,964
# [I 2025-11-28 03:35:25,470] Trial 1 finished with values: [0.7825000286102295, 3964.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 16, 'ds_filters_1': 32, 'ds_filters_2': 32, 'dense_units': 32, 'dropout_rate': 0.29807076404450805, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 14,444
# [I 2025-11-28 03:35:53,442] Trial 2 finished with values: [0.7462499737739563, 14444.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 64, 'ds_filters_1': 16, 'ds_filters_2': 128, 'dense_units': 64, 'dropout_rate': 0.2123738038749523, 'BATCH_SIZE': 64}.
# Nombre de poids du modèle: 10,924
# [I 2025-11-28 03:36:19,863] Trial 3 finished with values: [0.8243749737739563, 10924.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 32, 'ds_filters_2': 32, 'dense_units': 128, 'dropout_rate': 0.35502298854208525, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 15,196
# [I 2025-11-28 03:36:52,647] Trial 4 finished with values: [0.8387500047683716, 15196.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 128, 'ds_filters_2': 64, 'dense_units': 32, 'dropout_rate': 0.21590058116550723, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 4,060
# [I 2025-11-28 03:37:20,543] Trial 5 finished with values: [0.8162500262260437, 4060.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 64, 'dense_units': 16, 'dropout_rate': 0.2350460685614512, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 11,644
# 2025-11-28 03:37:21.986106: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_914', 4 bytes spill stores, 4 bytes spill loads
#
# [I 2025-11-28 03:37:52,945] Trial 6 finished with values: [0.8100000023841858, 11644.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 16, 'ds_filters_1': 64, 'ds_filters_2': 64, 'dense_units': 64, 'dropout_rate': 0.3688542189623515, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 46,540
# 2025-11-28 03:37:55.042703: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1334', 496 bytes spill stores, 496 bytes spill loads
#
# [I 2025-11-28 03:38:35,789] Trial 7 finished with values: [0.8031250238418579, 46540.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 64, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.1550083776583973, 'BATCH_SIZE': 64}.
# Nombre de poids du modèle: 13,388
# [I 2025-11-28 03:38:58,340] Trial 8 finished with values: [0.7787500023841858, 13388.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 16, 'ds_filters_1': 64, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.1646514856378455, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 7,580
# [I 2025-11-28 03:39:29,680] Trial 9 finished with values: [0.8187500238418579, 7580.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 32, 'ds_filters_2': 64, 'dense_units': 16, 'dropout_rate': 0.19759585735163343, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 2,284
# [I 2025-11-28 03:39:53,019] Trial 10 finished with values: [0.731249988079071, 2284.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.4630659181130071, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 2,284
# [I 2025-11-28 03:40:21,320] Trial 11 finished with values: [0.7356250286102295, 2284.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.4698931520025013, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 2,284
# [I 2025-11-28 03:40:49,371] Trial 12 finished with values: [0.7418749928474426, 2284.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.47959782802015327, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 6,028
# [I 2025-11-28 03:42:02,362] Trial 13 finished with values: [0.768750011920929, 6028.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 16, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.40729529100093786, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 2,284
# [I 2025-11-28 03:42:26,648] Trial 14 finished with values: [0.7306249737739563, 2284.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.4985986685955974, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 2,284
# [I 2025-11-28 03:42:54,555] Trial 15 finished with values: [0.7749999761581421, 2284.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.4122676071774375, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 15,004
# [I 2025-11-28 03:43:39,799] Trial 16 finished with values: [0.809374988079071, 15004.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 64, 'ds_filters_2': 16, 'dense_units': 64, 'dropout_rate': 0.41785814564483564, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 9,692
# [I 2025-11-28 03:44:06,300] Trial 17 finished with values: [0.7743750214576721, 9692.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 128, 'ds_filters_2': 16, 'dense_units': 32, 'dropout_rate': 0.10189604786123574, 'BATCH_SIZE': 64}.
# Nombre de poids du modèle: 4,060
# [I 2025-11-28 03:44:32,309] Trial 18 finished with values: [0.7925000190734863, 4060.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 64, 'dense_units': 16, 'dropout_rate': 0.3532393958394535, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 7,420
# [I 2025-11-28 03:45:33,611] Trial 19 finished with values: [0.8018749952316284, 7420.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 16, 'ds_filters_2': 16, 'dense_units': 64, 'dropout_rate': 0.4183509774407929, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 17,036
# [I 2025-11-28 03:45:54,530] Trial 20 finished with values: [0.8349999785423279, 17036.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 64, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.27309824447219666, 'BATCH_SIZE': 64}.
# Nombre de poids du modèle: 12,684
# 2025-11-28 03:45:56.043650: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_894', 4 bytes spill stores, 4 bytes spill loads
#
# [I 2025-11-28 03:46:13,477] Trial 21 finished with values: [0.7906249761581421, 12684.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 64, 'dense_units': 128, 'dropout_rate': 0.2491934944583717, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 4,060
# [I 2025-11-28 03:46:32,948] Trial 22 finished with values: [0.7587500214576721, 4060.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 64, 'dense_units': 16, 'dropout_rate': 0.32246920214870844, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 4,124
# [I 2025-11-28 03:46:56,436] Trial 23 finished with values: [0.7912499904632568, 4124.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 32, 'ds_filters_2': 32, 'dense_units': 16, 'dropout_rate': 0.3241629071621045, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 13,932
# [I 2025-11-28 03:47:24,365] Trial 24 finished with values: [0.8337500095367432, 13932.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 16, 'ds_filters_2': 64, 'dense_units': 128, 'dropout_rate': 0.3801151332999178, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 30,876
# [I 2025-11-28 03:49:00,859] Trial 25 finished with values: [0.8206250071525574, 30876.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 128, 'ds_filters_1': 128, 'ds_filters_2': 64, 'dense_units': 16, 'dropout_rate': 0.24130156228948735, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 4,060
# [I 2025-11-28 03:49:20,907] Trial 26 finished with values: [0.8118749856948853, 4060.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 64, 'dense_units': 16, 'dropout_rate': 0.15322010485379767, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 12,684
# [I 2025-11-28 03:49:43,654] Trial 27 finished with values: [0.8056250214576721, 12684.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 64, 'dense_units': 128, 'dropout_rate': 0.10575756811731069, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 5,308
# [I 2025-11-28 03:50:25,374] Trial 28 finished with values: [0.7406250238418579, 5308.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 64, 'ds_filters_1': 16, 'ds_filters_2': 64, 'dense_units': 16, 'dropout_rate': 0.1878471468538629, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 11,660
# [I 2025-11-28 03:50:45,659] Trial 29 finished with values: [0.7162500023841858, 11660.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 32, 'ds_filters_1': 64, 'ds_filters_2': 32, 'dense_units': 128, 'dropout_rate': 0.27766369979073025, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 32,108
# [I 2025-11-28 03:51:39,902] Trial 30 finished with values: [0.871874988079071, 32108.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 128, 'ds_filters_2': 64, 'dense_units': 32, 'dropout_rate': 0.376065444516962, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 15,196
# [I 2025-11-28 03:52:10,050] Trial 31 finished with values: [0.8231250047683716, 15196.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 128, 'ds_filters_2': 64, 'dense_units': 32, 'dropout_rate': 0.23394575005731605, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 15,196
# [I 2025-11-28 03:52:38,023] Trial 32 finished with values: [0.8506249785423279, 15196.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 128, 'ds_filters_2': 64, 'dense_units': 32, 'dropout_rate': 0.21938953969759892, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 15,196
# [I 2025-11-28 03:53:16,736] Trial 33 finished with values: [0.8656250238418579, 15196.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 128, 'ds_filters_2': 64, 'dense_units': 32, 'dropout_rate': 0.3095104426414292, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 5,404
# [I 2025-11-28 03:53:34,211] Trial 34 finished with values: [0.800000011920929, 5404.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 32, 'ds_filters_2': 32, 'dense_units': 64, 'dropout_rate': 0.2996228189209774, 'BATCH_SIZE': 64}.
# Nombre de poids du modèle: 5,884
# [I 2025-11-28 03:54:14,495] Trial 35 finished with values: [0.7806249856948853, 5884.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 64, 'ds_filters_1': 32, 'ds_filters_2': 32, 'dense_units': 16, 'dropout_rate': 0.33727008045743423, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 15,980
# [I 2025-11-28 03:54:36,164] Trial 36 finished with values: [0.8612499833106995, 15980.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 64, 'dropout_rate': 0.4458176136819663, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 7,292
# [I 2025-11-28 03:54:52,206] Trial 37 finished with values: [0.6812499761581421, 7292.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 16, 'ds_filters_1': 16, 'ds_filters_2': 32, 'dense_units': 128, 'dropout_rate': 0.26229607751654904, 'BATCH_SIZE': 64}.
# Nombre de poids du modèle: 10,972
# [I 2025-11-28 03:55:26,646] Trial 38 finished with values: [0.8606250286102295, 10972.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.29047803106618103, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 10,972
# [I 2025-11-28 03:55:59,850] Trial 39 finished with values: [0.8500000238418579, 10972.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.2931782307969313, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 10,972
# [I 2025-11-28 03:56:24,182] Trial 40 finished with values: [0.846875011920929, 10972.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.19416443970912306, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 33,004
# [I 2025-11-28 03:57:04,164] Trial 41 finished with values: [0.8662499785423279, 33004.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.3873581745714001, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 14,492
# [I 2025-11-28 03:57:46,852] Trial 42 finished with values: [0.8443750143051147, 14492.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.3108639173732691, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 25,756
# [I 2025-11-28 03:58:20,469] Trial 43 finished with values: [0.8556249737739563, 25756.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.2831483345042142, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 12,124
# [I 2025-11-28 03:58:47,561] Trial 44 finished with values: [0.768750011920929, 12124.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 64, 'ds_filters_1': 64, 'ds_filters_2': 64, 'dense_units': 16, 'dropout_rate': 0.25715057465814156, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 5,820
# [I 2025-11-28 03:59:14,001] Trial 45 finished with values: [0.8212500214576721, 5820.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 32, 'ds_filters_2': 64, 'dense_units': 16, 'dropout_rate': 0.22635673356173827, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 5,036
# [I 2025-11-28 03:59:53,247] Trial 46 finished with values: [0.7893750071525574, 5036.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 32, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.351244890596835, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 10,972
# [I 2025-11-28 04:00:32,742] Trial 47 finished with values: [0.8531249761581421, 10972.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.44806913025917583, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 3,276
# [I 2025-11-28 04:00:52,441] Trial 48 finished with values: [0.7900000214576721, 3276.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 32, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.226207612518041, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 5,036
# [I 2025-11-28 04:01:34,663] Trial 49 finished with values: [0.793749988079071, 5036.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 64, 'ds_filters_1': 32, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.39780056525089574, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 6,428
# [I 2025-11-28 04:01:56,408] Trial 50 finished with values: [0.8081250190734863, 6428.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.340149056959964, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 7,276
# [I 2025-11-28 04:02:38,295] Trial 51 finished with values: [0.809374988079071, 7276.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 128, 'ds_filters_2': 16, 'dense_units': 32, 'dropout_rate': 0.3672744457377956, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 42,668
# [I 2025-11-28 04:03:38,762] Trial 52 finished with values: [0.8893749713897705, 42668.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.4315362995483448, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 32,108
# [I 2025-11-28 04:04:25,092] Trial 53 finished with values: [0.8631250262260437, 32108.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 128, 'ds_filters_2': 64, 'dense_units': 32, 'dropout_rate': 0.17534098823611644, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 12,428
# [I 2025-11-28 04:05:19,425] Trial 54 finished with values: [0.8287500143051147, 12428.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 16, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.1354884276799052, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 34,572
# [I 2025-11-28 04:06:07,339] Trial 55 finished with values: [0.8668749928474426, 34572.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 128, 'ds_filters_2': 64, 'dense_units': 64, 'dropout_rate': 0.428200855215117, 'BATCH_SIZE': 64}.
# Nombre de poids du modèle: 9,036
# [I 2025-11-28 04:06:35,441] Trial 56 finished with values: [0.7543749809265137, 9036.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 16, 'ds_filters_2': 64, 'dense_units': 32, 'dropout_rate': 0.21220496201853964, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 17,036
# [I 2025-11-28 04:07:09,198] Trial 57 finished with values: [0.8556249737739563, 17036.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 64, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.49712266137748706, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 4,060
# [I 2025-11-28 04:07:35,766] Trial 58 finished with values: [0.815625011920929, 4060.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 64, 'dense_units': 16, 'dropout_rate': 0.3121466327888366, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 25,116
# [I 2025-11-28 04:08:34,013] Trial 59 finished with values: [0.8368750214576721, 25116.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 128, 'ds_filters_2': 16, 'dense_units': 64, 'dropout_rate': 0.43013059208267246, 'BATCH_SIZE': 64}.
# Nombre de poids du modèle: 4,060
# [I 2025-11-28 04:08:58,956] Trial 60 finished with values: [0.7631250023841858, 4060.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 64, 'dense_units': 16, 'dropout_rate': 0.3681588926099558, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 42,668
# [I 2025-11-28 04:09:57,886] Trial 61 finished with values: [0.8881250023841858, 42668.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.4030265112333315, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 7,276
# [I 2025-11-28 04:10:33,255] Trial 62 finished with values: [0.8012499809265137, 7276.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 128, 'ds_filters_2': 16, 'dense_units': 32, 'dropout_rate': 0.3872569631610704, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 42,668
# [I 2025-11-28 04:11:22,208] Trial 63 finished with values: [0.8687499761581421, 42668.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.4446480959209539, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 10,972
# [I 2025-11-28 04:11:55,875] Trial 64 finished with values: [0.8368750214576721, 10972.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.4615280601460169, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 10,060
# [I 2025-11-28 04:12:33,242] Trial 65 finished with values: [0.824999988079071, 10060.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 128, 'ds_filters_2': 16, 'dense_units': 128, 'dropout_rate': 0.41674196575217226, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 9,340
# [I 2025-11-28 04:13:00,935] Trial 66 finished with values: [0.8356249928474426, 9340.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 64, 'ds_filters_2': 64, 'dense_units': 16, 'dropout_rate': 0.2677191014705458, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 9,340
# [I 2025-11-28 04:13:29,985] Trial 67 finished with values: [0.8237500190734863, 9340.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 64, 'ds_filters_2': 64, 'dense_units': 16, 'dropout_rate': 0.24958207855667655, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 4,060
# [I 2025-11-28 04:13:56,130] Trial 68 finished with values: [0.8137500286102295, 4060.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 64, 'dense_units': 16, 'dropout_rate': 0.29165135245867513, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 7,916
# [I 2025-11-28 04:14:07,338] Trial 69 finished with values: [0.6431249976158142, 7916.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 32, 'dense_units': 128, 'dropout_rate': 0.2677366366754912, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 7,756
# [I 2025-11-28 04:14:27,351] Trial 70 finished with values: [0.8037499785423279, 7756.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 64, 'dense_units': 64, 'dropout_rate': 0.21007317145188925, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 24,188
# [I 2025-11-28 04:15:20,300] Trial 71 finished with values: [0.84375, 24188.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 128, 'ds_filters_2': 16, 'dense_units': 32, 'dropout_rate': 0.43401382577010117, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 9,180
# [I 2025-11-28 04:15:46,888] Trial 72 finished with values: [0.8331249952316284, 9180.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 64, 'ds_filters_2': 64, 'dense_units': 32, 'dropout_rate': 0.40940347882490064, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 30,876
# [I 2025-11-28 04:16:44,623] Trial 73 finished with values: [0.856249988079071, 30876.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 128, 'ds_filters_2': 64, 'dense_units': 16, 'dropout_rate': 0.33308399837238073, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 9,692
# [I 2025-11-28 04:17:23,150] Trial 74 finished with values: [0.8037499785423279, 9692.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 128, 'ds_filters_2': 16, 'dense_units': 32, 'dropout_rate': 0.31226945741805867, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 5,804
# [I 2025-11-28 04:17:52,417] Trial 75 finished with values: [0.7975000143051147, 5804.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 16, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.37704654163667484, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 16,380
# [I 2025-11-28 04:18:32,996] Trial 76 finished with values: [0.8537499904632568, 16380.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 128, 'ds_filters_2': 64, 'dense_units': 16, 'dropout_rate': 0.2823977838368847, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 6,604
# [I 2025-11-28 04:19:05,122] Trial 77 finished with values: [0.8268749713897705, 6604.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 32, 'ds_filters_2': 32, 'dense_units': 32, 'dropout_rate': 0.4804362207102201, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 4,844
# [I 2025-11-28 04:19:40,218] Trial 78 finished with values: [0.800000011920929, 4844.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 16, 'ds_filters_2': 32, 'dense_units': 32, 'dropout_rate': 0.48772351147126963, 'BATCH_SIZE': 64}.
# Nombre de poids du modèle: 4,844
# [I 2025-11-28 04:20:15,596] Trial 79 finished with values: [0.8075000047683716, 4844.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 16, 'ds_filters_2': 32, 'dense_units': 32, 'dropout_rate': 0.45840408360389484, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 8,556
# [I 2025-11-28 04:21:02,456] Trial 80 finished with values: [0.7881249785423279, 8556.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.3547053315115066, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 13,228
# [I 2025-11-28 04:21:34,043] Trial 81 finished with values: [0.8512499928474426, 13228.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.24876946803231534, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 10,588
# [I 2025-11-28 04:21:56,451] Trial 82 finished with values: [0.8193749785423279, 10588.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.47434707142737104, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 22,444
# [I 2025-11-28 04:22:27,305] Trial 83 finished with values: [0.8525000214576721, 22444.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 128, 'ds_filters_2': 64, 'dense_units': 32, 'dropout_rate': 0.2376212055971853, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 42,668
# [I 2025-11-28 04:23:24,688] Trial 84 finished with values: [0.8756250143051147, 42668.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.3233981838179564, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 5,884
# [I 2025-11-28 04:23:54,279] Trial 85 finished with values: [0.8056250214576721, 5884.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 32, 'ds_filters_2': 32, 'dense_units': 16, 'dropout_rate': 0.3027546620851054, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 15,196
# [I 2025-11-28 04:24:42,887] Trial 86 finished with values: [0.8331249952316284, 15196.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 16, 'ds_filters_1': 128, 'ds_filters_2': 64, 'dense_units': 32, 'dropout_rate': 0.39807868757696324, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 14,492
# [I 2025-11-28 04:25:35,934] Trial 87 finished with values: [0.84375, 14492.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.2259057276990602, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 20,748
# [I 2025-11-28 04:26:06,664] Trial 88 finished with values: [0.846875011920929, 20748.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 64, 'ds_filters_2': 64, 'dense_units': 128, 'dropout_rate': 0.2653249260657987, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 42,668
# [I 2025-11-28 04:26:47,719] Trial 89 finished with values: [0.8456249833106995, 42668.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.4229763754528106, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 3,276
# [I 2025-11-28 04:27:09,737] Trial 90 finished with values: [0.7806249856948853, 3276.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 32, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.27198063240915127, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 13,964
# [I 2025-11-28 04:27:47,073] Trial 91 finished with values: [0.84375, 13964.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 128, 'ds_filters_2': 64, 'dense_units': 16, 'dropout_rate': 0.4419205525140418, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 21,260
# [I 2025-11-28 04:28:21,521] Trial 92 finished with values: [0.8256250023841858, 21260.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 64, 'dropout_rate': 0.34085678813564746, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 17,612
# [I 2025-11-28 04:29:10,364] Trial 93 finished with values: [0.8118749856948853, 17612.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 32, 'ds_filters_1': 128, 'ds_filters_2': 64, 'dense_units': 32, 'dropout_rate': 0.2896309824042707, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 6,812
# [I 2025-11-28 04:30:05,604] Trial 94 finished with values: [0.7906249761581421, 6812.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 128, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.3621915586284823, 'BATCH_SIZE': 64}.
# Nombre de poids du modèle: 13,228
# [I 2025-11-28 04:30:30,586] Trial 95 finished with values: [0.8387500047683716, 13228.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.30127516701633067, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 17,692
# [I 2025-11-28 04:31:35,151] Trial 96 finished with values: [0.8506249785423279, 17692.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 64, 'ds_filters_2': 64, 'dense_units': 16, 'dropout_rate': 0.4110096362003221, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 25,916
# [I 2025-11-28 04:32:14,027] Trial 97 finished with values: [0.8550000190734863, 25916.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.37732070213604, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 9,020
# [I 2025-11-28 04:32:45,418] Trial 98 finished with values: [0.7599999904632568, 9020.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 16, 'dense_units': 32, 'dropout_rate': 0.2594516071392422, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 13,932
# [I 2025-11-28 04:33:22,024] Trial 99 finished with values: [0.8081250190734863, 13932.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 64, 'ds_filters_1': 16, 'ds_filters_2': 64, 'dense_units': 128, 'dropout_rate': 0.34563576018560277, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 25,916
# [I 2025-11-28 04:33:58,002] Trial 100 finished with values: [0.8687499761581421, 25916.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.2259369865399879, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 9,212
# [I 2025-11-28 04:34:18,671] Trial 101 finished with values: [0.8368750214576721, 9212.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.22567052322708775, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 9,212
# [I 2025-11-28 04:34:41,785] Trial 102 finished with values: [0.846875011920929, 9212.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.1898038038776182, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 6,428
# [I 2025-11-28 04:35:10,161] Trial 103 finished with values: [0.8268749713897705, 6428.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.1817070910025254, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 6,428
# [I 2025-11-28 04:35:40,619] Trial 104 finished with values: [0.8287500143051147, 6428.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.1423984504889832, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 6,428
# [I 2025-11-28 04:36:00,228] Trial 105 finished with values: [0.8274999856948853, 6428.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.1359317281390227, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 6,428
# [I 2025-11-28 04:36:28,992] Trial 106 finished with values: [0.8224999904632568, 6428.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.19798694358657154, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 2,284
# [I 2025-11-28 04:36:56,159] Trial 107 finished with values: [0.7537500262260437, 2284.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.15869727572949346, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 25,916
# [I 2025-11-28 04:37:34,794] Trial 108 finished with values: [0.8512499928474426, 25916.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.2026267979020241, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 6,428
# [I 2025-11-28 04:37:58,599] Trial 109 finished with values: [0.7681249976158142, 6428.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.4527356121852831, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 9,228
# [I 2025-11-28 04:38:33,244] Trial 110 finished with values: [0.7912499904632568, 9228.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 128, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.11871814825917687, 'BATCH_SIZE': 64}.
# Nombre de poids du modèle: 32,684
# [I 2025-11-28 04:39:11,225] Trial 111 finished with values: [0.8600000143051147, 32684.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 64, 'dropout_rate': 0.4364415290700243, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 1,660
# [I 2025-11-28 04:39:35,016] Trial 112 finished with values: [0.7012500166893005, 1660.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 16, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.39480950489651556, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 1,660
# [I 2025-11-28 04:39:58,972] Trial 113 finished with values: [0.7425000071525574, 1660.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 16, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.3952532020863405, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 23,500
# [I 2025-11-28 04:40:43,860] Trial 114 finished with values: [0.8512499928474426, 23500.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.3881119925357018, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 5,804
# [I 2025-11-28 04:41:08,118] Trial 115 finished with values: [0.8006250262260437, 5804.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 16, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.14380622537696558, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 7,276
# [I 2025-11-28 04:41:33,828] Trial 116 finished with values: [0.7825000286102295, 7276.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 128, 'ds_filters_2': 16, 'dense_units': 32, 'dropout_rate': 0.1699450448168976, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 10,172
# [I 2025-11-28 04:42:30,066] Trial 117 finished with values: [0.7931249737739563, 10172.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 128, 'ds_filters_1': 16, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.18964666879694697, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 25,756
# [I 2025-11-28 04:43:06,727] Trial 118 finished with values: [0.8675000071525574, 25756.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.41502102465922236, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 11,100
# [I 2025-11-28 04:43:51,631] Trial 119 finished with values: [0.8393750190734863, 11100.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 64, 'dense_units': 16, 'dropout_rate': 0.2300133911132411, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 4,908
# [I 2025-11-28 04:44:11,678] Trial 120 finished with values: [0.7774999737739563, 4908.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 16, 'ds_filters_2': 16, 'dense_units': 128, 'dropout_rate': 0.24522783473737497, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 25,756
# [I 2025-11-28 04:44:42,029] Trial 121 finished with values: [0.8675000071525574, 25756.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.4188093670694618, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 12,332
# [I 2025-11-28 04:45:20,796] Trial 122 finished with values: [0.8287500143051147, 12332.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 64, 'dense_units': 32, 'dropout_rate': 0.42737988097584834, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 5,804
# [I 2025-11-28 04:45:48,345] Trial 123 finished with values: [0.8100000023841858, 5804.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 16, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.4074503360141063, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 24,188
# [I 2025-11-28 04:46:51,973] Trial 124 finished with values: [0.8218749761581421, 24188.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 128, 'ds_filters_2': 16, 'dense_units': 32, 'dropout_rate': 0.33305822596603163, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 7,132
# [I 2025-11-28 04:47:07,316] Trial 125 finished with values: [0.7574999928474426, 7132.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 16, 'ds_filters_2': 64, 'dense_units': 64, 'dropout_rate': 0.20809783495994136, 'BATCH_SIZE': 64}.
# Nombre de poids du modèle: 9,212
# [I 2025-11-28 04:47:38,023] Trial 126 finished with values: [0.8137500286102295, 9212.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 32, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.21725063624103247, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 32,108
# [I 2025-11-28 04:48:22,839] Trial 127 finished with values: [0.8543750047683716, 32108.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 128, 'ds_filters_2': 64, 'dense_units': 32, 'dropout_rate': 0.11003245620179877, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 2,284
# [I 2025-11-28 04:48:46,567] Trial 128 finished with values: [0.7237499952316284, 2284.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.38522343003881826, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 10,588
# [I 2025-11-28 04:49:06,835] Trial 129 finished with values: [0.8368750214576721, 10588.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.4355896579035059, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 30,876
# [I 2025-11-28 04:49:57,249] Trial 130 finished with values: [0.8587499856948853, 30876.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 128, 'ds_filters_2': 64, 'dense_units': 16, 'dropout_rate': 0.253704999337629, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 9,180
# [I 2025-11-28 04:50:17,498] Trial 131 finished with values: [0.8374999761581421, 9180.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 64, 'ds_filters_2': 64, 'dense_units': 32, 'dropout_rate': 0.4136898514236902, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 14,524
# [I 2025-11-28 04:50:54,865] Trial 132 finished with values: [0.8206250071525574, 14524.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 128, 'ds_filters_2': 16, 'dense_units': 32, 'dropout_rate': 0.40106689214822844, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 9,036
# [I 2025-11-28 04:51:50,017] Trial 133 finished with values: [0.8324999809265137, 9036.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 16, 'ds_filters_2': 64, 'dense_units': 32, 'dropout_rate': 0.4137222942952342, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 6,620
# [I 2025-11-28 04:52:44,033] Trial 134 finished with values: [0.8012499809265137, 6620.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 16, 'ds_filters_2': 32, 'dense_units': 16, 'dropout_rate': 0.31885290325057936, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 25,916
# [I 2025-11-28 04:53:15,542] Trial 135 finished with values: [0.856249988079071, 25916.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.36402225032232094, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 13,932
# [I 2025-11-28 04:53:43,212] Trial 136 finished with values: [0.7387499809265137, 13932.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 64, 'ds_filters_1': 16, 'ds_filters_2': 64, 'dense_units': 128, 'dropout_rate': 0.3749279777336786, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 16,748
# [I 2025-11-28 04:54:35,157] Trial 137 finished with values: [0.8762500286102295, 16748.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.42214288574539405, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 16,748
# [I 2025-11-28 04:55:42,631] Trial 138 finished with values: [0.8349999785423279, 16748.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.4490353480474957, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 11,564
# [I 2025-11-28 04:56:40,767] Trial 139 finished with values: [0.7862499952316284, 11564.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 32, 'dense_units': 64, 'dropout_rate': 0.4254022738518368, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 16,748
# [I 2025-11-28 04:57:38,275] Trial 140 finished with values: [0.8243749737739563, 16748.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.46776115457868905, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 30,284
# [I 2025-11-28 04:58:32,607] Trial 141 finished with values: [0.8324999809265137, 30284.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.4195647548783153, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 21,260
# [I 2025-11-28 04:59:23,277] Trial 142 finished with values: [0.8331249952316284, 21260.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 64, 'dropout_rate': 0.4398994530607228, 'BATCH_SIZE': 64}.
# Nombre de poids du modèle: 16,748
# [I 2025-11-28 05:00:35,742] Trial 143 finished with values: [0.8243749737739563, 16748.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.40869095331547123, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 16,748
# [I 2025-11-28 05:01:34,363] Trial 144 finished with values: [0.8637499809265137, 16748.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.45639394667356864, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 15,692
# [I 2025-11-28 05:02:19,476] Trial 145 finished with values: [0.8237500190734863, 15692.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 64, 'ds_filters_2': 32, 'dense_units': 32, 'dropout_rate': 0.42809151103989296, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 30,284
# [I 2025-11-28 05:02:45,259] Trial 146 finished with values: [0.7549999952316284, 30284.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.4444815378301725, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 16,748
# [I 2025-11-28 05:03:25,991] Trial 147 finished with values: [0.8518750071525574, 16748.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.4176863296359806, 'BATCH_SIZE': 64}.
# Nombre de poids du modèle: 21,260
# [I 2025-11-28 05:04:05,015] Trial 148 finished with values: [0.8618749976158142, 21260.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 64, 'dropout_rate': 0.42900670916859096, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 25,388
# [I 2025-11-28 05:04:45,800] Trial 149 finished with values: [0.8650000095367432, 25388.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 64, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.39414767606462425, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 10,124
# [I 2025-11-28 05:05:34,877] Trial 150 finished with values: [0.8331249952316284, 10124.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 32, 'dense_units': 32, 'dropout_rate': 0.40072783281730434, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 16,748
# [I 2025-11-28 05:06:19,801] Trial 151 finished with values: [0.8487499952316284, 16748.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.41052414131313836, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 13,228
# [I 2025-11-28 05:06:57,801] Trial 152 finished with values: [0.8537499904632568, 13228.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.43577102189004135, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 30,284
# [I 2025-11-28 05:07:47,436] Trial 153 finished with values: [0.8575000166893005, 30284.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.42174818280383686, 'BATCH_SIZE': 64}.
# Nombre de poids du modèle: 16,748
# [I 2025-11-28 05:08:45,147] Trial 154 finished with values: [0.8368750214576721, 16748.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.4450123155462492, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 29,900
# [I 2025-11-28 05:09:25,821] Trial 155 finished with values: [0.856249988079071, 29900.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 64, 'ds_filters_2': 128, 'dense_units': 64, 'dropout_rate': 0.3091021571496793, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 5,500
# [I 2025-11-28 05:09:51,534] Trial 156 finished with values: [0.7831249833106995, 5500.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 32, 'ds_filters_2': 16, 'dense_units': 32, 'dropout_rate': 0.18104782867534475, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 16,748
# [I 2025-11-28 05:10:34,950] Trial 157 finished with values: [0.8531249761581421, 16748.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.12626339166594402, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 16,748
# ...
# Nombre de poids du modèle: 5,260
# [I 2025-11-28 06:02:08,483] Trial 247 finished with values: [0.7993749976158142, 5260.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 64, 'ds_filters_2': 16, 'dense_units': 64, 'dropout_rate': 0.4225315048823322, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 16,748
# [I 2025-11-28 06:02:51,246] Trial 248 finished with values: [0.8349999785423279, 16748.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.43341280870158083, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 9,212
# [I 2025-11-28 06:03:14,638] Trial 249 finished with values: [0.7887499928474426, 9212.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 32, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.39666203440871806, 'BATCH_SIZE': 64}.
# Nombre de poids du modèle: 6,492
# [I 2025-11-28 06:03:52,111] Trial 250 finished with values: [0.7443749904632568, 6492.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 16, 'ds_filters_2': 16, 'dense_units': 32, 'dropout_rate': 0.446534679679298, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 30,748
# [I 2025-11-28 06:04:37,038] Trial 251 finished with values: [0.875, 30748.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.4108158575706709, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 3,964
# [I 2025-11-28 06:05:02,830] Trial 252 finished with values: [0.8112499713897705, 3964.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 32, 'ds_filters_2': 32, 'dense_units': 32, 'dropout_rate': 0.48268043369330355, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 12,332
# [I 2025-11-28 06:05:43,208] Trial 253 finished with values: [0.8431249856948853, 12332.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 64, 'dense_units': 32, 'dropout_rate': 0.20113603035044225, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 22,220
# [I 2025-11-28 06:06:03,154] Trial 254 finished with values: [0.8199999928474426, 22220.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.42003446217807616, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 8,556
# [I 2025-11-28 06:06:56,319] Trial 255 finished with values: [0.7549999952316284, 8556.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.4325287257714662, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 33,004
# [I 2025-11-28 06:07:45,548] Trial 256 finished with values: [0.8706250190734863, 33004.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.4036127059594786, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 21,260
# [I 2025-11-28 06:08:25,302] Trial 257 finished with values: [0.8600000143051147, 21260.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 64, 'dropout_rate': 0.41522606520640004, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 4,332
# [I 2025-11-28 06:08:53,028] Trial 258 finished with values: [0.7950000166893005, 4332.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 64, 'ds_filters_2': 16, 'dense_units': 32, 'dropout_rate': 0.426555759919624, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 6,428
# [I 2025-11-28 06:09:25,125] Trial 259 finished with values: [0.8131250143051147, 6428.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.12612147016566097, 'BATCH_SIZE': 64}.
# Nombre de poids du modèle: 9,020
# [I 2025-11-28 06:10:17,130] Trial 260 finished with values: [0.7693750262260437, 9020.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 16, 'dense_units': 32, 'dropout_rate': 0.4115569858537351, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 16,748
# [I 2025-11-28 06:11:13,473] Trial 261 finished with values: [0.8600000143051147, 16748.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.4988446053007592, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 16,380
# [I 2025-11-28 06:11:54,850] Trial 262 finished with values: [0.8393750190734863, 16380.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 128, 'ds_filters_2': 64, 'dense_units': 16, 'dropout_rate': 0.43617306600666295, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 2,972
# [I 2025-11-28 06:12:19,225] Trial 263 finished with values: [0.7931249737739563, 2972.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 16, 'ds_filters_2': 32, 'dense_units': 32, 'dropout_rate': 0.3893812118721997, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 10,124
# [I 2025-11-28 06:13:29,231] Trial 264 finished with values: [0.824999988079071, 10124.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 32, 'dense_units': 32, 'dropout_rate': 0.2969035398090776, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 33,356
# [I 2025-11-28 06:14:01,254] Trial 265 finished with values: [0.8568750023841858, 33356.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 64, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.4473650263455767, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 10,588
# [I 2025-11-28 06:14:21,240] Trial 266 finished with values: [0.840624988079071, 10588.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.39064413335954207, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 28,268
# [I 2025-11-28 06:15:03,530] Trial 267 finished with values: [0.8475000262260437, 28268.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 128, 'ds_filters_2': 32, 'dense_units': 64, 'dropout_rate': 0.38314878060300567, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 16,748
# [I 2025-11-28 06:15:37,199] Trial 268 finished with values: [0.8500000238418579, 16748.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.21360602816016033, 'BATCH_SIZE': 64}.
# Nombre de poids du modèle: 8,060
# [I 2025-11-28 06:15:47,733] Trial 269 finished with values: [0.5899999737739563, 8060.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 16, 'ds_filters_1': 16, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.37118435427256763, 'BATCH_SIZE': 32}.
# Nombre de poids du modèle: 16,748
# [I 2025-11-28 06:16:26,231] Trial 270 finished with values: [0.8537499904632568, 16748.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.17260207241414854, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 8,812
# [I 2025-11-28 06:16:50,176] Trial 271 finished with values: [0.8100000023841858, 8812.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 32, 'ds_filters_2': 64, 'dense_units': 32, 'dropout_rate': 0.25939738371306326, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 25,964
# [I 2025-11-28 06:17:47,223] Trial 272 finished with values: [0.8462499976158142, 25964.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 16, 'ds_filters_2': 128, 'dense_units': 128, 'dropout_rate': 0.3994620882061086, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 42,668
# [I 2025-11-28 06:18:45,816] Trial 273 finished with values: [0.8700000047683716, 42668.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.4415955840000245, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 3,244
# [I 2025-11-28 06:19:12,224] Trial 274 finished with values: [0.7737500071525574, 3244.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 32, 'ds_filters_2': 32, 'dense_units': 16, 'dropout_rate': 0.2714525834426818, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 19,820
# [I 2025-11-28 06:19:56,647] Trial 275 finished with values: [0.8506249785423279, 19820.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 64, 'ds_filters_1': 64, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.306383403320174, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 9,948
# [I 2025-11-28 06:20:43,607] Trial 276 finished with values: [0.8168749809265137, 9948.0] and parameters: {'activation': 'relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 16, 'dense_units': 64, 'dropout_rate': 0.46682989389137697, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 8,684
# [I 2025-11-28 06:21:10,870] Trial 277 finished with values: [0.8381249904632568, 8684.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.3165721406233002, 'BATCH_SIZE': 64}.
# Nombre de poids du modèle: 2,124
# [I 2025-11-28 06:21:34,910] Trial 278 finished with values: [0.7456250190734863, 2124.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 16, 'ds_filters_2': 16, 'dense_units': 32, 'dropout_rate': 0.31597906030482587, 'BATCH_SIZE': 64}.
# Nombre de poids du modèle: 16,748
# [I 2025-11-28 06:22:33,946] Trial 279 finished with values: [0.8256250023841858, 16748.0] and parameters: {'activation': 'leaky_relu', 'conv_filters': 128, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.42222121916413724, 'BATCH_SIZE': 64}.
# Nombre de poids du modèle: 28,172
# [I 2025-11-28 06:23:08,804] Trial 280 finished with values: [0.8768749833106995, 28172.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.4326385056052975, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 9,228
# [I 2025-11-28 06:23:48,422] Trial 281 finished with values: [0.8331249952316284, 9228.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 128, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.14937110783134638, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 9,228
# [I 2025-11-28 06:24:36,765] Trial 282 finished with values: [0.8006250262260437, 9228.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 128, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.44789015230903867, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 2,284
# [I 2025-11-28 06:25:05,017] Trial 283 finished with values: [0.7262499928474426, 2284.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.4598844844970168, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 9,228
# [I 2025-11-28 06:25:44,296] Trial 284 finished with values: [0.7737500071525574, 9228.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 128, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.4560778425959867, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 2,284
# [I 2025-11-28 06:26:12,626] Trial 285 finished with values: [0.7574999928474426, 2284.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.44126677097750067, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 2,284
# [I 2025-11-28 06:26:40,631] Trial 286 finished with values: [0.7475000023841858, 2284.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.4524077428177888, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 2,284
# [I 2025-11-28 06:27:08,726] Trial 287 finished with values: [0.7437499761581421, 2284.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.44117650027714544, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 9,692
# [I 2025-11-28 06:27:48,690] Trial 288 finished with values: [0.8131250143051147, 9692.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 128, 'ds_filters_2': 16, 'dense_units': 32, 'dropout_rate': 0.4698772349890912, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 6,428
# [I 2025-11-28 06:28:20,663] Trial 289 finished with values: [0.8162500262260437, 6428.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.47982378120009317, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 9,692
# [I 2025-11-28 06:28:59,892] Trial 290 finished with values: [0.8075000047683716, 9692.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 128, 'ds_filters_2': 16, 'dense_units': 32, 'dropout_rate': 0.317639394238205, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 8,684
# [I 2025-11-28 06:29:26,797] Trial 291 finished with values: [0.8137500286102295, 8684.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 16, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.33143815315140057, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 7,676
# [I 2025-11-28 06:30:03,221] Trial 292 finished with values: [0.8374999761581421, 7676.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 16, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.3430733662435353, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 30,748
# [I 2025-11-28 06:31:02,630] Trial 293 finished with values: [0.8737499713897705, 30748.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.4319501434897717, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 3,532
# [I 2025-11-28 06:31:27,692] Trial 294 finished with values: [0.7450000047683716, 3532.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 16, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.34133902272101485, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 33,004
# [I 2025-11-28 06:32:10,874] Trial 295 finished with values: [0.8606250286102295, 33004.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 128, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.44068338885562813, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 5,500
# [I 2025-11-28 06:32:44,573] Trial 296 finished with values: [0.7975000143051147, 5500.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 32, 'ds_filters_2': 16, 'dense_units': 32, 'dropout_rate': 0.3917923114262547, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 5,804
# [I 2025-11-28 06:33:13,784] Trial 297 finished with values: [0.800000011920929, 5804.0] and parameters: {'activation': 'relu', 'conv_filters': 16, 'ds_filters_1': 16, 'ds_filters_2': 128, 'dense_units': 16, 'dropout_rate': 0.42567792670441146, 'BATCH_SIZE': 16}.
# Nombre de poids du modèle: 13,228
# [I 2025-11-28 06:33:43,361] Trial 298 finished with values: [0.8399999737739563, 13228.0] and parameters: {'activation': 'relu', 'conv_filters': 64, 'ds_filters_1': 32, 'ds_filters_2': 128, 'dense_units': 32, 'dropout_rate': 0.1936969315620244, 'BATCH_SIZE': 128}.
# Nombre de poids du modèle: 3,276
# [I 2025-11-28 06:34:14,595] Trial 299 finished with values: [0.7762500047683716, 3276.0] and parameters: {'activation': 'relu', 'conv_filters': 32, 'ds_filters_1': 32, 'ds_filters_2': 16, 'dense_units': 16, 'dropout_rate': 0.4177198604192565, 'BATCH_SIZE': 16}.

# %%
print("Trials sur le front de Pareto (acc à max, taille à min) :")
pareto_trials = study.best_trials   # liste de Trial

for t in pareto_trials:
    acc  = t.values[0]      # 1er objectif : val_acc
    size = t.values[1]      # 2e objectif : taille du modèle
    print(f"acc={acc:.4f}, size={size}, params={t.params}")

# Exemple de choix d'un compromis :
# ici : on prend le trial avec la plus grande accuracy
best_by_acc = max(pareto_trials, key=lambda tr: tr.values[0])

print("\nTrial choisi comme 'meilleur compromis' (max accuracy) :")
print(f"  acc  = {best_by_acc.values[0]:.4f}")
print(f"  size = {best_by_acc.values[1]}")
print("  Params :")
for k, v in best_by_acc.params.items():
    print(f"    {k}: {v}")

# Sauvegarde des hyperparamètres de CE modèle dans un fichier
import json
with open("best_params_multi.json", "w") as f:
    json.dump(best_by_acc.params, f, indent=4)

# %% [markdown]
# ## Résultat et discussion
#
# <font color=" Darkred"> Progression du TP après cette partie (environ 3h): </font>
# ![84%](https://progress-bar.dev/84)

# %% [markdown]
# ### Export du modèle
#
# Merci d'exporter le meilleur modèle et l'envoyer avec le jupyter notebook et la base de données d'entraînement. Lors de l'exportation d'un modèle, il est recommandé d'utiliser la base de donnée d'entrainement, et de validation.
#
#  <font color="green">*Cette partie du code est complète, vous n'avez pas besoin de la modifier.* </font>

# %%
import joblib

# Fix the storage URL format for SQLAlchemy
storage_url_fixed = f"sqlite:///{storage_name.replace('sqlite:///', '')}"
study = optuna.load_study(storage=storage_url_fixed, study_name=study_name)
print("Best trial until now:")
print("   Value: ", study.best_trial.value)
print("   Params: ")
for key, value in study.best_trial.params.items():
    print(f"    -{key}: {value}")
print("----------------------")

model = create_model(study.best_trial.params, INPUT_SHAPE, NUM_CLASSES)

train_and_val = tf.data.Dataset.from_tensor_slices((np.concatenate((X_train, X_val)), np.concatenate((y_train, y_val))))
train_and_val = train_and_val.shuffle(1500, reshuffle_each_iteration=True)
train_and_val = train_and_val.batch(32, drop_remainder=True)


validation_evaluation_post_optuna, global_model_post_optuna, history_post_optuna = compile_and_fit(model, train_and_val, val, study.best_trial.params, verbose=0)

#joblib.dump(global_model, '/content/drive/MyDrive/TP N9EE39A/NOM1~NOM2_model.pkl')
joblib.dump(global_model_post_optuna, '/home/zebre/Bureau/eddge_computing/Edge_computing/model//Hanni_Benarib_model.pkl')

# %% [markdown]
# ### Dépôt sur Kaggle
#
# Il est temps de soumettre vos résultats sur Kaggle. Qu'en pensez vous, êtes vous satisfait de vos performances ? Est-ce que vous vous attendiez à ces performances ?
#
#  <font color=" Darkblue"> **Tips:** Le format d'envoie et des tutoriels sont disponibles sur la page du concours. </font>
#
#  <font color="orange"> **Note anti-plagiat:** Il est impossible que le fichier que vous allez déposer soit le même qu'un autre binôme. Le fichier sera regénérer lors de la correction et doit être similaire avec celui déposé. </font>
#
# A la fin du projet, merci d'envoyer avec les autres fichiers ce fichier Kaggle avec comme nom **NOM1~NOM2_submission.csv**.
#
# > **Ecrire votre texte ici.**

# %%
#Ici, tous le code est à faire. Normalement, tous a déjà été codé ou est facilement trouvable sur internet et sur le site de la compétition !

# %% [markdown]
# ### Visualisation des résultats
#
# Ici tous le code a déjà été fait. Il faut par contre commenter les résultats et les performances que vous avez obtenu et l'utilité de chaque figure.

# %% [markdown]
#  #### Matrice de confusion
#
#  <font color="green">*Cette partie du code est complète, vous n'avez pas besoin de la modifier.* </font>
#
#  > **Ecrire votre texte ici.**

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# (re)load study if needed
study = optuna.load_study(storage=storage_url, study_name=study_name)

# Predictions from the model on the validation dataset
y_prob = global_model_post_optuna.predict(val)
y_pred = y_prob.argmax(axis=1)

# Build reference labels from the tf.data Dataset
ds_labels = []
for images, labels in val.unbatch():
    ds_labels.append(labels)
y_ref = np.array(ds_labels).argmax(axis=1)

# Label names (order must match the numeric label indices)
label_names = ["yes", "no", "up", "down", "left", "right", "on", "off", "stop", "go", "silence", "unknown"]

# Ensure the confusion matrix includes all classes (even if some are absent in y_ref/y_pred)
all_labels = list(range(len(label_names)))

# Draw confusion matrix — pass `labels` so ticks match `display_labels`
ConfusionMatrixDisplay.from_predictions(
    y_ref,
    y_pred,
    labels=all_labels,
    display_labels=label_names,
    cmap='Blues',
    normalize='true',
    ax=plt.subplots(figsize=(12, 12))[1]
)
plt.tight_layout()

# %% [markdown]
# #### Résultat du Fit-tuning
#
#  <font color="green">*Cette partie du code est complète, vous n'avez pas besoin de la modifier.* </font>
#
#  > **Ecrire votre texte ici.**

# %%
plt.figure(figsize=(12,12))
optuna.visualization.plot_optimization_history(study)

# %%
plt.figure(figsize=(12,12))
optuna.visualization.plot_slice(study)

# %% [markdown]
# #### Influence des hyperparamètres sur les performances
#
#  <font color="green">*Cette partie du code est complète, vous n'avez pas besoin de la modifier.* </font>
#
#  > **Ecrire votre texte ici.**

# %%
result = optuna.importance.get_param_importances(study)
plt.figure(figsize=(12, 4.5), dpi=100)
names = list(result.keys())
values = list(result.values())

plt.bar(range(len(result)), np.array(values)*100, tick_label=names, color='#000233')
plt.ylabel("Hyperparameter importance (%)")
plt.show()

# %% [markdown]
# #### Influence des hyperparamètres sur le temps de calcul
#
#  <font color="green">*Cette partie du code est complète, vous n'avez pas besoin de la modifier.* </font>
#
#  > **Ecrire votre texte ici.**

# %%
result = optuna.importance.get_param_importances(study, target=lambda t: t.duration.total_seconds())
plt.figure(figsize=(12, 4.5), dpi=100)
names = list(result.keys())
values = list(result.values())

plt.bar(range(len(result)), np.array(values)*100, tick_label=names, color='#000233')
plt.ylabel("Hyperparameter importance (%)")
plt.show()

# %% [markdown]
# #### Frontière de Pareto [[4]](https://fr.wikipedia.org/wiki/Optimum_de_Pareto)
#
#  <font color="green">*Cette partie du code est complète, vous n'avez pas besoin de la modifier.* </font>
#
#  > **Ecrire votre texte ici.**

# %%
import pandas

def plot_pareto_frontier(Xs, Ys, maxX=True, maxY=True):
  # From https://sirinnes.wordpress.com/2013/04/25/pareto-frontier-graphic-via-python/
    '''Pareto frontier selection process'''
    sorted_list = sorted([[Xs[i], Ys[i]] for i in range(len(Xs))], reverse=maxY)
    pareto_front = [sorted_list[0]]
    for pair in sorted_list[1:]:
        if maxY:
            if pair[1] >= pareto_front[-1][1]:
                pareto_front.append(pair)
        else:
            if pair[1] <= pareto_front[-1][1]:
                pareto_front.append(pair)

    '''Plotting process'''
    plt.scatter(Xs,Ys)
    pf_X = [pair[0] for pair in pareto_front]
    pf_Y = [pair[1] for pair in pareto_front]
    plt.plot(pf_X, pf_Y)
    plt.xlabel("Poids du modèle (octets)")
    plt.ylabel("Accuracy (%)")
    plt.show()

df = study.trials_dataframe()
plot_pareto_frontier(df['user_attrs_Size'], df['value'])

# %% [markdown]
# ## Allégement du modèle post-optimisation
#
# Dans cette dernière partie, nous allons nous intéresser à l'influence des performances lorsque le modèle est allégé. Dans des appareils embarqués, il est nécessaire de trouver un compromis entre la performance du modèle, son poids, et la quantité d'opération.
#
# Au vue du nombre de séances, nous allons nous intéressé ici qu'au poids du système.
#
# Pour cela, vous allez essayé de réduire le poids du meilleur modèle obtenu, puis avoir un regard critique sur les performances à chaque modification.
#
# Voici les techniques d'allégement à essayer:
#   - **La quantification**: Réduire le nombre d'octets des paramètres du modèles et les convertir en entiers [[5]](https://www.tensorflow.org/lite/performance/post_training_quantization).
#   - **L'élagage**: Supprimer les modèles qui ont un impact mineur sur les prédictions [[6]](https://www.tensorflow.org/model_optimization/guide/pruning/pruning_with_keras).
#   - **Le clustering**: Regrouper les poids de chaque couche dans un modèle en un nombre prédéfini de clusters, puis en partageant les valeurs centroïdes pour les poids appartenant à chaque cluster individuel [[7]](https://www.tensorflow.org/model_optimization/guide/clustering/clustering_example).
#   - **La décimation** : Réduire le nombre d'entrée.
#
# <font color=" Darkred"> Progression du TP après cette partie (environ 4h):
#
# Essayez d'avoir la meilleure accuracy avec un poids maximum inférieur à 75 KB.
#
#  <font color=" Darkblue"> **Tips:**  Des tutoriels sont disponibles sur les liens attachés au techniques d'allégement. </font>
#
#  > **Ecrire votre texte ici.**

# %% [markdown]
# Pour cette partie nous sommes partis nous avons suivie les conseils données en [[5]](https://www.tensorflow.org/lite/performance/post_training_quantization).
#
# Pour la quantification. Notre modèle étant optimisé via otpuna aux niveaus de ses hyperparamètres, notre architecture ayant pour but d'être porté sur FPGA (cible difficile à programmer) et notre dataset n'étant pas représentatif de nos données, nous nous sommes cantonés à une quantification en float16 ppur commencer.
# ![Screenshot from 2025-11-24 01-39-04.png](<attachment:Screenshot from 2025-11-24 01-39-04.png>)

# %% [markdown]
# Tensor Flow Lite permet de réaliser cette conversion en:
#
#     - float 16 (réduit de moitié la taille du modèle)
#     - int 8
# Les avanatges d'une telle quantification sont les suivants :
#
#     - Réduction de la taille du modèle de moitié (poids et activation réduit à 16 bits)
#     - Pert d'accuracy minimale
#     - Rend le calul possible sur architecyure GPU
#
# Les désavantages du float 16 sont:
#
#     - Ne réduit pas la latence autant qu'une quantificatio avec calcul en virgule fixe.
#     By default, a float16 quantized model will "dequantize" the weights values to float32 when run on the CPU. (Note that the GPU delegate will not perform this dequantization, since it can operate on float16 data.)

# %% [markdown]
# Pour aller plus loin dans le projet sur la quantification, et voire laquelle serait la plus intéressante pour un bon rapport perfomance/implémentation et embarquabilité sur cible, il nous faut observer ce que donne les résultats de notre modèle avec cette simple quantification, sans détails supplémentaire. Pour cela nous avons rédigé une petite focntion ci dessous pour quantifier nos données ainsi que notre réseaux.

# %%
def fake_quantize(x, bits=8, frac_bits=7):
    """
    Simule un format fixe signé Q(1.(bits-1)) avec 'frac_bits' bits de fraction.
    bits = largeur totale (ex: 8) ; frac_bits ~ 7 → Q1.7
    """
    x = x.astype(np.float32)
    scale = 2 ** frac_bits

    qmin = -2 ** (bits - 1)
    qmax =  2 ** (bits - 1) - 1

    x_scaled = np.round(x * scale)
    x_clipped = np.clip(x_scaled, qmin, qmax)
    x_dequant = x_clipped / scale
    return x_dequant.astype(np.float32)

# %%
model.evaluate(X_val, y_val),
model.evaluate(fake_quantize(X_val, bits=16, frac_bits=11), y_val),
model.evaluate(fake_quantize(X_val, bits=8, frac_bits=7), y_val)

# %%
import tensorflow as tf
import joblib

# Load the model from pickle file
model_path = "/home/zebre/Bureau/eddge_computing/Edge_computing/model/Hanni_Benarib_model.pkl"
loaded_model = joblib.load(model_path)

# Convert the Keras model to TensorFlow Lite format
converter = tf.lite.TFLiteConverter.from_keras_model(loaded_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_types = [tf.float16]
tflite_quant_model = converter.convert()

# Save the TensorFlow Lite model
tflite_model_path = "/home/zebre/Bureau/eddge_computing/Edge_computing/model/Hanni_Benarib_model.tflite"
with open(tflite_model_path, 'wb') as f:
	f.write(tflite_quant_model)

print(f"TFLite model saved to: {tflite_model_path}")
print(f"Model size: {len(tflite_quant_model) / 1024:.2f} KB")

# %% [markdown]
# ### BONUS: Allégement avant optimisation
#
# Relancez un fit-tuning en rajoutant les paramètres d'allégements. Puis, observez les resultats avec une frontière de pareto. Les valeurs minimums de poids de la frontière doivent se trouver en dessous de 50 KB.
#
#  <font color=" Darkblue"> **Tips:** Utilisez 2 métriques lorsque vous lancez la fonction d'activation. </font>
#
#  > **Ecrire votre texte ici.**

# %% [markdown]
# ## Conclusion
#
#
#  <font color=" Darkblue"> **Tips:** Concluez sur vos résultats, les limitations de votre modèle et les perspectives envisagées pour l'améliorer. </font>
#
#
#  <font color=" Darkred"> Progression du TP après cette partie (environ 0h30): </font>
#
#
# > **Ecrire votre texte ici.**
